# %%
'''In this program I am making an api request with regular request python module to make google searches.
I shall also be using try and except clauses in python.'''

import html_to_json
import pandas as pd
import requests
import json

#Link of what you want to search using search api.
urlLink = "https://www.nike.com/t/free-metcon-4-training-shoes-KX41Bv/CT3886-301?nikemt=true&cp=38647199687_search_%7CPRODUCT_GROUP%7CGOOGLE%7C71700000101429394%7CGG_Evergreen_Shopping_Shoes_AllShoes%7C%7Cc&exp=2011&gclsrc=aw.ds&&gclid=CjwKCAiAkrWdBhBkEiwAZ9cdcG7uW3qP3yZZIUe8oysRg4raRJLgiCGHfPXxeNCBlp908KAIcQgWcxoCF1kQAvD_BwE&gclsrc=aw.ds"

response = requests.get(url=urlLink)
response.encoding = 'ISO-8859-1'
print("The data's encoding is:",response.encoding)
print("\nstatusCode:", response.status_code)
#print("\nThe respose headers are:",response.headers)
#print("\nThe response content:",response.content)
#print(response.text)


data_in_json = html_to_json.convert(response.text)
print(data_in_json.keys())
#converting it from a list to dictionary

data = data_in_json['html']
actualData = data[0]

print("Here are the keys to the returned data:", actualData.keys())

################################## Now We access our Data!! Yay!!!#########################
#print(actualData['body'][0])
count = 1
for i in actualData['body'][0].keys():
    if i == 'script':
        print(len(actualData['body'][0][i]))
        #print("Key==", i, "\n\n\n\n", actualData['body'][0][i], "\n")
        #print(actualData['body'][0][i][7])
        # for j in actualData['body'][0][i]:
        #     try:
        #         print(j['_attributes'])
        #     except:
        #         print("This is an exception")
        #         print(j['_value'])
        #     count = count + 1

# for i in data_in_json['html']:
#     print(i)
# Out:
# The data's encoding is: ISO-8859-1
#
# statusCode: 200
# dict_keys(['_value', 'html'])
# Here are the keys to the returned data: dict_keys(['_attributes', 'head', 'body'])
# 25

# %% [markdown]
# Further breaking down the dictionary and trying to Access the real images we want. We use the json.loads() to convert  the str dictonary data to json

# %%
for i in actualData['body'][0].keys():
    if i == 'script':
        for line in actualData['body'][0][i]:
            #print(line,"\n\n\n")
            if len(line.keys()) == 2:
                #print(line["_attributes"],"\n\n")
                if line["_attributes"]['type'] == 'application/json':
                    #print(line["_value"])
                    json_object = json.loads(line["_value"]) #converting the str json format data to actual json and dictonary instead of a string

# %% [markdown]
# # Inspecting JSON Object

# %%
json_object
# Out:
# {'props': {'pageProps': {'initialState': {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#       'titleTemplate': '%s',
#       'meta': [{'name': 'description',
#         'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#        {'name': 'keywords', 'content': 'Nike Free Metcon 4 Training Shoes'},
#        {'name': 'robots', 'content': 'index, follow'},
#        {'property': 'og:title',
#         'content': 'Nike Free Metcon 4 Training Shoes. Nike.com'},
#        {'property': 'og:description',
#         'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#        {'property': 'og:type', 'content': 'website'},
#        {'property': 'og:url',
#         'content': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'},
#        {'property': 'og:image',
#         'content': 'https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png'},
#        {'property': 'og:locale', 'content': 'en_US'},
#        {'property': 'og:site_name', 'content': 'Nike.com'},
#        {'property': 'og:price:currency', 'content': 'USD'},
#        {'property': 'og:price:amount', 'content': 120},
#        {'name': 'branch:deeplink:$deeplink_path',
#         'content': 'x-callback-url/product-details?style-color=CT3886-004'},
#        {'property': 'fb:app_id', 'content': '1397260880304609'}],
#       'title': 'Nike Free Metcon 4 Training Shoes. Nike.com',
#       'link': [{'rel': 'canonical',
#         'href': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'}]}},
#     'reviews': {'country': 'us',
#      'apiversion': None,
#      'sorts': {'SubmissionTime': True},
#      'productStyleCode': 'CT3886',
#      'total': 0,
#      'averageRating': 0,
#      'recommendedCount': 0,
#      'reviews': [],
#      'dimensions': [],
#      'reviewsMap': {},
#      'initialFetched': False,
#      'initialFetching': False,
#      'initialFetchError': False,
#      'fetched': False,
#      'fetching': False,
#      'fetchError': False,
#      'positiveFeedbackSubmitting': {},
#      'positiveFeedbackSubmitted': {},
#      'positiveFeedbackSubmitError': {},
#      'negativeFeedbackSubmitting': {},
#      'negativeFeedbackSubmitted': {},
#      'negativeFeedbackSubmitError': {},
#      'inappropriateFeedbackSubmitting': {},
#      'inappropriateFeedbackSubmitted': {},
#      'inappropriateFeedbackSubmitError': {},
#      'isDrawerOpen': False,
#      'reviewsDrawerType': 'view',
#      'currentReviewId': '',
#      'summary': {'total': 0,
#       'limit': 0,
#       'averageRating': 0,
#       'recommendedCount': 0,
#       'reviews': [],
#       'secondaryRatingsOrder': [],
#       'bestRating': 5,
#       'worstRating': 1},
#      'vendor': 'VENDOR/TURN_TO',
#      'serverSideFetched': False,
#      'serverSideFetching': True,
#      'serverSideFetchError': False},
#     'localization': {'urlParam': 'en',
#      'language': 'en',
#      'intl': 'en-US',
#      'langRegion': 'en-US',
#      'hreflang': 'en-US',
#      'default': True,
#      'country': 'us',
#      'countryName': 'United States',
#      'currency': 'USD',
#      'reactIntl': '',
#      'merchGroup': 'US',
#      'messages': {'91330387': 'Name of wishlist is not unique.',
#       'JP.discount_addendum': 'Sale Price',
#       'browse_crossSellPopItemLowerCase': 'These popular items might interest you',
#       'browse_fallback_message': "The page you were viewing was experiencing technical difficulties and we're working to resolve it. A quick refresh should get you back in play. Apologies for the inconvenience.",
#       'browse_fallback_refresh_button': 'Refresh Now',
#       'browse_fallback_title': 'Short time out needed',
#       'browse_noMatchesFound': 'No matches found.',
#       'browse_pleaseTryAnotherSearch': 'Please try another search.',
#       'hf-geomismatch-chooseLocation': 'Choose Location',
#       'hf-geomismatch-confirm': 'Confirm',
#       'hf-geomismatch-message': 'Update your location to shop products available in {country}',
#       'hf-geomismatch-prompt': 'We think you are in {country}. Update your location?',
#       'hf-geomismatch-title': 'Confirm your Location',
#       'hf-geoselection-title': 'Select your Location',
#       'hf-header-label-carticon': 'Bag Items',
#       'hf-header-label-countryicon': 'Selected Location',
#       'hf_close_menu_aria_label': 'Close Menu',
#       'hf_cookie-policy_banner_ok': 'OK',
#       'hf_cookie_label_cookieSettings': 'Cookie Settings',
#       'hf_cookie_label_done': 'Done',
#       'hf_cookie_label_functional': 'Functional',
#       'hf_cookie_label_performance': 'Performance',
#       'hf_cookie_label_privacyPolicy': 'Privacy & Cookie Policy',
#       'hf_cookie_label_socialMedia': 'Social Media and Advertising',
#       'hf_cookie_label_yourCookieSettings': 'Your Cookie Settings',
#       'hf_cookie_policy_banner': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {privacyAndCookiePolicyHTML}. You can adjust your preferences in {cookieSettingsHTML}.',
#       'hf_cookie_policy_banner_ok': 'OK',
#       'hf_cookie_text_cookieAccept': 'Yes, I Accept',
#       'hf_cookie_text_cookieReject': "No, I Don't Accept",
#       'hf_cookie_text_do_you_accept': 'Do you accept these cookies and the processing of personal data involved?',
#       'hf_cookie_text_footer': 'You can always change your preference by visiting the "Cookie Settings" at the bottom of the page. View {privacyAndCookiePolicyHTML} for full details.',
#       'hf_cookie_text_functional': 'These cookies are required for basic site functionality and are therefore always enabled. These include cookies that allow you to be remembered as you explore the site within a single session or, if you request, from session to session. They help make the shopping cart and checkout process possible as well as assist in security issues and conforming to regulations.',
#       'hf_cookie_text_information': 'Privacy & Cookie Policy',
#       'hf_cookie_text_moreInformation': 'More Information',
#       'hf_cookie_text_performance': 'These cookies allow us to improve the siteâ\x80\x99s functionality by tracking usage on this website. In some cases these cookies improve the speed with which we can process your request, allow us to remember site preferences youâ\x80\x99ve selected. De-selecting these cookies may result in poorly-tailored recommendations and slow site performance.',
#       'hf_cookie_text_policy': 'Nike asks you to accept cookies for performance, social media and advertising purposes. Social media and advertising cookies of third parties are used to offer you social media functionalities and personalized ads. To get more information or amend your preferences, press the â\x80\x98more informationâ\x80\x99 button or visit "Cookie Settings" at the bottom of the website. To get more information about these cookies and the processing of your personal data, check our {privacyAndCookiePolicyHTML}. Do you accept these cookies and the processing of personal data involved?',
#       'hf_cookie_text_socialMedia': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#       'hf_cookie_text_socialMedia_2': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#       'hf_cookie_title_cookieSettings': 'Your Cookie Settings',
#       'hf_fallback_account': 'Account',
#       'hf_header_find_a_store': 'Find a Store',
#       'hf_header_label_acceptedPaymentTypes': 'Accepted Payment Types',
#       'hf_header_label_account': 'Account',
#       'hf_header_label_bag': 'Bag',
#       'hf_header_label_closeSearch': 'Close Search',
#       'hf_header_label_copyright': 'Â© 2023 Nike, Inc. All Rights Reserved',
#       'hf_header_label_favorites': 'Favorites',
#       'hf_header_label_help': 'Help',
#       'hf_header_label_hurleyLogo': 'Hurley Home Page',
#       'hf_header_label_joinOrLogin': 'Join/Log In To Nike Member Profile',
#       'hf_header_label_liveChat': 'Live Chat',
#       'hf_header_label_myAccount': 'My Account',
#       'hf_header_label_nikeSwooshLogo': 'Nike Home Page',
#       'hf_header_label_orders': 'Orders',
#       'hf_header_label_popular_search_terms': 'Popular Search Terms',
#       'hf_header_label_resetSearch': 'Reset Search',
#       'hf_header_label_search': 'Search',
#       'hf_header_label_search_input': 'Search Products',
#       'hf_header_label_search_open': 'Open Search Modal',
#       'hf_header_label_search_topSuggestions': 'Top Suggestions',
#       'hf_header_label_secondaryNavigation': 'Secondary Navigation',
#       'hf_header_label_selectACountry': 'Selected Location',
#       'hf_label_avatar': 'Avatar',
#       'hf_logo_converse': 'Converse Logo',
#       'hf_logo_jordan': 'Jordan Logo',
#       'hf_menu_aria_label': 'menu',
#       'hf_message_join_membership': 'Become a Nike Member for the best products, inspiration and stories in sport. {learnMore}',
#       'hf_message_join_nikeplus': 'Join Us to enjoy the best of Nike Membership with our family of apps, free shipping, access to coaching, global events and more.',
#       'hf_popular_search_gifts': 'Gifts',
#       'hf_search_cancel': 'Cancel',
#       'hf_skip_to_content': 'Skip to main content',
#       'hf_title_all_menuitem': 'All',
#       'hf_title_greeting_membership': 'Hi, {name}',
#       'hf_title_greeting_membership_a11y': 'Hi, {name}. Account & Favorites',
#       'hf_title_join_nikeplus': 'SIGN IN / JOIN US',
#       'hf_title_joinus_membership': 'Join Us',
#       'hf_title_learnmore_membership': 'Learn more',
#       'hf_title_signin_membership': 'Sign In',
#       'hf_visual_search_no_product_found': 'No product suggestions found for {query}',
#       'hf_visual_search_title': 'TOP SUGGESTIONS',
#       'hf_visual_search_viewall': 'View All',
#       'pdp_NBYCustomize': 'Customize',
#       'pdp_buying_tools_add_to_wishlist': 'Favorite',
#       'pdp_crosssell_buy_now': 'Buy Now',
#       'pdp_crosssell_cart_title': 'YOU MIGHT ALSO LIKE',
#       'pdp_crosssell_color': 'Color',
#       'pdp_crosssell_colors': 'Colors',
#       'pdp_crosssell_customize': 'Customize',
#       'pdp_crosssell_first_ordinal_indicator': 'st',
#       'pdp_crosssell_jersey_title': 'GET THE ULTIMATE',
#       'pdp_crosssell_jerseykids_title': 'GET THE ULTIMATE',
#       'pdp_crosssell_nfl_teams_available': 'All NFL Teams Available',
#       'pdp_crosssell_nfl_title': 'GET THE ULTIMATE',
#       'pdp_crosssell_nfl_title_suffix': 'HOOKUP',
#       'pdp_crosssell_nikeid_button': 'Shop All Nike By You',
#       'pdp_crosssell_nikeid_customize': 'CUSTOMIZE YOUR OWN WITH NIKE BY YOU',
#       'pdp_crosssell_nikeid_title': 'YOU MIGHT ALSO LIKE',
#       'pdp_crosssell_nikeid_url': 'http://www.nike.com/us/en_us/c/nikeid',
#       'pdp_crosssell_options': 'Options',
#       'pdp_crosssell_player_available': 'Player Available',
#       'pdp_crosssell_players_available': 'Players Available',
#       'pdp_crosssell_second_ordinal_indicator': 'nd',
#       'pdp_crosssell_shop_all_nikeid': 'SHOP ALL NIKE BY YOU',
#       'pdp_crosssell_third_ordinal_indicator': 'rd',
#       'pdp_crosssell_title': 'YOU MIGHT ALSO LIKE',
#       'pdp_crosssell_top_kids_products': 'TOP KIDSâ\x80\x99 PRODUCTS',
#       'pdp_crosssell_top_mens_products': 'TOP MENâ\x80\x99S PRODUCTS',
#       'pdp_crosssell_top_womens_products': 'TOP WOMENâ\x80\x99S PRODUCTS',
#       'pdp_crosssell_widths_available': 'Widths Available',
#       'pdp_nikeid_thumbnail_alt_text': 'Design your own Nike By You product',
#       'pdp_remove_customized_jersey': 'Remove',
#       'seePriceInCart': 'See Price in Bag',
#       'sub_footer_business_information_link_text': 'Business information confirmation',
#       'sub_footer_business_information_text': '(U) Nike Korea CEO Kimberlee Lynn Chang Mendes | 30th floor, Gangnam Finance Center, 152 Teheran-ro, Gangnam-gu, Seoul | Mail order distributor number 2011-Seoul Gangnam-03461 | Business registration number {phone}',
#       'sub_footer_businness_company_text': 'deposit payment',
#       'sub_footer_customer_service_text': 'Customer service phone number {phone} FAX {fax} | Email: {email} | Hosting service provider (U) Nike Korea',
#       'sub_footer_legal_info_link_text': 'Read more',
#       'sub_footer_legal_info_text': 'Information on content protection under the Content Industry Promotion Act.',
#       'sub_footer_modal_body_text': 'Name of content: product information, event information, etc.\nDate of creation of the content: cut-over date (or its update date if the content has been upgraded).\nAll content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent).',
#       'sub_footer_modal_body_text_one': 'Name of content: product information, event information, etc',
#       'sub_footer_modal_body_text_three': 'All content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent)',
#       'sub_footer_modal_body_text_two': 'Date of creation of the content: October 05, 2022 (or its update date if the content has been upgraded)',
#       'sub_footer_modal_title': 'Indication under the Content Industry Promotion Act',
#       'sub_footer_payment_information_text': 'For safe transactions, when paying with cash, etc., \u2028you can use the purchase safety service ({company}) of Korea Payment Network Co., Ltd., which you signed up for in our shopping mall.',
#       'test': 'testing',
#       '04E2F5C8': 'Sorry, the resource you requested does not exist.',
#       '15E57A07': 'Sorry, we had an issue with your request.  Please try again.',
#       '2DA19B6C': 'Sorry, you have reached the quantity limit.  Please remove an item and try again. ',
#       '3534E689': 'Sorry, the product you have selected is not available at this time.',
#       '36A1E761': 'Sorry, we do not recognize the postal code you entered. Please try entering a different postal code.',
#       '3F7B9831': 'Sorry, we couldnâ\x80\x99t process your request because your browser has too many cookies. Clear your cookies and try again.',
#       '49780BED': 'Unable to reach Partner',
#       '4C5FB5DF': 'Maximum wishlist items exceeded.',
#       '4CB0532B': 'Sorry, the code entered is incorrect or invalid. Please try again, or enter another code.',
#       '6BD7E72A': 'Maximum wishlists per user exceeded.',
#       '7E977FCE': 'Sorry, the product you have selected is not available at this time.',
#       '840D5CFE': 'Country not currently supported',
#       '8B2AE0A4': 'The resource you requested does not exist.',
#       '9008921A': 'Product already added to wishlist.',
#       '97AE3B36': 'We are temporarily experiencing site issues. If unable to complete your purchase, please try again later.',
#       'A044DD39': 'Sorry, this code could not be applied. Please review the criteria to qualify for this promotion.',
#       'A553CABC': 'Your item total has exceeded the $1000.00 checkout limit. Please remove a few items and try again.',
#       'A954F3EE': 'Offer invalid',
#       'AA33FB74': 'Sorry, the product you have selected is not available at this time. ',
#       'ABB4C446': 'Sorry, you have reached the quantity limit. Please remove an item and try again. ',
#       'AE66C4E0': 'Sorry, this code is expired. Please try another code.',
#       'B2D8D9B5': 'Sorry, we had an issue with your request.  Please try again.',
#       'B9671077': 'Sorry, the product you have selected is not available at this time.',
#       'C4CD1584': 'Offer invalid',
#       'CF1877FC': 'Failed to make Reservation with Inventory System.',
#       'D2A6EE25': 'The given country code is not in the valid list.',
#       'D403D4AD ': 'One or More Items Unavailable. Please remove one or more items from your Bag, refresh and try again.',
#       'DAD5D797': 'Sorry, the product you have selected is not available at this time. ',
#       'E2E82F65': 'The field value is invalid',
#       'E37BAB4': 'Sorry, the price of the Gift Card is invalid. ',
#       'AE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'AT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'AU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'BE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'BG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'BR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'BR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'CA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'CH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'CL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'CN.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'CN.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'CN.NikeCom_PDP_Suffix': '-Nike China official website',
#       'CN.NikeCom_Suffix': '-Nike China official website',
#       'CN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'CZ.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'CZ.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'CZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'DE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com.  ',
#       'DE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'DE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'DK.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'DK.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'DK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'EG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'ES.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'ES.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'ES.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'FI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'FR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'FR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'FR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'GB.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'GB.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#       'GB.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'GR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'GR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'GR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'HR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'HU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'HU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'HU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'HurleyCom_Wall_SEO_Title_Suffix': '. Hurley.com',
#       'ID.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'IE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'IL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'IN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'IT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'IT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'IT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'JP.NikeCom_PDP': '',
#       'JP.NikeCom_PDP_Prefix': '',
#       'JP.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'JP.NikeCom_PDP_SEO_Desc2': 'Try-on within 30 days can be returned (except some products). [Free shipping for Nike members anytime]',
#       'JP.NikeCom_PDP_Suffix': '. Nike JP',
#       'JP.NikeCom_Prefix': '',
#       'JP.NikeCom_Suffix': '. Nike JP',
#       'JP.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'JP.NikeCom_Wall_SEO_Title_Suffix': '. Nike JP',
#       'KR.NikeCom_Suffix': '. Nike KR',
#       'KR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'KR.NikeCom_Wall_SEO_Title_Suffix': '. Nike KR',
#       'LU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'MA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'MX.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'MY.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'NL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'NL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'NL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'NO.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'NO.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'NO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'NZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#       'NikeCom_PDP_SEO_Keywords': '{Product_Full_Title}',
#       'NikeCom_PDP_SEO_Title': '{NikeCom_Prefix}{Product_Full_Title}{NikeCom_Suffix}',
#       'NikeCom_PDP_Suffix': '. Nike.com',
#       'NikeCom_Suffix': '. Nike.com',
#       'NikeCom_Wall_SEO_Keywords': '{TITLE}',
#       'NikeCom_Wall_SEO_Title': '{TITLE}',
#       'NikeCom_Wall_SEO_Title_Default': 'Products',
#       'NikeCom_Wall_SEO_Title_Suffix': '. Nike.com',
#       'PH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'PL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'PL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'PL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'PR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'PT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'PT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'PT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'RO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'RU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'RU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'RU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'SA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'SE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'SE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'SE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'SG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'SI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'SK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'TH.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'TH.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'TH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'TR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'TR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'TR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'TW.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'TW.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#       'TW.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'US.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#       'US.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#       'US.NikeCom_PDP_Suffix': '. Nike.com',
#       'US.NikeCom_Suffix': '. Nike.com',
#       'US.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'VN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#       'ZA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#       'DE.pdp_vat_message': '<div> Prices incl. VAT and plus delivery costs. You can find details of shipping costs <a href = "https://www.nike.com/help/a/shipping-delivery" class = "exp-pdp-tc-disclaimer-url "> here </a> </ div>',
#       'FR.pdp_recycle_message': 'This product may be recyclable. <a href="https://www.nike.com/fr/help/a/triman"> Learn more </a>',
#       'JP.tax_addendum': '(Tax Incl.)',
#       'US.pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#       'US.pdp_standardShipping': 'Standard / Arrives 2-4 Business Days',
#       'US.pdp_twoDayShipping': 'Two-Day / Arrives 2-3 Business Days',
#       'crossell.certona.all-nfl-teams-available': 'All NFL Teams Available',
#       'crossell.certona.buy-now': 'Buy Now',
#       'crossell.certona.cart_rr': 'You Might Also Like ',
#       'crossell.certona.color-plural': 'Colors',
#       'crossell.certona.color-singular': 'Color',
#       'crossell.certona.error4041_rr': 'TOP MENâ\x80\x99S PRODUCTS',
#       'crossell.certona.error4042_rr': 'TOP WOMENâ\x80\x99S PRODUCTS',
#       'crossell.certona.error4043_rr': 'TOP KIDSâ\x80\x99 PRODUCTS',
#       'crossell.certona.first-option': 'st',
#       'crossell.certona.inactivepdp1_rr': 'THESE POPULAR PRODUCTS MIGHT INTEREST YOU',
#       'crossell.certona.inactivepdp2_rr': 'CUSTOMIZE YOUR OWN WITH NIKEiD',
#       'crossell.certona.nflbuilderpdp_rr': 'GET THE ULTIMATE',
#       'crossell.certona.nfljerseykidspdp_rr': 'GET THE ULTIMATE',
#       'crossell.certona.nfljerseypdp_rr': 'GET THE ULTIMATE',
#       'crossell.certona.nflpdp_rr_suffix': 'HOOKUP',
#       'crossell.certona.nikeid-button': 'Shop All NIKEiD',
#       'crossell.certona.nikeid-text': 'Customize',
#       'crossell.certona.nikeid-url': 'http://www.nike.com/us/en_us/c/nikeid',
#       'crossell.certona.nikeidpdp_rr': 'You Might Also Like',
#       'crossell.certona.nosearch1_rr': 'SHOP ALL NIKEiD',
#       'crossell.certona.nosearch2_rr': '&nbsp;',
#       'crossell.certona.options': 'Options',
#       'crossell.certona.pdp.crosssell.nikeid': 'CUSTOMIZE',
#       'crossell.certona.player-plural': 'Players Available',
#       'crossell.certona.player-singular': 'Player Available',
#       'crossell.certona.playerNamesAvailable': 'Players available',
#       'crossell.certona.product_rr': 'You Might Also Like',
#       'crossell.certona.purchase_rr': '(purchase_rr) REPLACE THIS VALUE IN HtmlLocalValueBundle.properties!',
#       'crossell.certona.second-option': 'nd',
#       'crossell.certona.third-option': 'rd',
#       'crossell.certona.widths-available': 'Widths Available',
#       'pdp_3rdParty_Overseas_Transfer_PI': '3rd Party and Overseas Transfer of Personal Information',
#       'pdp_Collection_Use_PI': ' the collection and use of personal information',
#       'pdp_I_Agree_To': 'I agree to',
#       'pdp_NBYAvailableFor': 'Available For',
#       'pdp_NBYButtonTitle': 'Customize',
#       'pdp_NBYColorChipLabel': 'Design Your Own',
#       'pdp_NBYCustomDesignTab': 'Your Designs',
#       'pdp_NBYDesignTabs': 'Designs',
#       'pdp_NBYInspirationTab': 'Inspiration',
#       'pdp_NBYShareYourDesign': 'Share Your Design',
#       'pdp_NBYSoldOut': 'Sold Out',
#       'pdp_NBYYourDesignTxt': "Choose 'Customize' to add a design",
#       'pdp_NotifyMeButtonTitle': 'Notify Me',
#       'pdp_NotifyMeCancel': 'Cancel',
#       'pdp_NotifyMeDefaultEmailAddressText': 'Email Address',
#       'pdp_NotifyMeDone': 'Done',
#       'pdp_NotifyMeEmailOptInMessage': 'Send me news and offers from Nike',
#       'pdp_NotifyMeInvalidEmail': 'Please enter a valid email.',
#       'pdp_NotifyMeLegalText': '{privacyLinkText} and {termsOfUseLinkText}',
#       'pdp_NotifyMeModalBody': 'Get a one-time email alert the moment this product drops',
#       'pdp_NotifyMeModalLegalLinkJoin': 'and',
#       'pdp_NotifyMeModalPrivacyPolicyLinkText': 'Privacy Policy',
#       'pdp_NotifyMeModalTermsOfUseLinkText': 'Terms of Use',
#       'pdp_NotifyMeModalTitle': "Don't Miss Out",
#       'pdp_NotifyMeOk': 'Ok',
#       'pdp_NotifyMeOkModalTitle': "You're on the List",
#       'pdp_NotifyMeServerError': 'There was an error creating this notification.  Please try again later.',
#       'pdp_NotifyMeSubmit': 'Submit',
#       'pdp_NotifyMeThanks': "We'll send a one-time email to {email} when this product drops.",
#       'pdp_NotifyMe_AddAPhoneNumber': 'Add a phone number to get notified',
#       'pdp_NotifyMe_AddAnEmail': 'Add an email address to get notified',
#       'pdp_NotifyMe_And': 'and',
#       'pdp_NotifyMe_ConsentRefusal': 'You may refuse to consent, in which case you will not be able to receive information about Nike product releases. Nike is not responsible if the notification message fails to deliver.',
#       'pdp_NotifyMe_DefaultHeaderSubtitle': 'Get a one-time notification when this product drops.',
#       'pdp_NotifyMe_EmailHeaderSubtitle': 'Enter your email to receive a one-time notification',
#       'pdp_NotifyMe_EmailHeaderTitle': 'Add your email address.',
#       'pdp_NotifyMe_MemberEmailSendTo': 'Send an email to',
#       'pdp_NotifyMe_NotifyWithEmail': 'Notify with email',
#       'pdp_NotifyMe_NotifyWithSMS': 'Notify with SMS',
#       'pdp_NotifyMe_OverseasTransfer': 'I agree to <a href="{infoTransferLink}">3rd Party and Overseas Transfer of Personal Information</a>',
#       'pdp_NotifyMe_PersonalInfo': 'I agree to the <a href="{infoCollectionLink}">collection and use of personal information</a>',
#       'pdp_NotifyMe_PrivacyPolicyLegal': 'I agree to Nikeâ\x80\x99s <a href="{privacyPolicyLink}">Privacy Policy</a> and <a href="{termsOfUseLink}">Terms of Use</a>',
#       'pdp_NotifyMe_SMSHeaderTitle': 'Add your mobile phone number.',
#       'pdp_NotifyMe_SendEmailTo': "We'll send an email to",
#       'pdp_NotifyMe_SendSMSTo': 'Weâ\x80\x99ll send an SMS to',
#       'pdp_NotifyMe_TermsOfUseLegal': 'I agree to Nikeâ\x80\x99s <a href="{termsOfUseLink}">Terms of Use</a>',
#       'pdp_NotifyMe_YouAreAllSet': "You're all set!",
#       'pdp_NotifyMe_title': "Don't Miss Out",
#       'pdp_PageNotFoundMessage': 'WE CANâ\x80\x99T FIND THE PAGE YOU ARE LOOKING FOR',
#       'pdp_RFYNotAuthorized': 'Sorry, this product is not reserved for you.',
#       'pdp_RFYProductExpiredOn': 'Expired on {expiredOn}',
#       'pdp_RFYProductRedeemedOn': 'Redeemed on {redeemedOn}',
#       'pdp_RFYRedeemProduct': 'Redeem',
#       'pdp_RFYSubtitle': 'Reserved for You',
#       'pdp_SeeMoreProducts': 'See More',
#       'pdp_SimilarStyles': 'Similar Styles',
#       'pdp_a11y_aria_choose_a_style_color': 'Choose a Style Color',
#       'pdp_a11y_avg_star_rating': 'Average Rating {rating} of {starCount}',
#       'pdp_addToCart': 'Add to Bag',
#       'pdp_addToCartErrorLabel': 'Error:',
#       'pdp_addToCartErrorText': 'This request timed out, please try again',
#       'pdp_addToWishlist': 'Add to Favorites',
#       'pdp_addedToCart': 'Added to Bag',
#       'pdp_addedToWishlist': 'Added to Favorites',
#       'pdp_additionalInfo': 'More Info',
#       'pdp_allProductsSoldOutMessage': 'This product is currently unavailable',
#       'pdp_also_includes_all_applicable_duties': 'Also includes all applicable duties',
#       'pdp_arrivesDate': 'Arrives',
#       'pdp_back': 'Back',
#       'pdp_bopisShipping': 'Shipping',
#       'pdp_button_close': 'Close',
#       'pdp_cartAndCheckout': 'Bag & Checkout',
#       'pdp_cartQuantity': 'Qty 1',
#       'pdp_check_back_soon_label': 'Check back soon.',
#       'pdp_check_back_soon_message': 'Unfortunately we are not able to fulfill orders in this country at this time. Please check back for future availability. ',
#       'pdp_checkout': 'Checkout',
#       'pdp_chooseSize': 'Select Size',
#       'pdp_closeDialogButtonLabel': 'Close this dialog window',
#       'pdp_cloudAddToCartError': 'An error has occurred: ',
#       'pdp_comingSoon': 'Coming Soon',
#       'pdp_continueShopping': 'Continue Shopping',
#       'pdp_cookie_banner_message': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {PrivacyPolicy}. You can adjust your preferences in {CookieSettings}.',
#       'pdp_cookie_settings': 'Cookie Settings',
#       'pdp_copyLink': 'Copy Link',
#       'pdp_copyLinkConfirmation': 'Copied',
#       'pdp_countdownDay': 'd',
#       'pdp_countdownHour': 'h',
#       'pdp_countdownMinute': 'm',
#       'pdp_countdownSecond': 's',
#       'pdp_country_of_origin': 'Country/Region of Origin:',
#       'pdp_currentlyUnavailable': 'Currently Unavailable',
#       'pdp_default_title': 'Nike Store. Shoes, Clothing & Gear.',
#       'pdp_estimateShippingTime': 'Estimate Shipping Time',
#       'pdp_fasterShippingOptions': 'Faster Shipping options may be available',
#       'pdp_feedbackText': 'Your input will help us create an even better shopping experience for you.',
#       'pdp_fitPrivacyHeader': 'Privacy',
#       'pdp_fitPrivacyModalCloseBtn': 'Close',
#       'pdp_fitPrivacyModalContent': '<h1>Your Privacy</h1>\n<ul>\n<li>Nike partners with <a href="https://www.fitanalytics.com/" target="_blank"><strong>Fit Analytics</strong></a> to recommend sizes on <a href="https://www.nike.com/" target="_blank">Nike.com</a>.</li><li>To help make those recommendations, <strong>Nike uses performance</strong> cookies and the information you provide.</li><li>Nike shares <strong>deidentified information</strong> with Fit Analytics to help improve size recommendations.</li><li>Nike only has access to general Fit Analytics statistics.</li>\n</ul>',
#       'pdp_fitSize': 'Your Nike Fit is',
#       'pdp_fit_opinion_runs_big': 'Runs Big',
#       'pdp_fit_opinion_runs_consistently_big': 'Customers who reviewed this product say it runs big.',
#       'pdp_fit_opinion_runs_consistently_small': 'Customers who reviewed this product say it runs small.',
#       'pdp_fit_opinion_runs_small': 'Runs Small',
#       'pdp_fit_opinion_runs_sometimes_big': 'Customers who reviewed this product say it runs slightly big.',
#       'pdp_fit_opinion_runs_sometimes_small': 'Customers who reviewed this product say it runs slightly small.',
#       'pdp_fit_opinion_runs_true': 'Customers who reviewed this product say it runs true to size.',
#       'pdp_freeShipping': 'Free Shipping with Nike Membership',
#       'pdp_gcChooseAnAmount': 'Choose an amount',
#       'pdp_gcColorwayTitle': 'Choose a design',
#       'pdp_gcCustomAmount': 'Custom amount:',
#       'pdp_gcCustomAmountMaxValueError': 'Gift card amount cannot exceed {maxValue}',
#       'pdp_gcCustomAmountMinValueError': 'Gift card amount must be at least {minValue}',
#       'pdp_gcCustomAmountRestrictedCharacterError': 'This contains a restricted character, please choose another.',
#       'pdp_gcDeliveryDetailsLink': 'Enter address',
#       'pdp_gcDeliveryDetailsText': "Let us know where it's going. ",
#       'pdp_gcDeliveryDetailsTitle': 'Add recipient delivery details',
#       'pdp_gcDeliveryMethod': 'Choose a delivery method',
#       'pdp_gcDeliveryMethodEmail': 'Email',
#       'pdp_gcDeliveryMethodMail': 'Mail',
#       'pdp_gcDigitalAddressEditButton': 'Edit',
#       'pdp_gcEmailInput': 'Email',
#       'pdp_gcLargeOrderButton': 'Need a Larger Order?',
#       'pdp_gcLargeOrderModalEmailLink': 'giftcards@nike.com',
#       'pdp_gcLargeOrderModalMainText': 'Just e-mail {emailLink} for more information or call Nike directly at 1-877-220-6453 for assistance. You will receive a reply or call-back during Nike corporate business hours (Monday through Friday, 8 AM â\x80\x93 5 PM Pacific Time, excluding holiday). Please do not send credit card information over email.',
#       'pdp_gcLargeOrderModalSubTitle': 'Need to order more than 10 cards or to put in an order totaling more than $5,000?',
#       'pdp_gcLargeOrderModalTitle': 'Need to Place a Larger Order?',
#       'pdp_gcNoPOBox': 'We do not deliver to P.O. Boxes',
#       'pdp_gcOptionalMessageErrorText': 'Your message is invalid, please try again.',
#       'pdp_gcOptionalMessageLabel': 'Add an optional message',
#       'pdp_gcOptionalMessageText': 'Enter a personalized message for the recipient.',
#       'pdp_gcQuantity': 'Quantity',
#       'pdp_gcRecipientAddress': 'Address',
#       'pdp_gcRecipientAddress2': 'Add Company, C/O, Apt, Suite, Unit (Optional)',
#       'pdp_gcRecipientAddressError': "Please enter recipient's address.",
#       'pdp_gcRecipientCity': 'City',
#       'pdp_gcRecipientCityError': "Please enter recipient's city.",
#       'pdp_gcRecipientEmailAddress': 'Email',
#       'pdp_gcRecipientEmailAddressError': 'Please enter a valid email address.',
#       'pdp_gcRecipientEmailError': 'Please enter a valid email address.',
#       'pdp_gcRecipientFirstName': 'First Name',
#       'pdp_gcRecipientFirstNameError': "Please enter recipient's first name.",
#       'pdp_gcRecipientLastName': 'Last Name',
#       'pdp_gcRecipientLastNameError': "Please enter recipient's last name.",
#       'pdp_gcRecipientState': 'State',
#       'pdp_gcRecipientStateError': "Please select recipient's state.",
#       'pdp_gcRecipientZip': 'Postal Code',
#       'pdp_gcRecipientZipError': 'Please enter a valid zip code.',
#       'pdp_gcStateDropdownTitle': 'Select a State',
#       'pdp_gcTCLink': 'Gift Card Terms and Conditions',
#       'pdp_gender_men': 'Men',
#       'pdp_gender_women': 'Women',
#       'pdp_gift_description': 'Send as an E-Gift',
#       'pdp_gift_link_message': 'Send Now',
#       'pdp_gift_message': 'You choose the gift, they choose the size and color.',
#       'pdp_gift_tooltip': "Send this item instantly, by email. They'll choose size and color, or use the gift value towards another Nike.com purchase.",
#       'pdp_helpUsImproveYourExperience': 'Help Us Improve Your Experience',
#       'pdp_highly_rated': 'Highly Rated',
#       'pdp_howItFits': 'How it Fits',
#       'pdp_incl_of_taxes': 'incl. of taxes',
#       'pdp_include_of_taxes_and_duties': 'incl. of taxes and duties',
#       'pdp_just_a_few_left_order_soon': 'Just a few left. Order soon.',
#       'pdp_just_a_few_left_order_soon_kr': 'Almost sold out. Order soon.',
#       'pdp_keepShopping': 'Keep Shopping',
#       'pdp_klarna_message': 'Buy now, pay in 3 installments with <span>Klarna</span>',
#       'pdp_klarna_message_short': '<span>Klarna</span> Available at checkout.',
#       'pdp_launchAvailableDate': 'Available {Launch_Date} at {Launch_Time}',
#       'pdp_launchBuyCTA': 'Buy',
#       'pdp_launchBuyableGuestIntro': 'Only Nike Members get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#       'pdp_launchBuyableMemberIntro': 'Only Nike Members like you get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#       'pdp_launchCSGuestIntro': "Create or sign in to your free Nike Member account for a chance to buy this product the moment it's released. {learnMoreButtonText}",
#       'pdp_launchCSMemberIntro': "Nike Members like you are the only ones who have a chance to purchase this product when it's released. {learnMoreButtonText}",
#       'pdp_launchCheckoutErrorBody': 'There was a problem processing your payment.  Check your payment information and try again.',
#       'pdp_launchCheckoutErrorTitle': "Let's try this again.",
#       'pdp_launchCheckoutNotLoggedIn': 'Your session has expired.  Please refresh and login to continue.',
#       'pdp_launchCheckoutNumberNotVerified': 'Your session has expired.  Please refresh and login to continue.',
#       'pdp_launchComingSoon': 'Coming Soon',
#       'pdp_launchComingSoonStepOne': '1. Sign in to your Nike Member account or {joinButtonText}',
#       'pdp_launchComingSoonStepThree': '3. Verify your mobile number in account settings.',
#       'pdp_launchComingSoonStepTwo': '2. Confirm your payment info is updated. ',
#       'pdp_launchDismissModalButton': 'Continue Shopping',
#       'pdp_launchFirstParagraphComingSoon': "Introducing Line Checkout. Come back after a Product is available to get in line. If your turn comes up, we'll complete your order. Before getting in line, make sure you:",
#       'pdp_launchFirstParagraphGetInLine': "Line Checkout is the only way to buy some of our most popular products - like this one. Once you're in line and your turn comes up, we'll complete your order. ",
#       'pdp_launchGetInLine': 'Get in Line',
#       'pdp_launchGetInLineTitle': 'Get in Line. Get the goods.',
#       'pdp_launchInLineBodyModal': "If your turn comes up, we'll complete your order. ",
#       'pdp_launchJoinForFreeButton': 'join for free.',
#       'pdp_launchLMModalBePreparedBullet': 'Be prepared',
#       'pdp_launchLMModalBePreparedSubBullet': "Make sure you're signed in to your Nike Member account and ready when the product launches.",
#       'pdp_launchLMModalContinueShoppingCTA': 'Continue Shopping',
#       'pdp_launchLMModalFirstTitle': 'How Line Checkout Works',
#       'pdp_launchLMModalGuestJoinBullet': 'Become a Nike Member',
#       'pdp_launchLMModalGuestJoinSubBullet': 'Line Checkout is available only to Nike Members. Not a Member? {JoinForFree}',
#       'pdp_launchLMModalJoinForFree': 'Join for Free',
#       'pdp_launchLMModalJoinNikePlusCTA': 'Become a Nike Member',
#       'pdp_launchLMModalLineOne': 'To make sure Nike Members have an equal chance to purchase high-demand items on our site, we use a Line Checkout system.',
#       'pdp_launchLMModalLineThree': 'Wait times vary based on demand. Limit one item per Nike Member.',
#       'pdp_launchLMModalLineTwo': "If your chosen size and color is available when you're selected, we'll process your order. If your selection sells out before that, we'll let you know.",
#       'pdp_launchLMModalSecondTitle': 'Improve Your Odds',
#       'pdp_launchLMModalSecondTitleSubtitle': "Here's how to make your Line Checkout experience as easy as possible:",
#       'pdp_launchLMModalUpdateProfileBullet': 'Update your Nike Member profile',
#       'pdp_launchLMModalUpdateProfileSubBullet': 'Make sure your shipping and payment information is current.',
#       'pdp_launchLMModalUpdateSettingsCTA': 'Update Account Settings',
#       'pdp_launchLMModalVerifyMobileBullet': 'Verify your mobile number',
#       'pdp_launchLMModalVerifyMobileSubBullet': 'This layer of added security helps keep the Line Checkout process fair.',
#       'pdp_launchLearnMoreButtonText': 'Learn more',
#       'pdp_launchNonWinnerBody': "Thank you for entering for the Nike Air VaporMax. Unfortunately, it didn't work out this time.",
#       'pdp_launchNonWinnerTitle': "Didn't Get 'Em",
#       'pdp_launchNotifyYou': 'We will notify you in a moment whether you get a pair or not.',
#       'pdp_launchPending': "You're in line",
#       'pdp_launchSessionExpiredTitle': 'Session expired',
#       'pdp_launchSoldOut': 'Sold Out',
#       'pdp_launchUnavailableTitle': 'Product unavailable',
#       'pdp_launchWinnerBody': 'Congratulations on your purchase. A confirmation email is on the way.',
#       'pdp_launchWinnerTitle': 'You Got It',
#       'pdp_launchYouAreInLine': "You're Currently In Line",
#       'pdp_launchYouAreInLineBody': 'We will notify you in a moment whether you get a pair or not.',
#       'pdp_launch_coming_soon_title': 'Get in Line. Get the Goods.',
#       'pdp_launch_entered': 'Launch Entered',
#       'pdp_launch_non_winner': 'Non winner',
#       'pdp_launch_pending': 'Pending...',
#       'pdp_launch_purchased': 'Purchased',
#       'pdp_launch_unavailable': 'This product is no longer available.',
#       'pdp_learnMore': 'Learn More',
#       'pdp_limitedColorBadge': 'Limited Color',
#       'pdp_limitedTimeBadge': 'Seasonal (Limited Time Color)',
#       'pdp_low_inventory_order_soon': 'Low inventory! Order soon.',
#       'pdp_low_stock_message': 'Limited stock in selected size',
#       'pdp_manufacturerAccordionCopy': 'Declaration of Importer: Direct import by the individual customer<br><br>Marketed by: Nike Global Trading B.V. Singapore Branch, 30 Pasir Panjang Road, #10-31/32, Mapletree Business City, Singapore 117 440',
#       'pdp_manufacturerAccordionHeader': 'Product Information',
#       'pdp_member_exclusive_subtitle': 'Member Exclusive',
#       'pdp_member_exclusive_subtitle_na': 'Member Access',
#       'pdp_member_exclusive_support_message': 'Sign in or create a free Nike Member account to get this product.',
#       'pdp_member_exclusive_support_message_title': 'It only takes a Nike Membership',
#       'pdp_minicart_upsell_recommendations_title': 'Frequently Bought Together',
#       'pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#       'pdp_no_return_text': 'This product is customized so the order cannot be cancelled 30 minutes after submit. Nike By You customized products do not apply to no reason return or exchange policy.',
#       'pdp_notAvailableForPickup': 'This item is not available for pickup',
#       'pdp_notifyMeSurveyText': 'If given the opportunity to be notified if this color becomes available, would you be interested?',
#       'pdp_numeric_range_separator': 'â\x80\x93',
#       'pdp_ok': 'OK',
#       'pdp_one_size': 'ONE SIZE',
#       'pdp_one_size_low_stock_message': 'Limited stock',
#       'pdp_pageNotFoundHeader': 'TIME OUT',
#       'pdp_percentageOff': 'off',
#       'pdp_pickUp': 'Free Pickup',
#       'pdp_pleaseSelectASize': 'Please select a size.',
#       'pdp_pre_order': 'Pre-Order',
#       'pdp_pre_order_get_it_first': 'Get it First:',
# ...
#          'type': 'card',
#          'version': '1633365089421',
#          'properties': {'copyId': 'a253dd95d0bae61b5d9ca9e207e32247ceb15df6',
#           'product': [],
#           'richTextLinks': [],
#           'custom': {},
#           'subtitle': '',
#           'colorTheme': 'dark',
#           'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#            'modifiedDate': '2021-10-04T16:31:29.405Z',
#            'exposeTemplate': False,
#            'properties': {'actions': {}},
#            'resourceType': 'content/style'},
#           'body': '<p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p>',
#           'title': 'Flexibility for Speed',
#           'actions': []}},
#         {'analytics': {'hashKey': 'add5b12590aa45c846ef8ab48ffb89ba2ee497d861dfff6291162efb2625bbc7'},
#          'subType': 'image',
#          'id': '072fa761-6350-45a0-9a85-88fad4ea24e7',
#          'type': 'card',
#          'version': '1633365102718',
#          'properties': {'portraitId': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#           'squarishURL': '',
#           'landscapeId': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#           'altText': '',
#           'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg',
#           'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg',
#           'portrait': {'id': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#            'type': 'product',
#            'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg'},
#           'title': '',
#           'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#           'richTextLinks': [],
#           'subtitle': '',
#           'colorTheme': 'dark',
#           'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#            'modifiedDate': '2021-10-04T16:31:42.718Z',
#            'exposeTemplate': False,
#            'resourceType': 'content/style'},
#           'actions': [],
#           'landscape': {'id': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#            'type': 'product',
#            'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg'}}},
#         {'analytics': {'hashKey': '19214ec1853bfd1aa0b5986f20c9f7bc1291c2d42405b07ae9d74bc303bb711d'},
#          'subType': 'text',
#          'id': '6de4f79e-1e52-4c01-a9d7-a21e9b8cb30b',
#          'type': 'card',
#          'version': '1633365097774',
#          'properties': {'copyId': 'd059f6db5527b41ea4abe44d472b2f9577221c23',
#           'product': [],
#           'richTextLinks': [],
#           'custom': {},
#           'subtitle': '',
#           'colorTheme': 'dark',
#           'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#            'modifiedDate': '2021-10-04T16:31:37.709Z',
#            'exposeTemplate': False,
#            'properties': {'actions': {}},
#            'resourceType': 'content/style'},
#           'body': '<p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p>',
#           'title': 'Stability for Strength',
#           'actions': []}}],
#        'layoutCards': [],
#        'firstImageUrl': 'https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png',
#        'firstImageAltText': 'Nike Free Metcon 4 Training Shoes',
#        'sustainabilityMessage': [],
#        'descriptionPreviewBullets': '',
#        'moreInfoMessages': [],
#        'sizeFitMessages': [],
#        'hubMessages': [],
#        'language': 'en',
#        'marketplace': 'US',
#        'availableSkus': [{'id': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da',
#          'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#          'resourceType': 'availableSkus',
#          'links': {'self': {'ref': '/deliver/available_skus/v1/ef237b73-2633-56fe-8ebd-fbc2258fa8da'}},
#          'available': True,
#          'level': 'LOW',
#          'skuId': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da'},
#         {'id': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f',
#          'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#          'resourceType': 'availableSkus',
#          'links': {'self': {'ref': '/deliver/available_skus/v1/2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'}},
#          'available': True,
#          'level': 'LOW',
#          'skuId': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'},
#         {'id': '9fd7e097-24db-5c33-b660-d300c3f6579c',
#          'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#          'resourceType': 'availableSkus',
#          'links': {'self': {'ref': '/deliver/available_skus/v1/9fd7e097-24db-5c33-b660-d300c3f6579c'}},
#          'available': True,
#          'level': 'LOW',
#          'skuId': '9fd7e097-24db-5c33-b660-d300c3f6579c'},
#         {'id': 'da0611fb-2af5-53fa-89c3-8baea350977b',
#          'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#          'resourceType': 'availableSkus',
#          'links': {'self': {'ref': '/deliver/available_skus/v1/da0611fb-2af5-53fa-89c3-8baea350977b'}},
#          'available': True,
#          'level': 'LOW',
#          'skuId': 'da0611fb-2af5-53fa-89c3-8baea350977b'},
#         {'id': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca',
#          'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#          'resourceType': 'availableSkus',
#          'links': {'self': {'ref': '/deliver/available_skus/v1/4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}},
#          'available': True,
#          'level': 'LOW',
#          'skuId': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}],
#        'publishType': 'FLOW',
#        'isLaunchView': False,
#        'launchView': None,
#        'isForNumberOfImagesABTesting': False,
#        'isMinimumAdvertisedPrice': False,
#        'collectionTermIds': ['c05bedd9-29d3-4e45-8c62-c463f9c5958f',
#         '1a70e9af-aea9-4a39-9773-fa6ced97c58b',
#         '65838112-1f4d-48a7-9b2f-1e8736c4cdcc',
#         'a49f8e69-ff9c-4356-89d8-d4a098fc02c2',
#         'e4e46ee6-496f-491a-8771-1a677eefee3a',
#         '94d2c954-14cd-4784-96ec-b02c950d2872',
#         '62f3c208-e1a3-45c0-9e70-a90be4e276f1',
#         'b9cefedb-1dd5-42dc-af13-939a240d4bb8',
#         '4be7e5d7-7e5b-460d-b3d7-41396b3fa985'],
#        'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#         '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#         '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#         'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#         '292efae5-2d9a-44a3-a529-cda684a47c44',
#         'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#         '7702dda3-62ca-3410-b4f3-97025be1089d',
#         '68a7b17f-291f-41f8-bf04-5e2fbe878d9b',
#         '05392778-fff6-4fa0-a375-2506d27f009e',
#         '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#         '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#         'b942d0ac-4887-4a8f-b914-d82a6181014f',
#         '67063381-90eb-4763-8f87-acc30b392f38',
#         '699b34a6-1950-3458-8322-910b695fccb7',
#         '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#         '10f9af5a-58d2-480a-a72d-5a65bd374850',
#         '0a937561-8633-3ea1-8ae3-8509f50f4127',
#         '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#         '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#         '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#         '539c6c43-d060-30b0-be5b-47c47f7c7658',
#         'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#         '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#         '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#         '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#         '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#         '2057952b-1a72-368e-b4b1-f67091ff1799',
#         '6e7e4809-fccb-4e82-8a7b-047125398076',
#         '9b0e77d0-aec5-4f4b-b8de-acb7a82e396d',
#         '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#         '7abdd901-856d-3601-94bf-14313cee8354',
#         '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#         'b5cd158b-b105-490c-b777-652943e742b0',
#         'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#         '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#         '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#         '16633190-45e5-4830-a068-232ac7aea82c',
#         '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#         '7817e756-7721-4cfb-b404-04df79c685e4',
#         'c29a0094-d302-4b7a-b5f0-73e46f772348'],
#        'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#        'catalogId': '1',
#        'selectedSkuId': {},
#        'sizeAndFitDescription': '',
#        'exclusiveAccess': False,
#        'notifyMeIndicator': False,
#        'promoExclusionAccess': False,
#        'useFeedsPromoExclusionMessage': False,
#        'jerseyIdPathName': '',
#        'nbyHubMessages': [],
#        'state': 'IN_STOCK'}}},
#     'NikeId': {'nikeIdPrebuildSuggestion': None,
#      'NBYBuilderModalOpen': False,
#      'metricId': '',
#      'itemId': '',
#      'gender': '',
#      'sizing': {},
#      'fit': '',
#      'showNBYBuyingTools': False,
#      'error': None,
#      'availability': False,
#      'async': {'prebuildSuggestions': False},
#      'isAvailable': True},
#     'NotQuiteReady': {'notQuiteReadyEvts': []},
#     'Fit': {'fitSize': '', 'localizedFitSize': '', 'isFitSizeSet': False},
#     'EDD': {'estimatedDeliveryData': None},
#     'User': {'user': {}, 'isSwoosh': False, 'initialized': False},
#     'FitAnalytics': {'fitAnalyticsRecommendedSize': None,
#      'fitAnalyticsFindMySizeClicked': False},
#     'Cart': {'isSizeSelectError': False,
#      'cartProduct': {},
#      'cartSku': {},
#      'wishlistProduct': {},
#      'wishlistSku': {},
#      'isWishlistConfirmationModalOpen': False,
#      'async': {},
#      'payload': {},
#      'cartError': []},
#     'Config': {'name': 'pdp',
#      'domain': 'dotcom',
#      'division': 'commerce',
#      'platform': 'cloud',
#      'version': '1.0.0',
#      'facebookAppId': '1397260880304609',
#      'channelId': 'd9a5bc42-4b9c-4976-858a-f159cf99c647',
#      'env': 'prod',
#      'dark': False,
#      'preview': False,
#      'branchIOKey': 'key_test_dcy0gJ0f2U1NBELEQXq8ElcgvumigPUu',
#      'defaultStyleColor': '724010-017',
#      'productStateOverride': None,
#      'gqlHash': '4bc133d8e69ba0dd907158346fed7f2e',
#      'flags': {'abTests': True,
#       'animateAccordionPanels': False,
#       'cookieSettings': False,
#       'cookieSettingsBanner': False,
#       'cutOverPdpToSegment': True,
#       'debug': False,
#       'enableMAP': True,
#       'filterByNikeDotComChannel': True,
#       'globalNavUseGeoPrivacy': True,
#       'gridRecommendations': True,
#       'hideBuyingTools': False,
#       'incentivizedReviewsMessageNA': True,
#       'incentivizedReviewsMessage': False,
#       'includeFacebookAppId': True,
#       'logoutShouldClearCart': True,
#       'lowInventoryMessage': True,
#       'loadWebShell': True,
#       'loadWebShellOnWall': False,
#       'loadForterScript': True,
#       'loadStylitics': True,
#       'notifyMe': True,
#       'showAvailabilityDate': False,
#       'recommendations': True,
#       'reserveForYou': True,
#       'sendPIDsOnWall': True,
#       'shareNBY': True,
#       'showCNNewYearsLink': False,
#       'showCgc': True,
#       'showColorWayPicker': True,
#       'showEGift': True,
#       'showElevatedContent': True,
#       'showFit': True,
#       'showGeoMismatch': True,
#       'showGiftCardMessage': True,
#       'showGiftCardTypeLink': True,
#       'showGiftCards': True,
#       'showJerseyId': True,
#       'showKlarnaPayMessage': True,
#       'showKlarnaPayLaterMessage': False,
#       'showLargeGiftCardOrder': True,
#       'showLaunchDebug': False,
#       'showLaunchProduct': True,
#       'showLeftHandNavCategories': True,
#       'showMobileWriteReview': True,
#       'showMoreInfo': True,
#       'showNBY': True,
#       'showNBYMessageHub': True,
#       'showNikeId': True,
#       'showOmni': False,
#       'showPhysicalGiftCards': True,
#       'showPromoBanner': True,
#       'showPromoMsg': True,
#       'showPromoExclusionMsg': True,
#       'showFeedsPromoExclusionMessage': False,
#       'showReadMore': True,
#       'showRelatedCategories': True,
#       'showReviews': True,
#       'showSEOCopy': False,
#       'showSinglesDaySalesLink': False,
#       'showSizeAndFit': True,
#       'showSizeCalculator': False,
#       'showSocialLinksNBY': True,
#       'showUniteTimers': False,
#       'showWidthSelector': True,
#       'showWishlist': True,
#       'skipPercentOff': False,
#       'skipSustainability': False,
#       'skipSegmentDupedEvents': True,
#       'swooshEligibleGeo': True,
#       'useBounceExchange': False,
#       'useDotcomNav': True,
#       'useDotcomNavESI': True,
#       'useExclusiveAccess': True,
#       'useFeedsMoreInfoMessage': False,
#       'useFeedsSizeFitMessage': False,
#       'useFeedsSustainabilityMessage': True,
#       'useMAPCollection': True,
#       'useNBYCloudUrl': True,
#       'useNBYImageService': True,
#       'useNeo': True,
#       'useNewRelic': True,
#       'useOptimizelyX': True,
#       'usePersonalizedNullSearch': False,
#       'useRollupKey': True,
#       'useSentryIO': False,
#       'useServiceCanonicalUrl': True,
#       'useSwitchboardRecommendations': False,
#       'useTTReviews': True,
#       'useUniteStaging': False,
#       'enableNikeShopModals': True,
#       'showElevatedCarousel': True,
#       'hideEDDFasterShippingOptionMsg': False,
#       'showEstimatedDeliveryDate': False,
#       'showEstimatedDeliveryDateAndPickup': True,
#       'showPickupLocation': True,
#       'showEDDAndBopisABTesting': False,
#       'wallFavorites': False,
#       'wallFiltersBtnFilterLabel': True,
#       'wallImpressions': True,
#       'wallNoResultsCarousel': True,
#       'useTTV5Reviews': True,
#       'useNotifyMeV2': False,
#       'isZoomEnabled': False},
#      'assetPaths': {},
#      'recommendationsScheme': 'product_rr',
#      'cacheDuration': {'404': 60,
#       'default': 900,
#       'launch': 900,
#       'pdp': 900,
#       'perf': 900,
#       'wall': 300},
#      'globalNavConfig': {'header': 'commerce-header',
#       'footer': 'footer',
#       'shared': 'shared',
#       'testHeader': 'commerce-header',
#       'testFooter': 'footer',
#       'testShared': 'shared'},
#      'optimizelyEndpoint': '//www.nike.com/assets/vendor/optimizely/prod/5aUCtZvFuDLjvdqdf2w53M.json',
#      'turnToConfig': {'turnToFetchTimeout': 350,
#       'turnToAuthBucket': 'shared/turnto/prod-auth-keys'},
#      'exp': '2011'},
#     'Console': {'providers': []},
#     'CrossSell': {'products': [], 'error': None, 'async': {'products': False}},
#     'Auth': {'bearer': ''},
#     'Experiments': {'activeExperiments': {}, 'forcedExperiments': {}},
#     'Launch': {'launchCheckoutModalOpen': False,
#      'launchCheckoutServices': 'launch-checkout'},
#     'MAPProducts': {'products': {}},
#     'Privacy': {'areSocialCookiesAllowed': False,
#      'arePerformanceCookiesAllowed': False,
#      'geoLoc': None,
#      'hasEUCookie': False},
#     'Device': {'breakpointMatched': False, 'deviceWidth': 'sm'},
#     'Overlays': [],
#     'Common': {'channel': 'NIKE',
#      'connection': {'saveData': False, 'effectiveType': None},
#      'globalHeaderFixedHeight': 60,
#      'globalHeaderHeight': 96,
#      'pageType': 'pdp',
#      'routes': [],
#      'siteHost': 'https://www.nike.com'},
#     'META': {'commit': ''},
#     'NOTIFY_ME': {'isNotifyMeModalOpen': False,
#      'page': 'default',
#      'journey': '',
#      'isNotifyMeSMSOpen': False,
#      'isNotifyMeEmailOpen': False,
#      'emailJourneyCompleted': False,
#      'smsJourneyCompleted': False,
#      'email': '',
#      'sms': ''},
#     'intl': {}}},
#   '__N_SSP': True},
#  'page': '/t/[slug]',
#  'query': {'nikemt': 'true',
#   'cp': '38647199687_search_|PRODUCT_GROUP|GOOGLE|71700000101429394|GG_Evergreen_Shopping_Shoes_AllShoes||c',
#   'exp': '2011',
#   'gclsrc': ['aw.ds', 'aw.ds'],
#   'gclid': 'CjwKCAiAkrWdBhBkEiwAZ9cdcG7uW3qP3yZZIUe8oysRg4raRJLgiCGHfPXxeNCBlp908KAIcQgWcxoCF1kQAvD_BwE',
#   'slug': 'free-metcon-4-amp-training-shoes-KX41Bv'},
#  'buildId': 'VeThxACTHA_DlaXnncGGj',
#  'assetPrefix': '//www.nike.com/assets/experience/dotcom-pdp/pdp-next',
#  'isFallback': False,
#  'gssp': True,
#  'customServer': True}

# %% [markdown]
# # Now we are gonna work with the new json object to access data and our pictures

# %% [markdown]
# We are going to be hashing the keys and accessing the data one by one. The step by steps will show us printing the data then checking for the extra keys inside the data and accesing those.

# %%
print(json_object.keys())
# Out:
# dict_keys(['props', 'page', 'query', 'buildId', 'assetPrefix', 'isFallback', 'gssp', 'customServer'])

# %%
# for i in json_object.keys():
#     print(i,"\n\n",json_object[i], "\n\n\n\n\n")

# %%
json_object['props']
# Out:
# {'pageProps': {'initialState': {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#      'titleTemplate': '%s',
#      'meta': [{'name': 'description',
#        'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#       {'name': 'keywords', 'content': 'Nike Free Metcon 4 Training Shoes'},
#       {'name': 'robots', 'content': 'index, follow'},
#       {'property': 'og:title',
#        'content': 'Nike Free Metcon 4 Training Shoes. Nike.com'},
#       {'property': 'og:description',
#        'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#       {'property': 'og:type', 'content': 'website'},
#       {'property': 'og:url',
#        'content': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'},
#       {'property': 'og:image',
#        'content': 'https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png'},
#       {'property': 'og:locale', 'content': 'en_US'},
#       {'property': 'og:site_name', 'content': 'Nike.com'},
#       {'property': 'og:price:currency', 'content': 'USD'},
#       {'property': 'og:price:amount', 'content': 120},
#       {'name': 'branch:deeplink:$deeplink_path',
#        'content': 'x-callback-url/product-details?style-color=CT3886-004'},
#       {'property': 'fb:app_id', 'content': '1397260880304609'}],
#      'title': 'Nike Free Metcon 4 Training Shoes. Nike.com',
#      'link': [{'rel': 'canonical',
#        'href': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'}]}},
#    'reviews': {'country': 'us',
#     'apiversion': None,
#     'sorts': {'SubmissionTime': True},
#     'productStyleCode': 'CT3886',
#     'total': 0,
#     'averageRating': 0,
#     'recommendedCount': 0,
#     'reviews': [],
#     'dimensions': [],
#     'reviewsMap': {},
#     'initialFetched': False,
#     'initialFetching': False,
#     'initialFetchError': False,
#     'fetched': False,
#     'fetching': False,
#     'fetchError': False,
#     'positiveFeedbackSubmitting': {},
#     'positiveFeedbackSubmitted': {},
#     'positiveFeedbackSubmitError': {},
#     'negativeFeedbackSubmitting': {},
#     'negativeFeedbackSubmitted': {},
#     'negativeFeedbackSubmitError': {},
#     'inappropriateFeedbackSubmitting': {},
#     'inappropriateFeedbackSubmitted': {},
#     'inappropriateFeedbackSubmitError': {},
#     'isDrawerOpen': False,
#     'reviewsDrawerType': 'view',
#     'currentReviewId': '',
#     'summary': {'total': 0,
#      'limit': 0,
#      'averageRating': 0,
#      'recommendedCount': 0,
#      'reviews': [],
#      'secondaryRatingsOrder': [],
#      'bestRating': 5,
#      'worstRating': 1},
#     'vendor': 'VENDOR/TURN_TO',
#     'serverSideFetched': False,
#     'serverSideFetching': True,
#     'serverSideFetchError': False},
#    'localization': {'urlParam': 'en',
#     'language': 'en',
#     'intl': 'en-US',
#     'langRegion': 'en-US',
#     'hreflang': 'en-US',
#     'default': True,
#     'country': 'us',
#     'countryName': 'United States',
#     'currency': 'USD',
#     'reactIntl': '',
#     'merchGroup': 'US',
#     'messages': {'91330387': 'Name of wishlist is not unique.',
#      'JP.discount_addendum': 'Sale Price',
#      'browse_crossSellPopItemLowerCase': 'These popular items might interest you',
#      'browse_fallback_message': "The page you were viewing was experiencing technical difficulties and we're working to resolve it. A quick refresh should get you back in play. Apologies for the inconvenience.",
#      'browse_fallback_refresh_button': 'Refresh Now',
#      'browse_fallback_title': 'Short time out needed',
#      'browse_noMatchesFound': 'No matches found.',
#      'browse_pleaseTryAnotherSearch': 'Please try another search.',
#      'hf-geomismatch-chooseLocation': 'Choose Location',
#      'hf-geomismatch-confirm': 'Confirm',
#      'hf-geomismatch-message': 'Update your location to shop products available in {country}',
#      'hf-geomismatch-prompt': 'We think you are in {country}. Update your location?',
#      'hf-geomismatch-title': 'Confirm your Location',
#      'hf-geoselection-title': 'Select your Location',
#      'hf-header-label-carticon': 'Bag Items',
#      'hf-header-label-countryicon': 'Selected Location',
#      'hf_close_menu_aria_label': 'Close Menu',
#      'hf_cookie-policy_banner_ok': 'OK',
#      'hf_cookie_label_cookieSettings': 'Cookie Settings',
#      'hf_cookie_label_done': 'Done',
#      'hf_cookie_label_functional': 'Functional',
#      'hf_cookie_label_performance': 'Performance',
#      'hf_cookie_label_privacyPolicy': 'Privacy & Cookie Policy',
#      'hf_cookie_label_socialMedia': 'Social Media and Advertising',
#      'hf_cookie_label_yourCookieSettings': 'Your Cookie Settings',
#      'hf_cookie_policy_banner': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {privacyAndCookiePolicyHTML}. You can adjust your preferences in {cookieSettingsHTML}.',
#      'hf_cookie_policy_banner_ok': 'OK',
#      'hf_cookie_text_cookieAccept': 'Yes, I Accept',
#      'hf_cookie_text_cookieReject': "No, I Don't Accept",
#      'hf_cookie_text_do_you_accept': 'Do you accept these cookies and the processing of personal data involved?',
#      'hf_cookie_text_footer': 'You can always change your preference by visiting the "Cookie Settings" at the bottom of the page. View {privacyAndCookiePolicyHTML} for full details.',
#      'hf_cookie_text_functional': 'These cookies are required for basic site functionality and are therefore always enabled. These include cookies that allow you to be remembered as you explore the site within a single session or, if you request, from session to session. They help make the shopping cart and checkout process possible as well as assist in security issues and conforming to regulations.',
#      'hf_cookie_text_information': 'Privacy & Cookie Policy',
#      'hf_cookie_text_moreInformation': 'More Information',
#      'hf_cookie_text_performance': 'These cookies allow us to improve the siteâ\x80\x99s functionality by tracking usage on this website. In some cases these cookies improve the speed with which we can process your request, allow us to remember site preferences youâ\x80\x99ve selected. De-selecting these cookies may result in poorly-tailored recommendations and slow site performance.',
#      'hf_cookie_text_policy': 'Nike asks you to accept cookies for performance, social media and advertising purposes. Social media and advertising cookies of third parties are used to offer you social media functionalities and personalized ads. To get more information or amend your preferences, press the â\x80\x98more informationâ\x80\x99 button or visit "Cookie Settings" at the bottom of the website. To get more information about these cookies and the processing of your personal data, check our {privacyAndCookiePolicyHTML}. Do you accept these cookies and the processing of personal data involved?',
#      'hf_cookie_text_socialMedia': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#      'hf_cookie_text_socialMedia_2': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#      'hf_cookie_title_cookieSettings': 'Your Cookie Settings',
#      'hf_fallback_account': 'Account',
#      'hf_header_find_a_store': 'Find a Store',
#      'hf_header_label_acceptedPaymentTypes': 'Accepted Payment Types',
#      'hf_header_label_account': 'Account',
#      'hf_header_label_bag': 'Bag',
#      'hf_header_label_closeSearch': 'Close Search',
#      'hf_header_label_copyright': 'Â© 2023 Nike, Inc. All Rights Reserved',
#      'hf_header_label_favorites': 'Favorites',
#      'hf_header_label_help': 'Help',
#      'hf_header_label_hurleyLogo': 'Hurley Home Page',
#      'hf_header_label_joinOrLogin': 'Join/Log In To Nike Member Profile',
#      'hf_header_label_liveChat': 'Live Chat',
#      'hf_header_label_myAccount': 'My Account',
#      'hf_header_label_nikeSwooshLogo': 'Nike Home Page',
#      'hf_header_label_orders': 'Orders',
#      'hf_header_label_popular_search_terms': 'Popular Search Terms',
#      'hf_header_label_resetSearch': 'Reset Search',
#      'hf_header_label_search': 'Search',
#      'hf_header_label_search_input': 'Search Products',
#      'hf_header_label_search_open': 'Open Search Modal',
#      'hf_header_label_search_topSuggestions': 'Top Suggestions',
#      'hf_header_label_secondaryNavigation': 'Secondary Navigation',
#      'hf_header_label_selectACountry': 'Selected Location',
#      'hf_label_avatar': 'Avatar',
#      'hf_logo_converse': 'Converse Logo',
#      'hf_logo_jordan': 'Jordan Logo',
#      'hf_menu_aria_label': 'menu',
#      'hf_message_join_membership': 'Become a Nike Member for the best products, inspiration and stories in sport. {learnMore}',
#      'hf_message_join_nikeplus': 'Join Us to enjoy the best of Nike Membership with our family of apps, free shipping, access to coaching, global events and more.',
#      'hf_popular_search_gifts': 'Gifts',
#      'hf_search_cancel': 'Cancel',
#      'hf_skip_to_content': 'Skip to main content',
#      'hf_title_all_menuitem': 'All',
#      'hf_title_greeting_membership': 'Hi, {name}',
#      'hf_title_greeting_membership_a11y': 'Hi, {name}. Account & Favorites',
#      'hf_title_join_nikeplus': 'SIGN IN / JOIN US',
#      'hf_title_joinus_membership': 'Join Us',
#      'hf_title_learnmore_membership': 'Learn more',
#      'hf_title_signin_membership': 'Sign In',
#      'hf_visual_search_no_product_found': 'No product suggestions found for {query}',
#      'hf_visual_search_title': 'TOP SUGGESTIONS',
#      'hf_visual_search_viewall': 'View All',
#      'pdp_NBYCustomize': 'Customize',
#      'pdp_buying_tools_add_to_wishlist': 'Favorite',
#      'pdp_crosssell_buy_now': 'Buy Now',
#      'pdp_crosssell_cart_title': 'YOU MIGHT ALSO LIKE',
#      'pdp_crosssell_color': 'Color',
#      'pdp_crosssell_colors': 'Colors',
#      'pdp_crosssell_customize': 'Customize',
#      'pdp_crosssell_first_ordinal_indicator': 'st',
#      'pdp_crosssell_jersey_title': 'GET THE ULTIMATE',
#      'pdp_crosssell_jerseykids_title': 'GET THE ULTIMATE',
#      'pdp_crosssell_nfl_teams_available': 'All NFL Teams Available',
#      'pdp_crosssell_nfl_title': 'GET THE ULTIMATE',
#      'pdp_crosssell_nfl_title_suffix': 'HOOKUP',
#      'pdp_crosssell_nikeid_button': 'Shop All Nike By You',
#      'pdp_crosssell_nikeid_customize': 'CUSTOMIZE YOUR OWN WITH NIKE BY YOU',
#      'pdp_crosssell_nikeid_title': 'YOU MIGHT ALSO LIKE',
#      'pdp_crosssell_nikeid_url': 'http://www.nike.com/us/en_us/c/nikeid',
#      'pdp_crosssell_options': 'Options',
#      'pdp_crosssell_player_available': 'Player Available',
#      'pdp_crosssell_players_available': 'Players Available',
#      'pdp_crosssell_second_ordinal_indicator': 'nd',
#      'pdp_crosssell_shop_all_nikeid': 'SHOP ALL NIKE BY YOU',
#      'pdp_crosssell_third_ordinal_indicator': 'rd',
#      'pdp_crosssell_title': 'YOU MIGHT ALSO LIKE',
#      'pdp_crosssell_top_kids_products': 'TOP KIDSâ\x80\x99 PRODUCTS',
#      'pdp_crosssell_top_mens_products': 'TOP MENâ\x80\x99S PRODUCTS',
#      'pdp_crosssell_top_womens_products': 'TOP WOMENâ\x80\x99S PRODUCTS',
#      'pdp_crosssell_widths_available': 'Widths Available',
#      'pdp_nikeid_thumbnail_alt_text': 'Design your own Nike By You product',
#      'pdp_remove_customized_jersey': 'Remove',
#      'seePriceInCart': 'See Price in Bag',
#      'sub_footer_business_information_link_text': 'Business information confirmation',
#      'sub_footer_business_information_text': '(U) Nike Korea CEO Kimberlee Lynn Chang Mendes | 30th floor, Gangnam Finance Center, 152 Teheran-ro, Gangnam-gu, Seoul | Mail order distributor number 2011-Seoul Gangnam-03461 | Business registration number {phone}',
#      'sub_footer_businness_company_text': 'deposit payment',
#      'sub_footer_customer_service_text': 'Customer service phone number {phone} FAX {fax} | Email: {email} | Hosting service provider (U) Nike Korea',
#      'sub_footer_legal_info_link_text': 'Read more',
#      'sub_footer_legal_info_text': 'Information on content protection under the Content Industry Promotion Act.',
#      'sub_footer_modal_body_text': 'Name of content: product information, event information, etc.\nDate of creation of the content: cut-over date (or its update date if the content has been upgraded).\nAll content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent).',
#      'sub_footer_modal_body_text_one': 'Name of content: product information, event information, etc',
#      'sub_footer_modal_body_text_three': 'All content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent)',
#      'sub_footer_modal_body_text_two': 'Date of creation of the content: October 05, 2022 (or its update date if the content has been upgraded)',
#      'sub_footer_modal_title': 'Indication under the Content Industry Promotion Act',
#      'sub_footer_payment_information_text': 'For safe transactions, when paying with cash, etc., \u2028you can use the purchase safety service ({company}) of Korea Payment Network Co., Ltd., which you signed up for in our shopping mall.',
#      'test': 'testing',
#      '04E2F5C8': 'Sorry, the resource you requested does not exist.',
#      '15E57A07': 'Sorry, we had an issue with your request.  Please try again.',
#      '2DA19B6C': 'Sorry, you have reached the quantity limit.  Please remove an item and try again. ',
#      '3534E689': 'Sorry, the product you have selected is not available at this time.',
#      '36A1E761': 'Sorry, we do not recognize the postal code you entered. Please try entering a different postal code.',
#      '3F7B9831': 'Sorry, we couldnâ\x80\x99t process your request because your browser has too many cookies. Clear your cookies and try again.',
#      '49780BED': 'Unable to reach Partner',
#      '4C5FB5DF': 'Maximum wishlist items exceeded.',
#      '4CB0532B': 'Sorry, the code entered is incorrect or invalid. Please try again, or enter another code.',
#      '6BD7E72A': 'Maximum wishlists per user exceeded.',
#      '7E977FCE': 'Sorry, the product you have selected is not available at this time.',
#      '840D5CFE': 'Country not currently supported',
#      '8B2AE0A4': 'The resource you requested does not exist.',
#      '9008921A': 'Product already added to wishlist.',
#      '97AE3B36': 'We are temporarily experiencing site issues. If unable to complete your purchase, please try again later.',
#      'A044DD39': 'Sorry, this code could not be applied. Please review the criteria to qualify for this promotion.',
#      'A553CABC': 'Your item total has exceeded the $1000.00 checkout limit. Please remove a few items and try again.',
#      'A954F3EE': 'Offer invalid',
#      'AA33FB74': 'Sorry, the product you have selected is not available at this time. ',
#      'ABB4C446': 'Sorry, you have reached the quantity limit. Please remove an item and try again. ',
#      'AE66C4E0': 'Sorry, this code is expired. Please try another code.',
#      'B2D8D9B5': 'Sorry, we had an issue with your request.  Please try again.',
#      'B9671077': 'Sorry, the product you have selected is not available at this time.',
#      'C4CD1584': 'Offer invalid',
#      'CF1877FC': 'Failed to make Reservation with Inventory System.',
#      'D2A6EE25': 'The given country code is not in the valid list.',
#      'D403D4AD ': 'One or More Items Unavailable. Please remove one or more items from your Bag, refresh and try again.',
#      'DAD5D797': 'Sorry, the product you have selected is not available at this time. ',
#      'E2E82F65': 'The field value is invalid',
#      'E37BAB4': 'Sorry, the price of the Gift Card is invalid. ',
#      'AE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'AT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'AU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'BE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'BG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'BR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'BR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'CA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'CH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'CL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'CN.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'CN.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'CN.NikeCom_PDP_Suffix': '-Nike China official website',
#      'CN.NikeCom_Suffix': '-Nike China official website',
#      'CN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'CZ.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'CZ.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'CZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'DE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com.  ',
#      'DE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'DE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'DK.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'DK.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'DK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'EG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'ES.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'ES.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'ES.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'FI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'FR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'FR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'FR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'GB.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'GB.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#      'GB.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'GR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'GR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'GR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'HR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'HU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'HU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'HU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'HurleyCom_Wall_SEO_Title_Suffix': '. Hurley.com',
#      'ID.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'IE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'IL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'IN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'IT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'IT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'IT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'JP.NikeCom_PDP': '',
#      'JP.NikeCom_PDP_Prefix': '',
#      'JP.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'JP.NikeCom_PDP_SEO_Desc2': 'Try-on within 30 days can be returned (except some products). [Free shipping for Nike members anytime]',
#      'JP.NikeCom_PDP_Suffix': '. Nike JP',
#      'JP.NikeCom_Prefix': '',
#      'JP.NikeCom_Suffix': '. Nike JP',
#      'JP.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'JP.NikeCom_Wall_SEO_Title_Suffix': '. Nike JP',
#      'KR.NikeCom_Suffix': '. Nike KR',
#      'KR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'KR.NikeCom_Wall_SEO_Title_Suffix': '. Nike KR',
#      'LU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'MA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'MX.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'MY.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'NL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'NL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'NL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'NO.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'NO.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'NO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'NZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#      'NikeCom_PDP_SEO_Keywords': '{Product_Full_Title}',
#      'NikeCom_PDP_SEO_Title': '{NikeCom_Prefix}{Product_Full_Title}{NikeCom_Suffix}',
#      'NikeCom_PDP_Suffix': '. Nike.com',
#      'NikeCom_Suffix': '. Nike.com',
#      'NikeCom_Wall_SEO_Keywords': '{TITLE}',
#      'NikeCom_Wall_SEO_Title': '{TITLE}',
#      'NikeCom_Wall_SEO_Title_Default': 'Products',
#      'NikeCom_Wall_SEO_Title_Suffix': '. Nike.com',
#      'PH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'PL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'PL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'PL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'PR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'PT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'PT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'PT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'RO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'RU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'RU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'RU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'SA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'SE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'SE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'SE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'SG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'SI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'SK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'TH.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'TH.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'TH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'TR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'TR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'TR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'TW.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'TW.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#      'TW.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'US.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#      'US.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#      'US.NikeCom_PDP_Suffix': '. Nike.com',
#      'US.NikeCom_Suffix': '. Nike.com',
#      'US.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'VN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#      'ZA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#      'DE.pdp_vat_message': '<div> Prices incl. VAT and plus delivery costs. You can find details of shipping costs <a href = "https://www.nike.com/help/a/shipping-delivery" class = "exp-pdp-tc-disclaimer-url "> here </a> </ div>',
#      'FR.pdp_recycle_message': 'This product may be recyclable. <a href="https://www.nike.com/fr/help/a/triman"> Learn more </a>',
#      'JP.tax_addendum': '(Tax Incl.)',
#      'US.pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#      'US.pdp_standardShipping': 'Standard / Arrives 2-4 Business Days',
#      'US.pdp_twoDayShipping': 'Two-Day / Arrives 2-3 Business Days',
#      'crossell.certona.all-nfl-teams-available': 'All NFL Teams Available',
#      'crossell.certona.buy-now': 'Buy Now',
#      'crossell.certona.cart_rr': 'You Might Also Like ',
#      'crossell.certona.color-plural': 'Colors',
#      'crossell.certona.color-singular': 'Color',
#      'crossell.certona.error4041_rr': 'TOP MENâ\x80\x99S PRODUCTS',
#      'crossell.certona.error4042_rr': 'TOP WOMENâ\x80\x99S PRODUCTS',
#      'crossell.certona.error4043_rr': 'TOP KIDSâ\x80\x99 PRODUCTS',
#      'crossell.certona.first-option': 'st',
#      'crossell.certona.inactivepdp1_rr': 'THESE POPULAR PRODUCTS MIGHT INTEREST YOU',
#      'crossell.certona.inactivepdp2_rr': 'CUSTOMIZE YOUR OWN WITH NIKEiD',
#      'crossell.certona.nflbuilderpdp_rr': 'GET THE ULTIMATE',
#      'crossell.certona.nfljerseykidspdp_rr': 'GET THE ULTIMATE',
#      'crossell.certona.nfljerseypdp_rr': 'GET THE ULTIMATE',
#      'crossell.certona.nflpdp_rr_suffix': 'HOOKUP',
#      'crossell.certona.nikeid-button': 'Shop All NIKEiD',
#      'crossell.certona.nikeid-text': 'Customize',
#      'crossell.certona.nikeid-url': 'http://www.nike.com/us/en_us/c/nikeid',
#      'crossell.certona.nikeidpdp_rr': 'You Might Also Like',
#      'crossell.certona.nosearch1_rr': 'SHOP ALL NIKEiD',
#      'crossell.certona.nosearch2_rr': '&nbsp;',
#      'crossell.certona.options': 'Options',
#      'crossell.certona.pdp.crosssell.nikeid': 'CUSTOMIZE',
#      'crossell.certona.player-plural': 'Players Available',
#      'crossell.certona.player-singular': 'Player Available',
#      'crossell.certona.playerNamesAvailable': 'Players available',
#      'crossell.certona.product_rr': 'You Might Also Like',
#      'crossell.certona.purchase_rr': '(purchase_rr) REPLACE THIS VALUE IN HtmlLocalValueBundle.properties!',
#      'crossell.certona.second-option': 'nd',
#      'crossell.certona.third-option': 'rd',
#      'crossell.certona.widths-available': 'Widths Available',
#      'pdp_3rdParty_Overseas_Transfer_PI': '3rd Party and Overseas Transfer of Personal Information',
#      'pdp_Collection_Use_PI': ' the collection and use of personal information',
#      'pdp_I_Agree_To': 'I agree to',
#      'pdp_NBYAvailableFor': 'Available For',
#      'pdp_NBYButtonTitle': 'Customize',
#      'pdp_NBYColorChipLabel': 'Design Your Own',
#      'pdp_NBYCustomDesignTab': 'Your Designs',
#      'pdp_NBYDesignTabs': 'Designs',
#      'pdp_NBYInspirationTab': 'Inspiration',
#      'pdp_NBYShareYourDesign': 'Share Your Design',
#      'pdp_NBYSoldOut': 'Sold Out',
#      'pdp_NBYYourDesignTxt': "Choose 'Customize' to add a design",
#      'pdp_NotifyMeButtonTitle': 'Notify Me',
#      'pdp_NotifyMeCancel': 'Cancel',
#      'pdp_NotifyMeDefaultEmailAddressText': 'Email Address',
#      'pdp_NotifyMeDone': 'Done',
#      'pdp_NotifyMeEmailOptInMessage': 'Send me news and offers from Nike',
#      'pdp_NotifyMeInvalidEmail': 'Please enter a valid email.',
#      'pdp_NotifyMeLegalText': '{privacyLinkText} and {termsOfUseLinkText}',
#      'pdp_NotifyMeModalBody': 'Get a one-time email alert the moment this product drops',
#      'pdp_NotifyMeModalLegalLinkJoin': 'and',
#      'pdp_NotifyMeModalPrivacyPolicyLinkText': 'Privacy Policy',
#      'pdp_NotifyMeModalTermsOfUseLinkText': 'Terms of Use',
#      'pdp_NotifyMeModalTitle': "Don't Miss Out",
#      'pdp_NotifyMeOk': 'Ok',
#      'pdp_NotifyMeOkModalTitle': "You're on the List",
#      'pdp_NotifyMeServerError': 'There was an error creating this notification.  Please try again later.',
#      'pdp_NotifyMeSubmit': 'Submit',
#      'pdp_NotifyMeThanks': "We'll send a one-time email to {email} when this product drops.",
#      'pdp_NotifyMe_AddAPhoneNumber': 'Add a phone number to get notified',
#      'pdp_NotifyMe_AddAnEmail': 'Add an email address to get notified',
#      'pdp_NotifyMe_And': 'and',
#      'pdp_NotifyMe_ConsentRefusal': 'You may refuse to consent, in which case you will not be able to receive information about Nike product releases. Nike is not responsible if the notification message fails to deliver.',
#      'pdp_NotifyMe_DefaultHeaderSubtitle': 'Get a one-time notification when this product drops.',
#      'pdp_NotifyMe_EmailHeaderSubtitle': 'Enter your email to receive a one-time notification',
#      'pdp_NotifyMe_EmailHeaderTitle': 'Add your email address.',
#      'pdp_NotifyMe_MemberEmailSendTo': 'Send an email to',
#      'pdp_NotifyMe_NotifyWithEmail': 'Notify with email',
#      'pdp_NotifyMe_NotifyWithSMS': 'Notify with SMS',
#      'pdp_NotifyMe_OverseasTransfer': 'I agree to <a href="{infoTransferLink}">3rd Party and Overseas Transfer of Personal Information</a>',
#      'pdp_NotifyMe_PersonalInfo': 'I agree to the <a href="{infoCollectionLink}">collection and use of personal information</a>',
#      'pdp_NotifyMe_PrivacyPolicyLegal': 'I agree to Nikeâ\x80\x99s <a href="{privacyPolicyLink}">Privacy Policy</a> and <a href="{termsOfUseLink}">Terms of Use</a>',
#      'pdp_NotifyMe_SMSHeaderTitle': 'Add your mobile phone number.',
#      'pdp_NotifyMe_SendEmailTo': "We'll send an email to",
#      'pdp_NotifyMe_SendSMSTo': 'Weâ\x80\x99ll send an SMS to',
#      'pdp_NotifyMe_TermsOfUseLegal': 'I agree to Nikeâ\x80\x99s <a href="{termsOfUseLink}">Terms of Use</a>',
#      'pdp_NotifyMe_YouAreAllSet': "You're all set!",
#      'pdp_NotifyMe_title': "Don't Miss Out",
#      'pdp_PageNotFoundMessage': 'WE CANâ\x80\x99T FIND THE PAGE YOU ARE LOOKING FOR',
#      'pdp_RFYNotAuthorized': 'Sorry, this product is not reserved for you.',
#      'pdp_RFYProductExpiredOn': 'Expired on {expiredOn}',
#      'pdp_RFYProductRedeemedOn': 'Redeemed on {redeemedOn}',
#      'pdp_RFYRedeemProduct': 'Redeem',
#      'pdp_RFYSubtitle': 'Reserved for You',
#      'pdp_SeeMoreProducts': 'See More',
#      'pdp_SimilarStyles': 'Similar Styles',
#      'pdp_a11y_aria_choose_a_style_color': 'Choose a Style Color',
#      'pdp_a11y_avg_star_rating': 'Average Rating {rating} of {starCount}',
#      'pdp_addToCart': 'Add to Bag',
#      'pdp_addToCartErrorLabel': 'Error:',
#      'pdp_addToCartErrorText': 'This request timed out, please try again',
#      'pdp_addToWishlist': 'Add to Favorites',
#      'pdp_addedToCart': 'Added to Bag',
#      'pdp_addedToWishlist': 'Added to Favorites',
#      'pdp_additionalInfo': 'More Info',
#      'pdp_allProductsSoldOutMessage': 'This product is currently unavailable',
#      'pdp_also_includes_all_applicable_duties': 'Also includes all applicable duties',
#      'pdp_arrivesDate': 'Arrives',
#      'pdp_back': 'Back',
#      'pdp_bopisShipping': 'Shipping',
#      'pdp_button_close': 'Close',
#      'pdp_cartAndCheckout': 'Bag & Checkout',
#      'pdp_cartQuantity': 'Qty 1',
#      'pdp_check_back_soon_label': 'Check back soon.',
#      'pdp_check_back_soon_message': 'Unfortunately we are not able to fulfill orders in this country at this time. Please check back for future availability. ',
#      'pdp_checkout': 'Checkout',
#      'pdp_chooseSize': 'Select Size',
#      'pdp_closeDialogButtonLabel': 'Close this dialog window',
#      'pdp_cloudAddToCartError': 'An error has occurred: ',
#      'pdp_comingSoon': 'Coming Soon',
#      'pdp_continueShopping': 'Continue Shopping',
#      'pdp_cookie_banner_message': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {PrivacyPolicy}. You can adjust your preferences in {CookieSettings}.',
#      'pdp_cookie_settings': 'Cookie Settings',
#      'pdp_copyLink': 'Copy Link',
#      'pdp_copyLinkConfirmation': 'Copied',
#      'pdp_countdownDay': 'd',
#      'pdp_countdownHour': 'h',
#      'pdp_countdownMinute': 'm',
#      'pdp_countdownSecond': 's',
#      'pdp_country_of_origin': 'Country/Region of Origin:',
#      'pdp_currentlyUnavailable': 'Currently Unavailable',
#      'pdp_default_title': 'Nike Store. Shoes, Clothing & Gear.',
#      'pdp_estimateShippingTime': 'Estimate Shipping Time',
#      'pdp_fasterShippingOptions': 'Faster Shipping options may be available',
#      'pdp_feedbackText': 'Your input will help us create an even better shopping experience for you.',
#      'pdp_fitPrivacyHeader': 'Privacy',
#      'pdp_fitPrivacyModalCloseBtn': 'Close',
#      'pdp_fitPrivacyModalContent': '<h1>Your Privacy</h1>\n<ul>\n<li>Nike partners with <a href="https://www.fitanalytics.com/" target="_blank"><strong>Fit Analytics</strong></a> to recommend sizes on <a href="https://www.nike.com/" target="_blank">Nike.com</a>.</li><li>To help make those recommendations, <strong>Nike uses performance</strong> cookies and the information you provide.</li><li>Nike shares <strong>deidentified information</strong> with Fit Analytics to help improve size recommendations.</li><li>Nike only has access to general Fit Analytics statistics.</li>\n</ul>',
#      'pdp_fitSize': 'Your Nike Fit is',
#      'pdp_fit_opinion_runs_big': 'Runs Big',
#      'pdp_fit_opinion_runs_consistently_big': 'Customers who reviewed this product say it runs big.',
#      'pdp_fit_opinion_runs_consistently_small': 'Customers who reviewed this product say it runs small.',
#      'pdp_fit_opinion_runs_small': 'Runs Small',
#      'pdp_fit_opinion_runs_sometimes_big': 'Customers who reviewed this product say it runs slightly big.',
#      'pdp_fit_opinion_runs_sometimes_small': 'Customers who reviewed this product say it runs slightly small.',
#      'pdp_fit_opinion_runs_true': 'Customers who reviewed this product say it runs true to size.',
#      'pdp_freeShipping': 'Free Shipping with Nike Membership',
#      'pdp_gcChooseAnAmount': 'Choose an amount',
#      'pdp_gcColorwayTitle': 'Choose a design',
#      'pdp_gcCustomAmount': 'Custom amount:',
#      'pdp_gcCustomAmountMaxValueError': 'Gift card amount cannot exceed {maxValue}',
#      'pdp_gcCustomAmountMinValueError': 'Gift card amount must be at least {minValue}',
#      'pdp_gcCustomAmountRestrictedCharacterError': 'This contains a restricted character, please choose another.',
#      'pdp_gcDeliveryDetailsLink': 'Enter address',
#      'pdp_gcDeliveryDetailsText': "Let us know where it's going. ",
#      'pdp_gcDeliveryDetailsTitle': 'Add recipient delivery details',
#      'pdp_gcDeliveryMethod': 'Choose a delivery method',
#      'pdp_gcDeliveryMethodEmail': 'Email',
#      'pdp_gcDeliveryMethodMail': 'Mail',
#      'pdp_gcDigitalAddressEditButton': 'Edit',
#      'pdp_gcEmailInput': 'Email',
#      'pdp_gcLargeOrderButton': 'Need a Larger Order?',
#      'pdp_gcLargeOrderModalEmailLink': 'giftcards@nike.com',
#      'pdp_gcLargeOrderModalMainText': 'Just e-mail {emailLink} for more information or call Nike directly at 1-877-220-6453 for assistance. You will receive a reply or call-back during Nike corporate business hours (Monday through Friday, 8 AM â\x80\x93 5 PM Pacific Time, excluding holiday). Please do not send credit card information over email.',
#      'pdp_gcLargeOrderModalSubTitle': 'Need to order more than 10 cards or to put in an order totaling more than $5,000?',
#      'pdp_gcLargeOrderModalTitle': 'Need to Place a Larger Order?',
#      'pdp_gcNoPOBox': 'We do not deliver to P.O. Boxes',
#      'pdp_gcOptionalMessageErrorText': 'Your message is invalid, please try again.',
#      'pdp_gcOptionalMessageLabel': 'Add an optional message',
#      'pdp_gcOptionalMessageText': 'Enter a personalized message for the recipient.',
#      'pdp_gcQuantity': 'Quantity',
#      'pdp_gcRecipientAddress': 'Address',
#      'pdp_gcRecipientAddress2': 'Add Company, C/O, Apt, Suite, Unit (Optional)',
#      'pdp_gcRecipientAddressError': "Please enter recipient's address.",
#      'pdp_gcRecipientCity': 'City',
#      'pdp_gcRecipientCityError': "Please enter recipient's city.",
#      'pdp_gcRecipientEmailAddress': 'Email',
#      'pdp_gcRecipientEmailAddressError': 'Please enter a valid email address.',
#      'pdp_gcRecipientEmailError': 'Please enter a valid email address.',
#      'pdp_gcRecipientFirstName': 'First Name',
#      'pdp_gcRecipientFirstNameError': "Please enter recipient's first name.",
#      'pdp_gcRecipientLastName': 'Last Name',
#      'pdp_gcRecipientLastNameError': "Please enter recipient's last name.",
#      'pdp_gcRecipientState': 'State',
#      'pdp_gcRecipientStateError': "Please select recipient's state.",
#      'pdp_gcRecipientZip': 'Postal Code',
#      'pdp_gcRecipientZipError': 'Please enter a valid zip code.',
#      'pdp_gcStateDropdownTitle': 'Select a State',
#      'pdp_gcTCLink': 'Gift Card Terms and Conditions',
#      'pdp_gender_men': 'Men',
#      'pdp_gender_women': 'Women',
#      'pdp_gift_description': 'Send as an E-Gift',
#      'pdp_gift_link_message': 'Send Now',
#      'pdp_gift_message': 'You choose the gift, they choose the size and color.',
#      'pdp_gift_tooltip': "Send this item instantly, by email. They'll choose size and color, or use the gift value towards another Nike.com purchase.",
#      'pdp_helpUsImproveYourExperience': 'Help Us Improve Your Experience',
#      'pdp_highly_rated': 'Highly Rated',
#      'pdp_howItFits': 'How it Fits',
#      'pdp_incl_of_taxes': 'incl. of taxes',
#      'pdp_include_of_taxes_and_duties': 'incl. of taxes and duties',
#      'pdp_just_a_few_left_order_soon': 'Just a few left. Order soon.',
#      'pdp_just_a_few_left_order_soon_kr': 'Almost sold out. Order soon.',
#      'pdp_keepShopping': 'Keep Shopping',
#      'pdp_klarna_message': 'Buy now, pay in 3 installments with <span>Klarna</span>',
#      'pdp_klarna_message_short': '<span>Klarna</span> Available at checkout.',
#      'pdp_launchAvailableDate': 'Available {Launch_Date} at {Launch_Time}',
#      'pdp_launchBuyCTA': 'Buy',
#      'pdp_launchBuyableGuestIntro': 'Only Nike Members get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#      'pdp_launchBuyableMemberIntro': 'Only Nike Members like you get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#      'pdp_launchCSGuestIntro': "Create or sign in to your free Nike Member account for a chance to buy this product the moment it's released. {learnMoreButtonText}",
#      'pdp_launchCSMemberIntro': "Nike Members like you are the only ones who have a chance to purchase this product when it's released. {learnMoreButtonText}",
#      'pdp_launchCheckoutErrorBody': 'There was a problem processing your payment.  Check your payment information and try again.',
#      'pdp_launchCheckoutErrorTitle': "Let's try this again.",
#      'pdp_launchCheckoutNotLoggedIn': 'Your session has expired.  Please refresh and login to continue.',
#      'pdp_launchCheckoutNumberNotVerified': 'Your session has expired.  Please refresh and login to continue.',
#      'pdp_launchComingSoon': 'Coming Soon',
#      'pdp_launchComingSoonStepOne': '1. Sign in to your Nike Member account or {joinButtonText}',
#      'pdp_launchComingSoonStepThree': '3. Verify your mobile number in account settings.',
#      'pdp_launchComingSoonStepTwo': '2. Confirm your payment info is updated. ',
#      'pdp_launchDismissModalButton': 'Continue Shopping',
#      'pdp_launchFirstParagraphComingSoon': "Introducing Line Checkout. Come back after a Product is available to get in line. If your turn comes up, we'll complete your order. Before getting in line, make sure you:",
#      'pdp_launchFirstParagraphGetInLine': "Line Checkout is the only way to buy some of our most popular products - like this one. Once you're in line and your turn comes up, we'll complete your order. ",
#      'pdp_launchGetInLine': 'Get in Line',
#      'pdp_launchGetInLineTitle': 'Get in Line. Get the goods.',
#      'pdp_launchInLineBodyModal': "If your turn comes up, we'll complete your order. ",
#      'pdp_launchJoinForFreeButton': 'join for free.',
#      'pdp_launchLMModalBePreparedBullet': 'Be prepared',
#      'pdp_launchLMModalBePreparedSubBullet': "Make sure you're signed in to your Nike Member account and ready when the product launches.",
#      'pdp_launchLMModalContinueShoppingCTA': 'Continue Shopping',
#      'pdp_launchLMModalFirstTitle': 'How Line Checkout Works',
#      'pdp_launchLMModalGuestJoinBullet': 'Become a Nike Member',
#      'pdp_launchLMModalGuestJoinSubBullet': 'Line Checkout is available only to Nike Members. Not a Member? {JoinForFree}',
#      'pdp_launchLMModalJoinForFree': 'Join for Free',
#      'pdp_launchLMModalJoinNikePlusCTA': 'Become a Nike Member',
#      'pdp_launchLMModalLineOne': 'To make sure Nike Members have an equal chance to purchase high-demand items on our site, we use a Line Checkout system.',
#      'pdp_launchLMModalLineThree': 'Wait times vary based on demand. Limit one item per Nike Member.',
#      'pdp_launchLMModalLineTwo': "If your chosen size and color is available when you're selected, we'll process your order. If your selection sells out before that, we'll let you know.",
#      'pdp_launchLMModalSecondTitle': 'Improve Your Odds',
#      'pdp_launchLMModalSecondTitleSubtitle': "Here's how to make your Line Checkout experience as easy as possible:",
#      'pdp_launchLMModalUpdateProfileBullet': 'Update your Nike Member profile',
#      'pdp_launchLMModalUpdateProfileSubBullet': 'Make sure your shipping and payment information is current.',
#      'pdp_launchLMModalUpdateSettingsCTA': 'Update Account Settings',
#      'pdp_launchLMModalVerifyMobileBullet': 'Verify your mobile number',
#      'pdp_launchLMModalVerifyMobileSubBullet': 'This layer of added security helps keep the Line Checkout process fair.',
#      'pdp_launchLearnMoreButtonText': 'Learn more',
#      'pdp_launchNonWinnerBody': "Thank you for entering for the Nike Air VaporMax. Unfortunately, it didn't work out this time.",
#      'pdp_launchNonWinnerTitle': "Didn't Get 'Em",
#      'pdp_launchNotifyYou': 'We will notify you in a moment whether you get a pair or not.',
#      'pdp_launchPending': "You're in line",
#      'pdp_launchSessionExpiredTitle': 'Session expired',
#      'pdp_launchSoldOut': 'Sold Out',
#      'pdp_launchUnavailableTitle': 'Product unavailable',
#      'pdp_launchWinnerBody': 'Congratulations on your purchase. A confirmation email is on the way.',
#      'pdp_launchWinnerTitle': 'You Got It',
#      'pdp_launchYouAreInLine': "You're Currently In Line",
#      'pdp_launchYouAreInLineBody': 'We will notify you in a moment whether you get a pair or not.',
#      'pdp_launch_coming_soon_title': 'Get in Line. Get the Goods.',
#      'pdp_launch_entered': 'Launch Entered',
#      'pdp_launch_non_winner': 'Non winner',
#      'pdp_launch_pending': 'Pending...',
#      'pdp_launch_purchased': 'Purchased',
#      'pdp_launch_unavailable': 'This product is no longer available.',
#      'pdp_learnMore': 'Learn More',
#      'pdp_limitedColorBadge': 'Limited Color',
#      'pdp_limitedTimeBadge': 'Seasonal (Limited Time Color)',
#      'pdp_low_inventory_order_soon': 'Low inventory! Order soon.',
#      'pdp_low_stock_message': 'Limited stock in selected size',
#      'pdp_manufacturerAccordionCopy': 'Declaration of Importer: Direct import by the individual customer<br><br>Marketed by: Nike Global Trading B.V. Singapore Branch, 30 Pasir Panjang Road, #10-31/32, Mapletree Business City, Singapore 117 440',
#      'pdp_manufacturerAccordionHeader': 'Product Information',
#      'pdp_member_exclusive_subtitle': 'Member Exclusive',
#      'pdp_member_exclusive_subtitle_na': 'Member Access',
#      'pdp_member_exclusive_support_message': 'Sign in or create a free Nike Member account to get this product.',
#      'pdp_member_exclusive_support_message_title': 'It only takes a Nike Membership',
#      'pdp_minicart_upsell_recommendations_title': 'Frequently Bought Together',
#      'pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#      'pdp_no_return_text': 'This product is customized so the order cannot be cancelled 30 minutes after submit. Nike By You customized products do not apply to no reason return or exchange policy.',
#      'pdp_notAvailableForPickup': 'This item is not available for pickup',
#      'pdp_notifyMeSurveyText': 'If given the opportunity to be notified if this color becomes available, would you be interested?',
#      'pdp_numeric_range_separator': 'â\x80\x93',
#      'pdp_ok': 'OK',
#      'pdp_one_size': 'ONE SIZE',
#      'pdp_one_size_low_stock_message': 'Limited stock',
#      'pdp_pageNotFoundHeader': 'TIME OUT',
#      'pdp_percentageOff': 'off',
#      'pdp_pickUp': 'Free Pickup',
#      'pdp_pleaseSelectASize': 'Please select a size.',
#      'pdp_pre_order': 'Pre-Order',
#      'pdp_pre_order_get_it_first': 'Get it First:',
#      'pdp_pre_order_ships': 'Ships',
#      'pdp_privacy_policy_link': 'Privacy & Cookie Policy',
#      'pdp_productNotFound': 'THE PRODUCT YOU ARE LOOKING FOR IS NO LONGER AVAILABLE',
#      'pdp_productSoldOutMessage': 'This product is currently unavailable',
#      'pdp_product_crossedoutMessage': 'Discounted from',
#      'pdp_product_details_button': 'Read more',
#      'pdp_product_details_button_abtest_variant_a': 'View Product Details',
#      'pdp_promoMessaging': 'This product is excluded from site promotions and discounts.',
#      'pdp_recommendations_header': 'YOU MAY ALSO LIKE',
#      'pdp_recommendations_top_trending': 'TOP TRENDING',
# ...
#          'title': '',
#          'squarishId': '',
#          'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#          'richTextLinks': [],
#          'subtitle': '',
#          'colorTheme': 'dark',
#          'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#           'modifiedDate': '2021-10-04T16:32:17.053Z',
#           'exposeTemplate': False,
#           'properties': {'actions': {}},
#           'resourceType': 'content/style'},
#          'actions': [],
#          'landscape': {'id': '9d61f74a-6c21-45d4-bb60-e94c06f3c945',
#           'type': 'product',
#           'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg'}}},
#        {'analytics': {'hashKey': 'fb66428b4726a52cb2f81f5739fe5be5d4b0ad04af664ecc30339ece62b60f98'},
#         'subType': 'text',
#         'id': '3a049537-aed5-44aa-b0f5-fb3e48e56399',
#         'type': 'card',
#         'version': '1633365089421',
#         'properties': {'copyId': 'a253dd95d0bae61b5d9ca9e207e32247ceb15df6',
#          'product': [],
#          'richTextLinks': [],
#          'custom': {},
#          'subtitle': '',
#          'colorTheme': 'dark',
#          'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#           'modifiedDate': '2021-10-04T16:31:29.405Z',
#           'exposeTemplate': False,
#           'properties': {'actions': {}},
#           'resourceType': 'content/style'},
#          'body': '<p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p>',
#          'title': 'Flexibility for Speed',
#          'actions': []}},
#        {'analytics': {'hashKey': 'add5b12590aa45c846ef8ab48ffb89ba2ee497d861dfff6291162efb2625bbc7'},
#         'subType': 'image',
#         'id': '072fa761-6350-45a0-9a85-88fad4ea24e7',
#         'type': 'card',
#         'version': '1633365102718',
#         'properties': {'portraitId': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#          'squarishURL': '',
#          'landscapeId': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#          'altText': '',
#          'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg',
#          'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg',
#          'portrait': {'id': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#           'type': 'product',
#           'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg'},
#          'title': '',
#          'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#          'richTextLinks': [],
#          'subtitle': '',
#          'colorTheme': 'dark',
#          'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#           'modifiedDate': '2021-10-04T16:31:42.718Z',
#           'exposeTemplate': False,
#           'resourceType': 'content/style'},
#          'actions': [],
#          'landscape': {'id': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#           'type': 'product',
#           'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg'}}},
#        {'analytics': {'hashKey': '19214ec1853bfd1aa0b5986f20c9f7bc1291c2d42405b07ae9d74bc303bb711d'},
#         'subType': 'text',
#         'id': '6de4f79e-1e52-4c01-a9d7-a21e9b8cb30b',
#         'type': 'card',
#         'version': '1633365097774',
#         'properties': {'copyId': 'd059f6db5527b41ea4abe44d472b2f9577221c23',
#          'product': [],
#          'richTextLinks': [],
#          'custom': {},
#          'subtitle': '',
#          'colorTheme': 'dark',
#          'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#           'modifiedDate': '2021-10-04T16:31:37.709Z',
#           'exposeTemplate': False,
#           'properties': {'actions': {}},
#           'resourceType': 'content/style'},
#          'body': '<p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p>',
#          'title': 'Stability for Strength',
#          'actions': []}}],
#       'layoutCards': [],
#       'firstImageUrl': 'https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png',
#       'firstImageAltText': 'Nike Free Metcon 4 Training Shoes',
#       'sustainabilityMessage': [],
#       'descriptionPreviewBullets': '',
#       'moreInfoMessages': [],
#       'sizeFitMessages': [],
#       'hubMessages': [],
#       'language': 'en',
#       'marketplace': 'US',
#       'availableSkus': [{'id': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da',
#         'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#         'resourceType': 'availableSkus',
#         'links': {'self': {'ref': '/deliver/available_skus/v1/ef237b73-2633-56fe-8ebd-fbc2258fa8da'}},
#         'available': True,
#         'level': 'LOW',
#         'skuId': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da'},
#        {'id': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f',
#         'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#         'resourceType': 'availableSkus',
#         'links': {'self': {'ref': '/deliver/available_skus/v1/2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'}},
#         'available': True,
#         'level': 'LOW',
#         'skuId': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'},
#        {'id': '9fd7e097-24db-5c33-b660-d300c3f6579c',
#         'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#         'resourceType': 'availableSkus',
#         'links': {'self': {'ref': '/deliver/available_skus/v1/9fd7e097-24db-5c33-b660-d300c3f6579c'}},
#         'available': True,
#         'level': 'LOW',
#         'skuId': '9fd7e097-24db-5c33-b660-d300c3f6579c'},
#        {'id': 'da0611fb-2af5-53fa-89c3-8baea350977b',
#         'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#         'resourceType': 'availableSkus',
#         'links': {'self': {'ref': '/deliver/available_skus/v1/da0611fb-2af5-53fa-89c3-8baea350977b'}},
#         'available': True,
#         'level': 'LOW',
#         'skuId': 'da0611fb-2af5-53fa-89c3-8baea350977b'},
#        {'id': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca',
#         'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#         'resourceType': 'availableSkus',
#         'links': {'self': {'ref': '/deliver/available_skus/v1/4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}},
#         'available': True,
#         'level': 'LOW',
#         'skuId': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}],
#       'publishType': 'FLOW',
#       'isLaunchView': False,
#       'launchView': None,
#       'isForNumberOfImagesABTesting': False,
#       'isMinimumAdvertisedPrice': False,
#       'collectionTermIds': ['c05bedd9-29d3-4e45-8c62-c463f9c5958f',
#        '1a70e9af-aea9-4a39-9773-fa6ced97c58b',
#        '65838112-1f4d-48a7-9b2f-1e8736c4cdcc',
#        'a49f8e69-ff9c-4356-89d8-d4a098fc02c2',
#        'e4e46ee6-496f-491a-8771-1a677eefee3a',
#        '94d2c954-14cd-4784-96ec-b02c950d2872',
#        '62f3c208-e1a3-45c0-9e70-a90be4e276f1',
#        'b9cefedb-1dd5-42dc-af13-939a240d4bb8',
#        '4be7e5d7-7e5b-460d-b3d7-41396b3fa985'],
#       'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#        '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#        '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#        'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#        '292efae5-2d9a-44a3-a529-cda684a47c44',
#        'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#        '7702dda3-62ca-3410-b4f3-97025be1089d',
#        '68a7b17f-291f-41f8-bf04-5e2fbe878d9b',
#        '05392778-fff6-4fa0-a375-2506d27f009e',
#        '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#        '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#        'b942d0ac-4887-4a8f-b914-d82a6181014f',
#        '67063381-90eb-4763-8f87-acc30b392f38',
#        '699b34a6-1950-3458-8322-910b695fccb7',
#        '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#        '10f9af5a-58d2-480a-a72d-5a65bd374850',
#        '0a937561-8633-3ea1-8ae3-8509f50f4127',
#        '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#        '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#        '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#        '539c6c43-d060-30b0-be5b-47c47f7c7658',
#        'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#        '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#        '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#        '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#        '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#        '2057952b-1a72-368e-b4b1-f67091ff1799',
#        '6e7e4809-fccb-4e82-8a7b-047125398076',
#        '9b0e77d0-aec5-4f4b-b8de-acb7a82e396d',
#        '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#        '7abdd901-856d-3601-94bf-14313cee8354',
#        '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#        'b5cd158b-b105-490c-b777-652943e742b0',
#        'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#        '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#        '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#        '16633190-45e5-4830-a068-232ac7aea82c',
#        '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#        '7817e756-7721-4cfb-b404-04df79c685e4',
#        'c29a0094-d302-4b7a-b5f0-73e46f772348'],
#       'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#       'catalogId': '1',
#       'selectedSkuId': {},
#       'sizeAndFitDescription': '',
#       'exclusiveAccess': False,
#       'notifyMeIndicator': False,
#       'promoExclusionAccess': False,
#       'useFeedsPromoExclusionMessage': False,
#       'jerseyIdPathName': '',
#       'nbyHubMessages': [],
#       'state': 'IN_STOCK'}}},
#    'NikeId': {'nikeIdPrebuildSuggestion': None,
#     'NBYBuilderModalOpen': False,
#     'metricId': '',
#     'itemId': '',
#     'gender': '',
#     'sizing': {},
#     'fit': '',
#     'showNBYBuyingTools': False,
#     'error': None,
#     'availability': False,
#     'async': {'prebuildSuggestions': False},
#     'isAvailable': True},
#    'NotQuiteReady': {'notQuiteReadyEvts': []},
#    'Fit': {'fitSize': '', 'localizedFitSize': '', 'isFitSizeSet': False},
#    'EDD': {'estimatedDeliveryData': None},
#    'User': {'user': {}, 'isSwoosh': False, 'initialized': False},
#    'FitAnalytics': {'fitAnalyticsRecommendedSize': None,
#     'fitAnalyticsFindMySizeClicked': False},
#    'Cart': {'isSizeSelectError': False,
#     'cartProduct': {},
#     'cartSku': {},
#     'wishlistProduct': {},
#     'wishlistSku': {},
#     'isWishlistConfirmationModalOpen': False,
#     'async': {},
#     'payload': {},
#     'cartError': []},
#    'Config': {'name': 'pdp',
#     'domain': 'dotcom',
#     'division': 'commerce',
#     'platform': 'cloud',
#     'version': '1.0.0',
#     'facebookAppId': '1397260880304609',
#     'channelId': 'd9a5bc42-4b9c-4976-858a-f159cf99c647',
#     'env': 'prod',
#     'dark': False,
#     'preview': False,
#     'branchIOKey': 'key_test_dcy0gJ0f2U1NBELEQXq8ElcgvumigPUu',
#     'defaultStyleColor': '724010-017',
#     'productStateOverride': None,
#     'gqlHash': '4bc133d8e69ba0dd907158346fed7f2e',
#     'flags': {'abTests': True,
#      'animateAccordionPanels': False,
#      'cookieSettings': False,
#      'cookieSettingsBanner': False,
#      'cutOverPdpToSegment': True,
#      'debug': False,
#      'enableMAP': True,
#      'filterByNikeDotComChannel': True,
#      'globalNavUseGeoPrivacy': True,
#      'gridRecommendations': True,
#      'hideBuyingTools': False,
#      'incentivizedReviewsMessageNA': True,
#      'incentivizedReviewsMessage': False,
#      'includeFacebookAppId': True,
#      'logoutShouldClearCart': True,
#      'lowInventoryMessage': True,
#      'loadWebShell': True,
#      'loadWebShellOnWall': False,
#      'loadForterScript': True,
#      'loadStylitics': True,
#      'notifyMe': True,
#      'showAvailabilityDate': False,
#      'recommendations': True,
#      'reserveForYou': True,
#      'sendPIDsOnWall': True,
#      'shareNBY': True,
#      'showCNNewYearsLink': False,
#      'showCgc': True,
#      'showColorWayPicker': True,
#      'showEGift': True,
#      'showElevatedContent': True,
#      'showFit': True,
#      'showGeoMismatch': True,
#      'showGiftCardMessage': True,
#      'showGiftCardTypeLink': True,
#      'showGiftCards': True,
#      'showJerseyId': True,
#      'showKlarnaPayMessage': True,
#      'showKlarnaPayLaterMessage': False,
#      'showLargeGiftCardOrder': True,
#      'showLaunchDebug': False,
#      'showLaunchProduct': True,
#      'showLeftHandNavCategories': True,
#      'showMobileWriteReview': True,
#      'showMoreInfo': True,
#      'showNBY': True,
#      'showNBYMessageHub': True,
#      'showNikeId': True,
#      'showOmni': False,
#      'showPhysicalGiftCards': True,
#      'showPromoBanner': True,
#      'showPromoMsg': True,
#      'showPromoExclusionMsg': True,
#      'showFeedsPromoExclusionMessage': False,
#      'showReadMore': True,
#      'showRelatedCategories': True,
#      'showReviews': True,
#      'showSEOCopy': False,
#      'showSinglesDaySalesLink': False,
#      'showSizeAndFit': True,
#      'showSizeCalculator': False,
#      'showSocialLinksNBY': True,
#      'showUniteTimers': False,
#      'showWidthSelector': True,
#      'showWishlist': True,
#      'skipPercentOff': False,
#      'skipSustainability': False,
#      'skipSegmentDupedEvents': True,
#      'swooshEligibleGeo': True,
#      'useBounceExchange': False,
#      'useDotcomNav': True,
#      'useDotcomNavESI': True,
#      'useExclusiveAccess': True,
#      'useFeedsMoreInfoMessage': False,
#      'useFeedsSizeFitMessage': False,
#      'useFeedsSustainabilityMessage': True,
#      'useMAPCollection': True,
#      'useNBYCloudUrl': True,
#      'useNBYImageService': True,
#      'useNeo': True,
#      'useNewRelic': True,
#      'useOptimizelyX': True,
#      'usePersonalizedNullSearch': False,
#      'useRollupKey': True,
#      'useSentryIO': False,
#      'useServiceCanonicalUrl': True,
#      'useSwitchboardRecommendations': False,
#      'useTTReviews': True,
#      'useUniteStaging': False,
#      'enableNikeShopModals': True,
#      'showElevatedCarousel': True,
#      'hideEDDFasterShippingOptionMsg': False,
#      'showEstimatedDeliveryDate': False,
#      'showEstimatedDeliveryDateAndPickup': True,
#      'showPickupLocation': True,
#      'showEDDAndBopisABTesting': False,
#      'wallFavorites': False,
#      'wallFiltersBtnFilterLabel': True,
#      'wallImpressions': True,
#      'wallNoResultsCarousel': True,
#      'useTTV5Reviews': True,
#      'useNotifyMeV2': False,
#      'isZoomEnabled': False},
#     'assetPaths': {},
#     'recommendationsScheme': 'product_rr',
#     'cacheDuration': {'404': 60,
#      'default': 900,
#      'launch': 900,
#      'pdp': 900,
#      'perf': 900,
#      'wall': 300},
#     'globalNavConfig': {'header': 'commerce-header',
#      'footer': 'footer',
#      'shared': 'shared',
#      'testHeader': 'commerce-header',
#      'testFooter': 'footer',
#      'testShared': 'shared'},
#     'optimizelyEndpoint': '//www.nike.com/assets/vendor/optimizely/prod/5aUCtZvFuDLjvdqdf2w53M.json',
#     'turnToConfig': {'turnToFetchTimeout': 350,
#      'turnToAuthBucket': 'shared/turnto/prod-auth-keys'},
#     'exp': '2011'},
#    'Console': {'providers': []},
#    'CrossSell': {'products': [], 'error': None, 'async': {'products': False}},
#    'Auth': {'bearer': ''},
#    'Experiments': {'activeExperiments': {}, 'forcedExperiments': {}},
#    'Launch': {'launchCheckoutModalOpen': False,
#     'launchCheckoutServices': 'launch-checkout'},
#    'MAPProducts': {'products': {}},
#    'Privacy': {'areSocialCookiesAllowed': False,
#     'arePerformanceCookiesAllowed': False,
#     'geoLoc': None,
#     'hasEUCookie': False},
#    'Device': {'breakpointMatched': False, 'deviceWidth': 'sm'},
#    'Overlays': [],
#    'Common': {'channel': 'NIKE',
#     'connection': {'saveData': False, 'effectiveType': None},
#     'globalHeaderFixedHeight': 60,
#     'globalHeaderHeight': 96,
#     'pageType': 'pdp',
#     'routes': [],
#     'siteHost': 'https://www.nike.com'},
#    'META': {'commit': ''},
#    'NOTIFY_ME': {'isNotifyMeModalOpen': False,
#     'page': 'default',
#     'journey': '',
#     'isNotifyMeSMSOpen': False,
#     'isNotifyMeEmailOpen': False,
#     'emailJourneyCompleted': False,
#     'smsJourneyCompleted': False,
#     'email': '',
#     'sms': ''},
#    'intl': {}}},
#  '__N_SSP': True}

# %%
json_object['props'].keys()
# Out:
# dict_keys(['pageProps', '__N_SSP'])

# %%
# for i in json_object['props'].keys():
#     print(i,"\n\n\n",json_object['props'][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']
# Out:
# {'initialState': {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#     'titleTemplate': '%s',
#     'meta': [{'name': 'description',
#       'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#      {'name': 'keywords', 'content': 'Nike Free Metcon 4 Training Shoes'},
#      {'name': 'robots', 'content': 'index, follow'},
#      {'property': 'og:title',
#       'content': 'Nike Free Metcon 4 Training Shoes. Nike.com'},
#      {'property': 'og:description',
#       'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#      {'property': 'og:type', 'content': 'website'},
#      {'property': 'og:url',
#       'content': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'},
#      {'property': 'og:image',
#       'content': 'https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png'},
#      {'property': 'og:locale', 'content': 'en_US'},
#      {'property': 'og:site_name', 'content': 'Nike.com'},
#      {'property': 'og:price:currency', 'content': 'USD'},
#      {'property': 'og:price:amount', 'content': 120},
#      {'name': 'branch:deeplink:$deeplink_path',
#       'content': 'x-callback-url/product-details?style-color=CT3886-004'},
#      {'property': 'fb:app_id', 'content': '1397260880304609'}],
#     'title': 'Nike Free Metcon 4 Training Shoes. Nike.com',
#     'link': [{'rel': 'canonical',
#       'href': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'}]}},
#   'reviews': {'country': 'us',
#    'apiversion': None,
#    'sorts': {'SubmissionTime': True},
#    'productStyleCode': 'CT3886',
#    'total': 0,
#    'averageRating': 0,
#    'recommendedCount': 0,
#    'reviews': [],
#    'dimensions': [],
#    'reviewsMap': {},
#    'initialFetched': False,
#    'initialFetching': False,
#    'initialFetchError': False,
#    'fetched': False,
#    'fetching': False,
#    'fetchError': False,
#    'positiveFeedbackSubmitting': {},
#    'positiveFeedbackSubmitted': {},
#    'positiveFeedbackSubmitError': {},
#    'negativeFeedbackSubmitting': {},
#    'negativeFeedbackSubmitted': {},
#    'negativeFeedbackSubmitError': {},
#    'inappropriateFeedbackSubmitting': {},
#    'inappropriateFeedbackSubmitted': {},
#    'inappropriateFeedbackSubmitError': {},
#    'isDrawerOpen': False,
#    'reviewsDrawerType': 'view',
#    'currentReviewId': '',
#    'summary': {'total': 0,
#     'limit': 0,
#     'averageRating': 0,
#     'recommendedCount': 0,
#     'reviews': [],
#     'secondaryRatingsOrder': [],
#     'bestRating': 5,
#     'worstRating': 1},
#    'vendor': 'VENDOR/TURN_TO',
#    'serverSideFetched': False,
#    'serverSideFetching': True,
#    'serverSideFetchError': False},
#   'localization': {'urlParam': 'en',
#    'language': 'en',
#    'intl': 'en-US',
#    'langRegion': 'en-US',
#    'hreflang': 'en-US',
#    'default': True,
#    'country': 'us',
#    'countryName': 'United States',
#    'currency': 'USD',
#    'reactIntl': '',
#    'merchGroup': 'US',
#    'messages': {'91330387': 'Name of wishlist is not unique.',
#     'JP.discount_addendum': 'Sale Price',
#     'browse_crossSellPopItemLowerCase': 'These popular items might interest you',
#     'browse_fallback_message': "The page you were viewing was experiencing technical difficulties and we're working to resolve it. A quick refresh should get you back in play. Apologies for the inconvenience.",
#     'browse_fallback_refresh_button': 'Refresh Now',
#     'browse_fallback_title': 'Short time out needed',
#     'browse_noMatchesFound': 'No matches found.',
#     'browse_pleaseTryAnotherSearch': 'Please try another search.',
#     'hf-geomismatch-chooseLocation': 'Choose Location',
#     'hf-geomismatch-confirm': 'Confirm',
#     'hf-geomismatch-message': 'Update your location to shop products available in {country}',
#     'hf-geomismatch-prompt': 'We think you are in {country}. Update your location?',
#     'hf-geomismatch-title': 'Confirm your Location',
#     'hf-geoselection-title': 'Select your Location',
#     'hf-header-label-carticon': 'Bag Items',
#     'hf-header-label-countryicon': 'Selected Location',
#     'hf_close_menu_aria_label': 'Close Menu',
#     'hf_cookie-policy_banner_ok': 'OK',
#     'hf_cookie_label_cookieSettings': 'Cookie Settings',
#     'hf_cookie_label_done': 'Done',
#     'hf_cookie_label_functional': 'Functional',
#     'hf_cookie_label_performance': 'Performance',
#     'hf_cookie_label_privacyPolicy': 'Privacy & Cookie Policy',
#     'hf_cookie_label_socialMedia': 'Social Media and Advertising',
#     'hf_cookie_label_yourCookieSettings': 'Your Cookie Settings',
#     'hf_cookie_policy_banner': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {privacyAndCookiePolicyHTML}. You can adjust your preferences in {cookieSettingsHTML}.',
#     'hf_cookie_policy_banner_ok': 'OK',
#     'hf_cookie_text_cookieAccept': 'Yes, I Accept',
#     'hf_cookie_text_cookieReject': "No, I Don't Accept",
#     'hf_cookie_text_do_you_accept': 'Do you accept these cookies and the processing of personal data involved?',
#     'hf_cookie_text_footer': 'You can always change your preference by visiting the "Cookie Settings" at the bottom of the page. View {privacyAndCookiePolicyHTML} for full details.',
#     'hf_cookie_text_functional': 'These cookies are required for basic site functionality and are therefore always enabled. These include cookies that allow you to be remembered as you explore the site within a single session or, if you request, from session to session. They help make the shopping cart and checkout process possible as well as assist in security issues and conforming to regulations.',
#     'hf_cookie_text_information': 'Privacy & Cookie Policy',
#     'hf_cookie_text_moreInformation': 'More Information',
#     'hf_cookie_text_performance': 'These cookies allow us to improve the siteâ\x80\x99s functionality by tracking usage on this website. In some cases these cookies improve the speed with which we can process your request, allow us to remember site preferences youâ\x80\x99ve selected. De-selecting these cookies may result in poorly-tailored recommendations and slow site performance.',
#     'hf_cookie_text_policy': 'Nike asks you to accept cookies for performance, social media and advertising purposes. Social media and advertising cookies of third parties are used to offer you social media functionalities and personalized ads. To get more information or amend your preferences, press the â\x80\x98more informationâ\x80\x99 button or visit "Cookie Settings" at the bottom of the website. To get more information about these cookies and the processing of your personal data, check our {privacyAndCookiePolicyHTML}. Do you accept these cookies and the processing of personal data involved?',
#     'hf_cookie_text_socialMedia': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#     'hf_cookie_text_socialMedia_2': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#     'hf_cookie_title_cookieSettings': 'Your Cookie Settings',
#     'hf_fallback_account': 'Account',
#     'hf_header_find_a_store': 'Find a Store',
#     'hf_header_label_acceptedPaymentTypes': 'Accepted Payment Types',
#     'hf_header_label_account': 'Account',
#     'hf_header_label_bag': 'Bag',
#     'hf_header_label_closeSearch': 'Close Search',
#     'hf_header_label_copyright': 'Â© 2023 Nike, Inc. All Rights Reserved',
#     'hf_header_label_favorites': 'Favorites',
#     'hf_header_label_help': 'Help',
#     'hf_header_label_hurleyLogo': 'Hurley Home Page',
#     'hf_header_label_joinOrLogin': 'Join/Log In To Nike Member Profile',
#     'hf_header_label_liveChat': 'Live Chat',
#     'hf_header_label_myAccount': 'My Account',
#     'hf_header_label_nikeSwooshLogo': 'Nike Home Page',
#     'hf_header_label_orders': 'Orders',
#     'hf_header_label_popular_search_terms': 'Popular Search Terms',
#     'hf_header_label_resetSearch': 'Reset Search',
#     'hf_header_label_search': 'Search',
#     'hf_header_label_search_input': 'Search Products',
#     'hf_header_label_search_open': 'Open Search Modal',
#     'hf_header_label_search_topSuggestions': 'Top Suggestions',
#     'hf_header_label_secondaryNavigation': 'Secondary Navigation',
#     'hf_header_label_selectACountry': 'Selected Location',
#     'hf_label_avatar': 'Avatar',
#     'hf_logo_converse': 'Converse Logo',
#     'hf_logo_jordan': 'Jordan Logo',
#     'hf_menu_aria_label': 'menu',
#     'hf_message_join_membership': 'Become a Nike Member for the best products, inspiration and stories in sport. {learnMore}',
#     'hf_message_join_nikeplus': 'Join Us to enjoy the best of Nike Membership with our family of apps, free shipping, access to coaching, global events and more.',
#     'hf_popular_search_gifts': 'Gifts',
#     'hf_search_cancel': 'Cancel',
#     'hf_skip_to_content': 'Skip to main content',
#     'hf_title_all_menuitem': 'All',
#     'hf_title_greeting_membership': 'Hi, {name}',
#     'hf_title_greeting_membership_a11y': 'Hi, {name}. Account & Favorites',
#     'hf_title_join_nikeplus': 'SIGN IN / JOIN US',
#     'hf_title_joinus_membership': 'Join Us',
#     'hf_title_learnmore_membership': 'Learn more',
#     'hf_title_signin_membership': 'Sign In',
#     'hf_visual_search_no_product_found': 'No product suggestions found for {query}',
#     'hf_visual_search_title': 'TOP SUGGESTIONS',
#     'hf_visual_search_viewall': 'View All',
#     'pdp_NBYCustomize': 'Customize',
#     'pdp_buying_tools_add_to_wishlist': 'Favorite',
#     'pdp_crosssell_buy_now': 'Buy Now',
#     'pdp_crosssell_cart_title': 'YOU MIGHT ALSO LIKE',
#     'pdp_crosssell_color': 'Color',
#     'pdp_crosssell_colors': 'Colors',
#     'pdp_crosssell_customize': 'Customize',
#     'pdp_crosssell_first_ordinal_indicator': 'st',
#     'pdp_crosssell_jersey_title': 'GET THE ULTIMATE',
#     'pdp_crosssell_jerseykids_title': 'GET THE ULTIMATE',
#     'pdp_crosssell_nfl_teams_available': 'All NFL Teams Available',
#     'pdp_crosssell_nfl_title': 'GET THE ULTIMATE',
#     'pdp_crosssell_nfl_title_suffix': 'HOOKUP',
#     'pdp_crosssell_nikeid_button': 'Shop All Nike By You',
#     'pdp_crosssell_nikeid_customize': 'CUSTOMIZE YOUR OWN WITH NIKE BY YOU',
#     'pdp_crosssell_nikeid_title': 'YOU MIGHT ALSO LIKE',
#     'pdp_crosssell_nikeid_url': 'http://www.nike.com/us/en_us/c/nikeid',
#     'pdp_crosssell_options': 'Options',
#     'pdp_crosssell_player_available': 'Player Available',
#     'pdp_crosssell_players_available': 'Players Available',
#     'pdp_crosssell_second_ordinal_indicator': 'nd',
#     'pdp_crosssell_shop_all_nikeid': 'SHOP ALL NIKE BY YOU',
#     'pdp_crosssell_third_ordinal_indicator': 'rd',
#     'pdp_crosssell_title': 'YOU MIGHT ALSO LIKE',
#     'pdp_crosssell_top_kids_products': 'TOP KIDSâ\x80\x99 PRODUCTS',
#     'pdp_crosssell_top_mens_products': 'TOP MENâ\x80\x99S PRODUCTS',
#     'pdp_crosssell_top_womens_products': 'TOP WOMENâ\x80\x99S PRODUCTS',
#     'pdp_crosssell_widths_available': 'Widths Available',
#     'pdp_nikeid_thumbnail_alt_text': 'Design your own Nike By You product',
#     'pdp_remove_customized_jersey': 'Remove',
#     'seePriceInCart': 'See Price in Bag',
#     'sub_footer_business_information_link_text': 'Business information confirmation',
#     'sub_footer_business_information_text': '(U) Nike Korea CEO Kimberlee Lynn Chang Mendes | 30th floor, Gangnam Finance Center, 152 Teheran-ro, Gangnam-gu, Seoul | Mail order distributor number 2011-Seoul Gangnam-03461 | Business registration number {phone}',
#     'sub_footer_businness_company_text': 'deposit payment',
#     'sub_footer_customer_service_text': 'Customer service phone number {phone} FAX {fax} | Email: {email} | Hosting service provider (U) Nike Korea',
#     'sub_footer_legal_info_link_text': 'Read more',
#     'sub_footer_legal_info_text': 'Information on content protection under the Content Industry Promotion Act.',
#     'sub_footer_modal_body_text': 'Name of content: product information, event information, etc.\nDate of creation of the content: cut-over date (or its update date if the content has been upgraded).\nAll content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent).',
#     'sub_footer_modal_body_text_one': 'Name of content: product information, event information, etc',
#     'sub_footer_modal_body_text_three': 'All content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent)',
#     'sub_footer_modal_body_text_two': 'Date of creation of the content: October 05, 2022 (or its update date if the content has been upgraded)',
#     'sub_footer_modal_title': 'Indication under the Content Industry Promotion Act',
#     'sub_footer_payment_information_text': 'For safe transactions, when paying with cash, etc., \u2028you can use the purchase safety service ({company}) of Korea Payment Network Co., Ltd., which you signed up for in our shopping mall.',
#     'test': 'testing',
#     '04E2F5C8': 'Sorry, the resource you requested does not exist.',
#     '15E57A07': 'Sorry, we had an issue with your request.  Please try again.',
#     '2DA19B6C': 'Sorry, you have reached the quantity limit.  Please remove an item and try again. ',
#     '3534E689': 'Sorry, the product you have selected is not available at this time.',
#     '36A1E761': 'Sorry, we do not recognize the postal code you entered. Please try entering a different postal code.',
#     '3F7B9831': 'Sorry, we couldnâ\x80\x99t process your request because your browser has too many cookies. Clear your cookies and try again.',
#     '49780BED': 'Unable to reach Partner',
#     '4C5FB5DF': 'Maximum wishlist items exceeded.',
#     '4CB0532B': 'Sorry, the code entered is incorrect or invalid. Please try again, or enter another code.',
#     '6BD7E72A': 'Maximum wishlists per user exceeded.',
#     '7E977FCE': 'Sorry, the product you have selected is not available at this time.',
#     '840D5CFE': 'Country not currently supported',
#     '8B2AE0A4': 'The resource you requested does not exist.',
#     '9008921A': 'Product already added to wishlist.',
#     '97AE3B36': 'We are temporarily experiencing site issues. If unable to complete your purchase, please try again later.',
#     'A044DD39': 'Sorry, this code could not be applied. Please review the criteria to qualify for this promotion.',
#     'A553CABC': 'Your item total has exceeded the $1000.00 checkout limit. Please remove a few items and try again.',
#     'A954F3EE': 'Offer invalid',
#     'AA33FB74': 'Sorry, the product you have selected is not available at this time. ',
#     'ABB4C446': 'Sorry, you have reached the quantity limit. Please remove an item and try again. ',
#     'AE66C4E0': 'Sorry, this code is expired. Please try another code.',
#     'B2D8D9B5': 'Sorry, we had an issue with your request.  Please try again.',
#     'B9671077': 'Sorry, the product you have selected is not available at this time.',
#     'C4CD1584': 'Offer invalid',
#     'CF1877FC': 'Failed to make Reservation with Inventory System.',
#     'D2A6EE25': 'The given country code is not in the valid list.',
#     'D403D4AD ': 'One or More Items Unavailable. Please remove one or more items from your Bag, refresh and try again.',
#     'DAD5D797': 'Sorry, the product you have selected is not available at this time. ',
#     'E2E82F65': 'The field value is invalid',
#     'E37BAB4': 'Sorry, the price of the Gift Card is invalid. ',
#     'AE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'AT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'AU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'BE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'BG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'BR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'BR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'CA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'CH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'CL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'CN.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'CN.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'CN.NikeCom_PDP_Suffix': '-Nike China official website',
#     'CN.NikeCom_Suffix': '-Nike China official website',
#     'CN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'CZ.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'CZ.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'CZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'DE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com.  ',
#     'DE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'DE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'DK.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'DK.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'DK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'EG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'ES.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'ES.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'ES.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'FI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'FR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'FR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'FR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'GB.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'GB.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#     'GB.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'GR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'GR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'GR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'HR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'HU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'HU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'HU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'HurleyCom_Wall_SEO_Title_Suffix': '. Hurley.com',
#     'ID.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'IE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'IL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'IN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'IT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'IT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'IT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'JP.NikeCom_PDP': '',
#     'JP.NikeCom_PDP_Prefix': '',
#     'JP.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'JP.NikeCom_PDP_SEO_Desc2': 'Try-on within 30 days can be returned (except some products). [Free shipping for Nike members anytime]',
#     'JP.NikeCom_PDP_Suffix': '. Nike JP',
#     'JP.NikeCom_Prefix': '',
#     'JP.NikeCom_Suffix': '. Nike JP',
#     'JP.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'JP.NikeCom_Wall_SEO_Title_Suffix': '. Nike JP',
#     'KR.NikeCom_Suffix': '. Nike KR',
#     'KR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'KR.NikeCom_Wall_SEO_Title_Suffix': '. Nike KR',
#     'LU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'MA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'MX.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'MY.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'NL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'NL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'NL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'NO.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'NO.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'NO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'NZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#     'NikeCom_PDP_SEO_Keywords': '{Product_Full_Title}',
#     'NikeCom_PDP_SEO_Title': '{NikeCom_Prefix}{Product_Full_Title}{NikeCom_Suffix}',
#     'NikeCom_PDP_Suffix': '. Nike.com',
#     'NikeCom_Suffix': '. Nike.com',
#     'NikeCom_Wall_SEO_Keywords': '{TITLE}',
#     'NikeCom_Wall_SEO_Title': '{TITLE}',
#     'NikeCom_Wall_SEO_Title_Default': 'Products',
#     'NikeCom_Wall_SEO_Title_Suffix': '. Nike.com',
#     'PH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'PL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'PL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'PL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'PR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'PT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'PT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'PT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'RO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'RU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'RU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'RU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'SA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'SE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'SE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'SE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'SG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'SI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'SK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'TH.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'TH.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'TH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'TR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'TR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'TR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'TW.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'TW.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#     'TW.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'US.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#     'US.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#     'US.NikeCom_PDP_Suffix': '. Nike.com',
#     'US.NikeCom_Suffix': '. Nike.com',
#     'US.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'VN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#     'ZA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#     'DE.pdp_vat_message': '<div> Prices incl. VAT and plus delivery costs. You can find details of shipping costs <a href = "https://www.nike.com/help/a/shipping-delivery" class = "exp-pdp-tc-disclaimer-url "> here </a> </ div>',
#     'FR.pdp_recycle_message': 'This product may be recyclable. <a href="https://www.nike.com/fr/help/a/triman"> Learn more </a>',
#     'JP.tax_addendum': '(Tax Incl.)',
#     'US.pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#     'US.pdp_standardShipping': 'Standard / Arrives 2-4 Business Days',
#     'US.pdp_twoDayShipping': 'Two-Day / Arrives 2-3 Business Days',
#     'crossell.certona.all-nfl-teams-available': 'All NFL Teams Available',
#     'crossell.certona.buy-now': 'Buy Now',
#     'crossell.certona.cart_rr': 'You Might Also Like ',
#     'crossell.certona.color-plural': 'Colors',
#     'crossell.certona.color-singular': 'Color',
#     'crossell.certona.error4041_rr': 'TOP MENâ\x80\x99S PRODUCTS',
#     'crossell.certona.error4042_rr': 'TOP WOMENâ\x80\x99S PRODUCTS',
#     'crossell.certona.error4043_rr': 'TOP KIDSâ\x80\x99 PRODUCTS',
#     'crossell.certona.first-option': 'st',
#     'crossell.certona.inactivepdp1_rr': 'THESE POPULAR PRODUCTS MIGHT INTEREST YOU',
#     'crossell.certona.inactivepdp2_rr': 'CUSTOMIZE YOUR OWN WITH NIKEiD',
#     'crossell.certona.nflbuilderpdp_rr': 'GET THE ULTIMATE',
#     'crossell.certona.nfljerseykidspdp_rr': 'GET THE ULTIMATE',
#     'crossell.certona.nfljerseypdp_rr': 'GET THE ULTIMATE',
#     'crossell.certona.nflpdp_rr_suffix': 'HOOKUP',
#     'crossell.certona.nikeid-button': 'Shop All NIKEiD',
#     'crossell.certona.nikeid-text': 'Customize',
#     'crossell.certona.nikeid-url': 'http://www.nike.com/us/en_us/c/nikeid',
#     'crossell.certona.nikeidpdp_rr': 'You Might Also Like',
#     'crossell.certona.nosearch1_rr': 'SHOP ALL NIKEiD',
#     'crossell.certona.nosearch2_rr': '&nbsp;',
#     'crossell.certona.options': 'Options',
#     'crossell.certona.pdp.crosssell.nikeid': 'CUSTOMIZE',
#     'crossell.certona.player-plural': 'Players Available',
#     'crossell.certona.player-singular': 'Player Available',
#     'crossell.certona.playerNamesAvailable': 'Players available',
#     'crossell.certona.product_rr': 'You Might Also Like',
#     'crossell.certona.purchase_rr': '(purchase_rr) REPLACE THIS VALUE IN HtmlLocalValueBundle.properties!',
#     'crossell.certona.second-option': 'nd',
#     'crossell.certona.third-option': 'rd',
#     'crossell.certona.widths-available': 'Widths Available',
#     'pdp_3rdParty_Overseas_Transfer_PI': '3rd Party and Overseas Transfer of Personal Information',
#     'pdp_Collection_Use_PI': ' the collection and use of personal information',
#     'pdp_I_Agree_To': 'I agree to',
#     'pdp_NBYAvailableFor': 'Available For',
#     'pdp_NBYButtonTitle': 'Customize',
#     'pdp_NBYColorChipLabel': 'Design Your Own',
#     'pdp_NBYCustomDesignTab': 'Your Designs',
#     'pdp_NBYDesignTabs': 'Designs',
#     'pdp_NBYInspirationTab': 'Inspiration',
#     'pdp_NBYShareYourDesign': 'Share Your Design',
#     'pdp_NBYSoldOut': 'Sold Out',
#     'pdp_NBYYourDesignTxt': "Choose 'Customize' to add a design",
#     'pdp_NotifyMeButtonTitle': 'Notify Me',
#     'pdp_NotifyMeCancel': 'Cancel',
#     'pdp_NotifyMeDefaultEmailAddressText': 'Email Address',
#     'pdp_NotifyMeDone': 'Done',
#     'pdp_NotifyMeEmailOptInMessage': 'Send me news and offers from Nike',
#     'pdp_NotifyMeInvalidEmail': 'Please enter a valid email.',
#     'pdp_NotifyMeLegalText': '{privacyLinkText} and {termsOfUseLinkText}',
#     'pdp_NotifyMeModalBody': 'Get a one-time email alert the moment this product drops',
#     'pdp_NotifyMeModalLegalLinkJoin': 'and',
#     'pdp_NotifyMeModalPrivacyPolicyLinkText': 'Privacy Policy',
#     'pdp_NotifyMeModalTermsOfUseLinkText': 'Terms of Use',
#     'pdp_NotifyMeModalTitle': "Don't Miss Out",
#     'pdp_NotifyMeOk': 'Ok',
#     'pdp_NotifyMeOkModalTitle': "You're on the List",
#     'pdp_NotifyMeServerError': 'There was an error creating this notification.  Please try again later.',
#     'pdp_NotifyMeSubmit': 'Submit',
#     'pdp_NotifyMeThanks': "We'll send a one-time email to {email} when this product drops.",
#     'pdp_NotifyMe_AddAPhoneNumber': 'Add a phone number to get notified',
#     'pdp_NotifyMe_AddAnEmail': 'Add an email address to get notified',
#     'pdp_NotifyMe_And': 'and',
#     'pdp_NotifyMe_ConsentRefusal': 'You may refuse to consent, in which case you will not be able to receive information about Nike product releases. Nike is not responsible if the notification message fails to deliver.',
#     'pdp_NotifyMe_DefaultHeaderSubtitle': 'Get a one-time notification when this product drops.',
#     'pdp_NotifyMe_EmailHeaderSubtitle': 'Enter your email to receive a one-time notification',
#     'pdp_NotifyMe_EmailHeaderTitle': 'Add your email address.',
#     'pdp_NotifyMe_MemberEmailSendTo': 'Send an email to',
#     'pdp_NotifyMe_NotifyWithEmail': 'Notify with email',
#     'pdp_NotifyMe_NotifyWithSMS': 'Notify with SMS',
#     'pdp_NotifyMe_OverseasTransfer': 'I agree to <a href="{infoTransferLink}">3rd Party and Overseas Transfer of Personal Information</a>',
#     'pdp_NotifyMe_PersonalInfo': 'I agree to the <a href="{infoCollectionLink}">collection and use of personal information</a>',
#     'pdp_NotifyMe_PrivacyPolicyLegal': 'I agree to Nikeâ\x80\x99s <a href="{privacyPolicyLink}">Privacy Policy</a> and <a href="{termsOfUseLink}">Terms of Use</a>',
#     'pdp_NotifyMe_SMSHeaderTitle': 'Add your mobile phone number.',
#     'pdp_NotifyMe_SendEmailTo': "We'll send an email to",
#     'pdp_NotifyMe_SendSMSTo': 'Weâ\x80\x99ll send an SMS to',
#     'pdp_NotifyMe_TermsOfUseLegal': 'I agree to Nikeâ\x80\x99s <a href="{termsOfUseLink}">Terms of Use</a>',
#     'pdp_NotifyMe_YouAreAllSet': "You're all set!",
#     'pdp_NotifyMe_title': "Don't Miss Out",
#     'pdp_PageNotFoundMessage': 'WE CANâ\x80\x99T FIND THE PAGE YOU ARE LOOKING FOR',
#     'pdp_RFYNotAuthorized': 'Sorry, this product is not reserved for you.',
#     'pdp_RFYProductExpiredOn': 'Expired on {expiredOn}',
#     'pdp_RFYProductRedeemedOn': 'Redeemed on {redeemedOn}',
#     'pdp_RFYRedeemProduct': 'Redeem',
#     'pdp_RFYSubtitle': 'Reserved for You',
#     'pdp_SeeMoreProducts': 'See More',
#     'pdp_SimilarStyles': 'Similar Styles',
#     'pdp_a11y_aria_choose_a_style_color': 'Choose a Style Color',
#     'pdp_a11y_avg_star_rating': 'Average Rating {rating} of {starCount}',
#     'pdp_addToCart': 'Add to Bag',
#     'pdp_addToCartErrorLabel': 'Error:',
#     'pdp_addToCartErrorText': 'This request timed out, please try again',
#     'pdp_addToWishlist': 'Add to Favorites',
#     'pdp_addedToCart': 'Added to Bag',
#     'pdp_addedToWishlist': 'Added to Favorites',
#     'pdp_additionalInfo': 'More Info',
#     'pdp_allProductsSoldOutMessage': 'This product is currently unavailable',
#     'pdp_also_includes_all_applicable_duties': 'Also includes all applicable duties',
#     'pdp_arrivesDate': 'Arrives',
#     'pdp_back': 'Back',
#     'pdp_bopisShipping': 'Shipping',
#     'pdp_button_close': 'Close',
#     'pdp_cartAndCheckout': 'Bag & Checkout',
#     'pdp_cartQuantity': 'Qty 1',
#     'pdp_check_back_soon_label': 'Check back soon.',
#     'pdp_check_back_soon_message': 'Unfortunately we are not able to fulfill orders in this country at this time. Please check back for future availability. ',
#     'pdp_checkout': 'Checkout',
#     'pdp_chooseSize': 'Select Size',
#     'pdp_closeDialogButtonLabel': 'Close this dialog window',
#     'pdp_cloudAddToCartError': 'An error has occurred: ',
#     'pdp_comingSoon': 'Coming Soon',
#     'pdp_continueShopping': 'Continue Shopping',
#     'pdp_cookie_banner_message': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {PrivacyPolicy}. You can adjust your preferences in {CookieSettings}.',
#     'pdp_cookie_settings': 'Cookie Settings',
#     'pdp_copyLink': 'Copy Link',
#     'pdp_copyLinkConfirmation': 'Copied',
#     'pdp_countdownDay': 'd',
#     'pdp_countdownHour': 'h',
#     'pdp_countdownMinute': 'm',
#     'pdp_countdownSecond': 's',
#     'pdp_country_of_origin': 'Country/Region of Origin:',
#     'pdp_currentlyUnavailable': 'Currently Unavailable',
#     'pdp_default_title': 'Nike Store. Shoes, Clothing & Gear.',
#     'pdp_estimateShippingTime': 'Estimate Shipping Time',
#     'pdp_fasterShippingOptions': 'Faster Shipping options may be available',
#     'pdp_feedbackText': 'Your input will help us create an even better shopping experience for you.',
#     'pdp_fitPrivacyHeader': 'Privacy',
#     'pdp_fitPrivacyModalCloseBtn': 'Close',
#     'pdp_fitPrivacyModalContent': '<h1>Your Privacy</h1>\n<ul>\n<li>Nike partners with <a href="https://www.fitanalytics.com/" target="_blank"><strong>Fit Analytics</strong></a> to recommend sizes on <a href="https://www.nike.com/" target="_blank">Nike.com</a>.</li><li>To help make those recommendations, <strong>Nike uses performance</strong> cookies and the information you provide.</li><li>Nike shares <strong>deidentified information</strong> with Fit Analytics to help improve size recommendations.</li><li>Nike only has access to general Fit Analytics statistics.</li>\n</ul>',
#     'pdp_fitSize': 'Your Nike Fit is',
#     'pdp_fit_opinion_runs_big': 'Runs Big',
#     'pdp_fit_opinion_runs_consistently_big': 'Customers who reviewed this product say it runs big.',
#     'pdp_fit_opinion_runs_consistently_small': 'Customers who reviewed this product say it runs small.',
#     'pdp_fit_opinion_runs_small': 'Runs Small',
#     'pdp_fit_opinion_runs_sometimes_big': 'Customers who reviewed this product say it runs slightly big.',
#     'pdp_fit_opinion_runs_sometimes_small': 'Customers who reviewed this product say it runs slightly small.',
#     'pdp_fit_opinion_runs_true': 'Customers who reviewed this product say it runs true to size.',
#     'pdp_freeShipping': 'Free Shipping with Nike Membership',
#     'pdp_gcChooseAnAmount': 'Choose an amount',
#     'pdp_gcColorwayTitle': 'Choose a design',
#     'pdp_gcCustomAmount': 'Custom amount:',
#     'pdp_gcCustomAmountMaxValueError': 'Gift card amount cannot exceed {maxValue}',
#     'pdp_gcCustomAmountMinValueError': 'Gift card amount must be at least {minValue}',
#     'pdp_gcCustomAmountRestrictedCharacterError': 'This contains a restricted character, please choose another.',
#     'pdp_gcDeliveryDetailsLink': 'Enter address',
#     'pdp_gcDeliveryDetailsText': "Let us know where it's going. ",
#     'pdp_gcDeliveryDetailsTitle': 'Add recipient delivery details',
#     'pdp_gcDeliveryMethod': 'Choose a delivery method',
#     'pdp_gcDeliveryMethodEmail': 'Email',
#     'pdp_gcDeliveryMethodMail': 'Mail',
#     'pdp_gcDigitalAddressEditButton': 'Edit',
#     'pdp_gcEmailInput': 'Email',
#     'pdp_gcLargeOrderButton': 'Need a Larger Order?',
#     'pdp_gcLargeOrderModalEmailLink': 'giftcards@nike.com',
#     'pdp_gcLargeOrderModalMainText': 'Just e-mail {emailLink} for more information or call Nike directly at 1-877-220-6453 for assistance. You will receive a reply or call-back during Nike corporate business hours (Monday through Friday, 8 AM â\x80\x93 5 PM Pacific Time, excluding holiday). Please do not send credit card information over email.',
#     'pdp_gcLargeOrderModalSubTitle': 'Need to order more than 10 cards or to put in an order totaling more than $5,000?',
#     'pdp_gcLargeOrderModalTitle': 'Need to Place a Larger Order?',
#     'pdp_gcNoPOBox': 'We do not deliver to P.O. Boxes',
#     'pdp_gcOptionalMessageErrorText': 'Your message is invalid, please try again.',
#     'pdp_gcOptionalMessageLabel': 'Add an optional message',
#     'pdp_gcOptionalMessageText': 'Enter a personalized message for the recipient.',
#     'pdp_gcQuantity': 'Quantity',
#     'pdp_gcRecipientAddress': 'Address',
#     'pdp_gcRecipientAddress2': 'Add Company, C/O, Apt, Suite, Unit (Optional)',
#     'pdp_gcRecipientAddressError': "Please enter recipient's address.",
#     'pdp_gcRecipientCity': 'City',
#     'pdp_gcRecipientCityError': "Please enter recipient's city.",
#     'pdp_gcRecipientEmailAddress': 'Email',
#     'pdp_gcRecipientEmailAddressError': 'Please enter a valid email address.',
#     'pdp_gcRecipientEmailError': 'Please enter a valid email address.',
#     'pdp_gcRecipientFirstName': 'First Name',
#     'pdp_gcRecipientFirstNameError': "Please enter recipient's first name.",
#     'pdp_gcRecipientLastName': 'Last Name',
#     'pdp_gcRecipientLastNameError': "Please enter recipient's last name.",
#     'pdp_gcRecipientState': 'State',
#     'pdp_gcRecipientStateError': "Please select recipient's state.",
#     'pdp_gcRecipientZip': 'Postal Code',
#     'pdp_gcRecipientZipError': 'Please enter a valid zip code.',
#     'pdp_gcStateDropdownTitle': 'Select a State',
#     'pdp_gcTCLink': 'Gift Card Terms and Conditions',
#     'pdp_gender_men': 'Men',
#     'pdp_gender_women': 'Women',
#     'pdp_gift_description': 'Send as an E-Gift',
#     'pdp_gift_link_message': 'Send Now',
#     'pdp_gift_message': 'You choose the gift, they choose the size and color.',
#     'pdp_gift_tooltip': "Send this item instantly, by email. They'll choose size and color, or use the gift value towards another Nike.com purchase.",
#     'pdp_helpUsImproveYourExperience': 'Help Us Improve Your Experience',
#     'pdp_highly_rated': 'Highly Rated',
#     'pdp_howItFits': 'How it Fits',
#     'pdp_incl_of_taxes': 'incl. of taxes',
#     'pdp_include_of_taxes_and_duties': 'incl. of taxes and duties',
#     'pdp_just_a_few_left_order_soon': 'Just a few left. Order soon.',
#     'pdp_just_a_few_left_order_soon_kr': 'Almost sold out. Order soon.',
#     'pdp_keepShopping': 'Keep Shopping',
#     'pdp_klarna_message': 'Buy now, pay in 3 installments with <span>Klarna</span>',
#     'pdp_klarna_message_short': '<span>Klarna</span> Available at checkout.',
#     'pdp_launchAvailableDate': 'Available {Launch_Date} at {Launch_Time}',
#     'pdp_launchBuyCTA': 'Buy',
#     'pdp_launchBuyableGuestIntro': 'Only Nike Members get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#     'pdp_launchBuyableMemberIntro': 'Only Nike Members like you get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#     'pdp_launchCSGuestIntro': "Create or sign in to your free Nike Member account for a chance to buy this product the moment it's released. {learnMoreButtonText}",
#     'pdp_launchCSMemberIntro': "Nike Members like you are the only ones who have a chance to purchase this product when it's released. {learnMoreButtonText}",
#     'pdp_launchCheckoutErrorBody': 'There was a problem processing your payment.  Check your payment information and try again.',
#     'pdp_launchCheckoutErrorTitle': "Let's try this again.",
#     'pdp_launchCheckoutNotLoggedIn': 'Your session has expired.  Please refresh and login to continue.',
#     'pdp_launchCheckoutNumberNotVerified': 'Your session has expired.  Please refresh and login to continue.',
#     'pdp_launchComingSoon': 'Coming Soon',
#     'pdp_launchComingSoonStepOne': '1. Sign in to your Nike Member account or {joinButtonText}',
#     'pdp_launchComingSoonStepThree': '3. Verify your mobile number in account settings.',
#     'pdp_launchComingSoonStepTwo': '2. Confirm your payment info is updated. ',
#     'pdp_launchDismissModalButton': 'Continue Shopping',
#     'pdp_launchFirstParagraphComingSoon': "Introducing Line Checkout. Come back after a Product is available to get in line. If your turn comes up, we'll complete your order. Before getting in line, make sure you:",
#     'pdp_launchFirstParagraphGetInLine': "Line Checkout is the only way to buy some of our most popular products - like this one. Once you're in line and your turn comes up, we'll complete your order. ",
#     'pdp_launchGetInLine': 'Get in Line',
#     'pdp_launchGetInLineTitle': 'Get in Line. Get the goods.',
#     'pdp_launchInLineBodyModal': "If your turn comes up, we'll complete your order. ",
#     'pdp_launchJoinForFreeButton': 'join for free.',
#     'pdp_launchLMModalBePreparedBullet': 'Be prepared',
#     'pdp_launchLMModalBePreparedSubBullet': "Make sure you're signed in to your Nike Member account and ready when the product launches.",
#     'pdp_launchLMModalContinueShoppingCTA': 'Continue Shopping',
#     'pdp_launchLMModalFirstTitle': 'How Line Checkout Works',
#     'pdp_launchLMModalGuestJoinBullet': 'Become a Nike Member',
#     'pdp_launchLMModalGuestJoinSubBullet': 'Line Checkout is available only to Nike Members. Not a Member? {JoinForFree}',
#     'pdp_launchLMModalJoinForFree': 'Join for Free',
#     'pdp_launchLMModalJoinNikePlusCTA': 'Become a Nike Member',
#     'pdp_launchLMModalLineOne': 'To make sure Nike Members have an equal chance to purchase high-demand items on our site, we use a Line Checkout system.',
#     'pdp_launchLMModalLineThree': 'Wait times vary based on demand. Limit one item per Nike Member.',
#     'pdp_launchLMModalLineTwo': "If your chosen size and color is available when you're selected, we'll process your order. If your selection sells out before that, we'll let you know.",
#     'pdp_launchLMModalSecondTitle': 'Improve Your Odds',
#     'pdp_launchLMModalSecondTitleSubtitle': "Here's how to make your Line Checkout experience as easy as possible:",
#     'pdp_launchLMModalUpdateProfileBullet': 'Update your Nike Member profile',
#     'pdp_launchLMModalUpdateProfileSubBullet': 'Make sure your shipping and payment information is current.',
#     'pdp_launchLMModalUpdateSettingsCTA': 'Update Account Settings',
#     'pdp_launchLMModalVerifyMobileBullet': 'Verify your mobile number',
#     'pdp_launchLMModalVerifyMobileSubBullet': 'This layer of added security helps keep the Line Checkout process fair.',
#     'pdp_launchLearnMoreButtonText': 'Learn more',
#     'pdp_launchNonWinnerBody': "Thank you for entering for the Nike Air VaporMax. Unfortunately, it didn't work out this time.",
#     'pdp_launchNonWinnerTitle': "Didn't Get 'Em",
#     'pdp_launchNotifyYou': 'We will notify you in a moment whether you get a pair or not.',
#     'pdp_launchPending': "You're in line",
#     'pdp_launchSessionExpiredTitle': 'Session expired',
#     'pdp_launchSoldOut': 'Sold Out',
#     'pdp_launchUnavailableTitle': 'Product unavailable',
#     'pdp_launchWinnerBody': 'Congratulations on your purchase. A confirmation email is on the way.',
#     'pdp_launchWinnerTitle': 'You Got It',
#     'pdp_launchYouAreInLine': "You're Currently In Line",
#     'pdp_launchYouAreInLineBody': 'We will notify you in a moment whether you get a pair or not.',
#     'pdp_launch_coming_soon_title': 'Get in Line. Get the Goods.',
#     'pdp_launch_entered': 'Launch Entered',
#     'pdp_launch_non_winner': 'Non winner',
#     'pdp_launch_pending': 'Pending...',
#     'pdp_launch_purchased': 'Purchased',
#     'pdp_launch_unavailable': 'This product is no longer available.',
#     'pdp_learnMore': 'Learn More',
#     'pdp_limitedColorBadge': 'Limited Color',
#     'pdp_limitedTimeBadge': 'Seasonal (Limited Time Color)',
#     'pdp_low_inventory_order_soon': 'Low inventory! Order soon.',
#     'pdp_low_stock_message': 'Limited stock in selected size',
#     'pdp_manufacturerAccordionCopy': 'Declaration of Importer: Direct import by the individual customer<br><br>Marketed by: Nike Global Trading B.V. Singapore Branch, 30 Pasir Panjang Road, #10-31/32, Mapletree Business City, Singapore 117 440',
#     'pdp_manufacturerAccordionHeader': 'Product Information',
#     'pdp_member_exclusive_subtitle': 'Member Exclusive',
#     'pdp_member_exclusive_subtitle_na': 'Member Access',
#     'pdp_member_exclusive_support_message': 'Sign in or create a free Nike Member account to get this product.',
#     'pdp_member_exclusive_support_message_title': 'It only takes a Nike Membership',
#     'pdp_minicart_upsell_recommendations_title': 'Frequently Bought Together',
#     'pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#     'pdp_no_return_text': 'This product is customized so the order cannot be cancelled 30 minutes after submit. Nike By You customized products do not apply to no reason return or exchange policy.',
#     'pdp_notAvailableForPickup': 'This item is not available for pickup',
#     'pdp_notifyMeSurveyText': 'If given the opportunity to be notified if this color becomes available, would you be interested?',
#     'pdp_numeric_range_separator': 'â\x80\x93',
#     'pdp_ok': 'OK',
#     'pdp_one_size': 'ONE SIZE',
#     'pdp_one_size_low_stock_message': 'Limited stock',
#     'pdp_pageNotFoundHeader': 'TIME OUT',
#     'pdp_percentageOff': 'off',
#     'pdp_pickUp': 'Free Pickup',
#     'pdp_pleaseSelectASize': 'Please select a size.',
#     'pdp_pre_order': 'Pre-Order',
#     'pdp_pre_order_get_it_first': 'Get it First:',
#     'pdp_pre_order_ships': 'Ships',
#     'pdp_privacy_policy_link': 'Privacy & Cookie Policy',
#     'pdp_productNotFound': 'THE PRODUCT YOU ARE LOOKING FOR IS NO LONGER AVAILABLE',
#     'pdp_productSoldOutMessage': 'This product is currently unavailable',
#     'pdp_product_crossedoutMessage': 'Discounted from',
#     'pdp_product_details_button': 'Read more',
#     'pdp_product_details_button_abtest_variant_a': 'View Product Details',
#     'pdp_promoMessaging': 'This product is excluded from site promotions and discounts.',
#     'pdp_recommendations_header': 'YOU MAY ALSO LIKE',
#     'pdp_recommendations_top_trending': 'TOP TRENDING',
#     'pdp_recommendedFitMessage': ' Fit: We recommend ordering a half-size up.',
#     'pdp_responsibleMaterials': 'Responsible Materials',
#     'pdp_review_text': 'Product received for free, or reviewed as part of a prize-draws/giveaway.\n<br>#productsprovidedbynike',
#     'pdp_review_text_na': 'Product received for free, or reviewed as part of a sweepstakes/giveaway.\n<br>#teamnike',
#     'pdp_reviews_accordion_panel_title': 'Reviews',
#     'pdp_reviews_add_review_button': 'Write a Review',
#     'pdp_reviews_mobile_loadmore_button': 'Load More',
#     'pdp_reviews_mobile_recpercent_button': '{{percent}}% of reviewers recommend this product',
# ...
#         'custom': {},
#         'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg',
#         'portrait': {'id': '84c9e581-df1b-44ba-b540-d21178c21295',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg'},
#         'title': '',
#         'squarishId': '',
#         'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#         'richTextLinks': [],
#         'subtitle': '',
#         'colorTheme': 'dark',
#         'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#          'modifiedDate': '2021-10-04T16:32:17.053Z',
#          'exposeTemplate': False,
#          'properties': {'actions': {}},
#          'resourceType': 'content/style'},
#         'actions': [],
#         'landscape': {'id': '9d61f74a-6c21-45d4-bb60-e94c06f3c945',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg'}}},
#       {'analytics': {'hashKey': 'fb66428b4726a52cb2f81f5739fe5be5d4b0ad04af664ecc30339ece62b60f98'},
#        'subType': 'text',
#        'id': '3a049537-aed5-44aa-b0f5-fb3e48e56399',
#        'type': 'card',
#        'version': '1633365089421',
#        'properties': {'copyId': 'a253dd95d0bae61b5d9ca9e207e32247ceb15df6',
#         'product': [],
#         'richTextLinks': [],
#         'custom': {},
#         'subtitle': '',
#         'colorTheme': 'dark',
#         'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#          'modifiedDate': '2021-10-04T16:31:29.405Z',
#          'exposeTemplate': False,
#          'properties': {'actions': {}},
#          'resourceType': 'content/style'},
#         'body': '<p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p>',
#         'title': 'Flexibility for Speed',
#         'actions': []}},
#       {'analytics': {'hashKey': 'add5b12590aa45c846ef8ab48ffb89ba2ee497d861dfff6291162efb2625bbc7'},
#        'subType': 'image',
#        'id': '072fa761-6350-45a0-9a85-88fad4ea24e7',
#        'type': 'card',
#        'version': '1633365102718',
#        'properties': {'portraitId': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#         'squarishURL': '',
#         'landscapeId': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#         'altText': '',
#         'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg',
#         'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg',
#         'portrait': {'id': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg'},
#         'title': '',
#         'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#         'richTextLinks': [],
#         'subtitle': '',
#         'colorTheme': 'dark',
#         'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#          'modifiedDate': '2021-10-04T16:31:42.718Z',
#          'exposeTemplate': False,
#          'resourceType': 'content/style'},
#         'actions': [],
#         'landscape': {'id': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg'}}},
#       {'analytics': {'hashKey': '19214ec1853bfd1aa0b5986f20c9f7bc1291c2d42405b07ae9d74bc303bb711d'},
#        'subType': 'text',
#        'id': '6de4f79e-1e52-4c01-a9d7-a21e9b8cb30b',
#        'type': 'card',
#        'version': '1633365097774',
#        'properties': {'copyId': 'd059f6db5527b41ea4abe44d472b2f9577221c23',
#         'product': [],
#         'richTextLinks': [],
#         'custom': {},
#         'subtitle': '',
#         'colorTheme': 'dark',
#         'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#          'modifiedDate': '2021-10-04T16:31:37.709Z',
#          'exposeTemplate': False,
#          'properties': {'actions': {}},
#          'resourceType': 'content/style'},
#         'body': '<p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p>',
#         'title': 'Stability for Strength',
#         'actions': []}}],
#      'layoutCards': [],
#      'firstImageUrl': 'https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png',
#      'firstImageAltText': 'Nike Free Metcon 4 Training Shoes',
#      'sustainabilityMessage': [],
#      'descriptionPreviewBullets': '',
#      'moreInfoMessages': [],
#      'sizeFitMessages': [],
#      'hubMessages': [],
#      'language': 'en',
#      'marketplace': 'US',
#      'availableSkus': [{'id': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da',
#        'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#        'resourceType': 'availableSkus',
#        'links': {'self': {'ref': '/deliver/available_skus/v1/ef237b73-2633-56fe-8ebd-fbc2258fa8da'}},
#        'available': True,
#        'level': 'LOW',
#        'skuId': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da'},
#       {'id': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f',
#        'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#        'resourceType': 'availableSkus',
#        'links': {'self': {'ref': '/deliver/available_skus/v1/2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'}},
#        'available': True,
#        'level': 'LOW',
#        'skuId': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'},
#       {'id': '9fd7e097-24db-5c33-b660-d300c3f6579c',
#        'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#        'resourceType': 'availableSkus',
#        'links': {'self': {'ref': '/deliver/available_skus/v1/9fd7e097-24db-5c33-b660-d300c3f6579c'}},
#        'available': True,
#        'level': 'LOW',
#        'skuId': '9fd7e097-24db-5c33-b660-d300c3f6579c'},
#       {'id': 'da0611fb-2af5-53fa-89c3-8baea350977b',
#        'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#        'resourceType': 'availableSkus',
#        'links': {'self': {'ref': '/deliver/available_skus/v1/da0611fb-2af5-53fa-89c3-8baea350977b'}},
#        'available': True,
#        'level': 'LOW',
#        'skuId': 'da0611fb-2af5-53fa-89c3-8baea350977b'},
#       {'id': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca',
#        'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#        'resourceType': 'availableSkus',
#        'links': {'self': {'ref': '/deliver/available_skus/v1/4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}},
#        'available': True,
#        'level': 'LOW',
#        'skuId': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}],
#      'publishType': 'FLOW',
#      'isLaunchView': False,
#      'launchView': None,
#      'isForNumberOfImagesABTesting': False,
#      'isMinimumAdvertisedPrice': False,
#      'collectionTermIds': ['c05bedd9-29d3-4e45-8c62-c463f9c5958f',
#       '1a70e9af-aea9-4a39-9773-fa6ced97c58b',
#       '65838112-1f4d-48a7-9b2f-1e8736c4cdcc',
#       'a49f8e69-ff9c-4356-89d8-d4a098fc02c2',
#       'e4e46ee6-496f-491a-8771-1a677eefee3a',
#       '94d2c954-14cd-4784-96ec-b02c950d2872',
#       '62f3c208-e1a3-45c0-9e70-a90be4e276f1',
#       'b9cefedb-1dd5-42dc-af13-939a240d4bb8',
#       '4be7e5d7-7e5b-460d-b3d7-41396b3fa985'],
#      'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#       '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#       '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#       'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#       '292efae5-2d9a-44a3-a529-cda684a47c44',
#       'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#       '7702dda3-62ca-3410-b4f3-97025be1089d',
#       '68a7b17f-291f-41f8-bf04-5e2fbe878d9b',
#       '05392778-fff6-4fa0-a375-2506d27f009e',
#       '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#       '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#       'b942d0ac-4887-4a8f-b914-d82a6181014f',
#       '67063381-90eb-4763-8f87-acc30b392f38',
#       '699b34a6-1950-3458-8322-910b695fccb7',
#       '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#       '10f9af5a-58d2-480a-a72d-5a65bd374850',
#       '0a937561-8633-3ea1-8ae3-8509f50f4127',
#       '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#       '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#       '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#       '539c6c43-d060-30b0-be5b-47c47f7c7658',
#       'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#       '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#       '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#       '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#       '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#       '2057952b-1a72-368e-b4b1-f67091ff1799',
#       '6e7e4809-fccb-4e82-8a7b-047125398076',
#       '9b0e77d0-aec5-4f4b-b8de-acb7a82e396d',
#       '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#       '7abdd901-856d-3601-94bf-14313cee8354',
#       '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#       'b5cd158b-b105-490c-b777-652943e742b0',
#       'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#       '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#       '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#       '16633190-45e5-4830-a068-232ac7aea82c',
#       '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#       '7817e756-7721-4cfb-b404-04df79c685e4',
#       'c29a0094-d302-4b7a-b5f0-73e46f772348'],
#      'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#      'catalogId': '1',
#      'selectedSkuId': {},
#      'sizeAndFitDescription': '',
#      'exclusiveAccess': False,
#      'notifyMeIndicator': False,
#      'promoExclusionAccess': False,
#      'useFeedsPromoExclusionMessage': False,
#      'jerseyIdPathName': '',
#      'nbyHubMessages': [],
#      'state': 'IN_STOCK'}}},
#   'NikeId': {'nikeIdPrebuildSuggestion': None,
#    'NBYBuilderModalOpen': False,
#    'metricId': '',
#    'itemId': '',
#    'gender': '',
#    'sizing': {},
#    'fit': '',
#    'showNBYBuyingTools': False,
#    'error': None,
#    'availability': False,
#    'async': {'prebuildSuggestions': False},
#    'isAvailable': True},
#   'NotQuiteReady': {'notQuiteReadyEvts': []},
#   'Fit': {'fitSize': '', 'localizedFitSize': '', 'isFitSizeSet': False},
#   'EDD': {'estimatedDeliveryData': None},
#   'User': {'user': {}, 'isSwoosh': False, 'initialized': False},
#   'FitAnalytics': {'fitAnalyticsRecommendedSize': None,
#    'fitAnalyticsFindMySizeClicked': False},
#   'Cart': {'isSizeSelectError': False,
#    'cartProduct': {},
#    'cartSku': {},
#    'wishlistProduct': {},
#    'wishlistSku': {},
#    'isWishlistConfirmationModalOpen': False,
#    'async': {},
#    'payload': {},
#    'cartError': []},
#   'Config': {'name': 'pdp',
#    'domain': 'dotcom',
#    'division': 'commerce',
#    'platform': 'cloud',
#    'version': '1.0.0',
#    'facebookAppId': '1397260880304609',
#    'channelId': 'd9a5bc42-4b9c-4976-858a-f159cf99c647',
#    'env': 'prod',
#    'dark': False,
#    'preview': False,
#    'branchIOKey': 'key_test_dcy0gJ0f2U1NBELEQXq8ElcgvumigPUu',
#    'defaultStyleColor': '724010-017',
#    'productStateOverride': None,
#    'gqlHash': '4bc133d8e69ba0dd907158346fed7f2e',
#    'flags': {'abTests': True,
#     'animateAccordionPanels': False,
#     'cookieSettings': False,
#     'cookieSettingsBanner': False,
#     'cutOverPdpToSegment': True,
#     'debug': False,
#     'enableMAP': True,
#     'filterByNikeDotComChannel': True,
#     'globalNavUseGeoPrivacy': True,
#     'gridRecommendations': True,
#     'hideBuyingTools': False,
#     'incentivizedReviewsMessageNA': True,
#     'incentivizedReviewsMessage': False,
#     'includeFacebookAppId': True,
#     'logoutShouldClearCart': True,
#     'lowInventoryMessage': True,
#     'loadWebShell': True,
#     'loadWebShellOnWall': False,
#     'loadForterScript': True,
#     'loadStylitics': True,
#     'notifyMe': True,
#     'showAvailabilityDate': False,
#     'recommendations': True,
#     'reserveForYou': True,
#     'sendPIDsOnWall': True,
#     'shareNBY': True,
#     'showCNNewYearsLink': False,
#     'showCgc': True,
#     'showColorWayPicker': True,
#     'showEGift': True,
#     'showElevatedContent': True,
#     'showFit': True,
#     'showGeoMismatch': True,
#     'showGiftCardMessage': True,
#     'showGiftCardTypeLink': True,
#     'showGiftCards': True,
#     'showJerseyId': True,
#     'showKlarnaPayMessage': True,
#     'showKlarnaPayLaterMessage': False,
#     'showLargeGiftCardOrder': True,
#     'showLaunchDebug': False,
#     'showLaunchProduct': True,
#     'showLeftHandNavCategories': True,
#     'showMobileWriteReview': True,
#     'showMoreInfo': True,
#     'showNBY': True,
#     'showNBYMessageHub': True,
#     'showNikeId': True,
#     'showOmni': False,
#     'showPhysicalGiftCards': True,
#     'showPromoBanner': True,
#     'showPromoMsg': True,
#     'showPromoExclusionMsg': True,
#     'showFeedsPromoExclusionMessage': False,
#     'showReadMore': True,
#     'showRelatedCategories': True,
#     'showReviews': True,
#     'showSEOCopy': False,
#     'showSinglesDaySalesLink': False,
#     'showSizeAndFit': True,
#     'showSizeCalculator': False,
#     'showSocialLinksNBY': True,
#     'showUniteTimers': False,
#     'showWidthSelector': True,
#     'showWishlist': True,
#     'skipPercentOff': False,
#     'skipSustainability': False,
#     'skipSegmentDupedEvents': True,
#     'swooshEligibleGeo': True,
#     'useBounceExchange': False,
#     'useDotcomNav': True,
#     'useDotcomNavESI': True,
#     'useExclusiveAccess': True,
#     'useFeedsMoreInfoMessage': False,
#     'useFeedsSizeFitMessage': False,
#     'useFeedsSustainabilityMessage': True,
#     'useMAPCollection': True,
#     'useNBYCloudUrl': True,
#     'useNBYImageService': True,
#     'useNeo': True,
#     'useNewRelic': True,
#     'useOptimizelyX': True,
#     'usePersonalizedNullSearch': False,
#     'useRollupKey': True,
#     'useSentryIO': False,
#     'useServiceCanonicalUrl': True,
#     'useSwitchboardRecommendations': False,
#     'useTTReviews': True,
#     'useUniteStaging': False,
#     'enableNikeShopModals': True,
#     'showElevatedCarousel': True,
#     'hideEDDFasterShippingOptionMsg': False,
#     'showEstimatedDeliveryDate': False,
#     'showEstimatedDeliveryDateAndPickup': True,
#     'showPickupLocation': True,
#     'showEDDAndBopisABTesting': False,
#     'wallFavorites': False,
#     'wallFiltersBtnFilterLabel': True,
#     'wallImpressions': True,
#     'wallNoResultsCarousel': True,
#     'useTTV5Reviews': True,
#     'useNotifyMeV2': False,
#     'isZoomEnabled': False},
#    'assetPaths': {},
#    'recommendationsScheme': 'product_rr',
#    'cacheDuration': {'404': 60,
#     'default': 900,
#     'launch': 900,
#     'pdp': 900,
#     'perf': 900,
#     'wall': 300},
#    'globalNavConfig': {'header': 'commerce-header',
#     'footer': 'footer',
#     'shared': 'shared',
#     'testHeader': 'commerce-header',
#     'testFooter': 'footer',
#     'testShared': 'shared'},
#    'optimizelyEndpoint': '//www.nike.com/assets/vendor/optimizely/prod/5aUCtZvFuDLjvdqdf2w53M.json',
#    'turnToConfig': {'turnToFetchTimeout': 350,
#     'turnToAuthBucket': 'shared/turnto/prod-auth-keys'},
#    'exp': '2011'},
#   'Console': {'providers': []},
#   'CrossSell': {'products': [], 'error': None, 'async': {'products': False}},
#   'Auth': {'bearer': ''},
#   'Experiments': {'activeExperiments': {}, 'forcedExperiments': {}},
#   'Launch': {'launchCheckoutModalOpen': False,
#    'launchCheckoutServices': 'launch-checkout'},
#   'MAPProducts': {'products': {}},
#   'Privacy': {'areSocialCookiesAllowed': False,
#    'arePerformanceCookiesAllowed': False,
#    'geoLoc': None,
#    'hasEUCookie': False},
#   'Device': {'breakpointMatched': False, 'deviceWidth': 'sm'},
#   'Overlays': [],
#   'Common': {'channel': 'NIKE',
#    'connection': {'saveData': False, 'effectiveType': None},
#    'globalHeaderFixedHeight': 60,
#    'globalHeaderHeight': 96,
#    'pageType': 'pdp',
#    'routes': [],
#    'siteHost': 'https://www.nike.com'},
#   'META': {'commit': ''},
#   'NOTIFY_ME': {'isNotifyMeModalOpen': False,
#    'page': 'default',
#    'journey': '',
#    'isNotifyMeSMSOpen': False,
#    'isNotifyMeEmailOpen': False,
#    'emailJourneyCompleted': False,
#    'smsJourneyCompleted': False,
#    'email': '',
#    'sms': ''},
#   'intl': {}}}

# %%
json_object['props']['pageProps'].keys()
# Out:
# dict_keys(['initialState'])

# %%
json_object['props']['pageProps']['initialState']
# Out:
# {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#    'titleTemplate': '%s',
#    'meta': [{'name': 'description',
#      'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#     {'name': 'keywords', 'content': 'Nike Free Metcon 4 Training Shoes'},
#     {'name': 'robots', 'content': 'index, follow'},
#     {'property': 'og:title',
#      'content': 'Nike Free Metcon 4 Training Shoes. Nike.com'},
#     {'property': 'og:description',
#      'content': 'Find the Nike Free Metcon 4 Training Shoes at Nike.com.  Free delivery and returns.'},
#     {'property': 'og:type', 'content': 'website'},
#     {'property': 'og:url',
#      'content': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'},
#     {'property': 'og:image',
#      'content': 'https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png'},
#     {'property': 'og:locale', 'content': 'en_US'},
#     {'property': 'og:site_name', 'content': 'Nike.com'},
#     {'property': 'og:price:currency', 'content': 'USD'},
#     {'property': 'og:price:amount', 'content': 120},
#     {'name': 'branch:deeplink:$deeplink_path',
#      'content': 'x-callback-url/product-details?style-color=CT3886-004'},
#     {'property': 'fb:app_id', 'content': '1397260880304609'}],
#    'title': 'Nike Free Metcon 4 Training Shoes. Nike.com',
#    'link': [{'rel': 'canonical',
#      'href': 'https://www.nike.com/t/free-metcon-4-amp-training-shoes-KX41Bv'}]}},
#  'reviews': {'country': 'us',
#   'apiversion': None,
#   'sorts': {'SubmissionTime': True},
#   'productStyleCode': 'CT3886',
#   'total': 0,
#   'averageRating': 0,
#   'recommendedCount': 0,
#   'reviews': [],
#   'dimensions': [],
#   'reviewsMap': {},
#   'initialFetched': False,
#   'initialFetching': False,
#   'initialFetchError': False,
#   'fetched': False,
#   'fetching': False,
#   'fetchError': False,
#   'positiveFeedbackSubmitting': {},
#   'positiveFeedbackSubmitted': {},
#   'positiveFeedbackSubmitError': {},
#   'negativeFeedbackSubmitting': {},
#   'negativeFeedbackSubmitted': {},
#   'negativeFeedbackSubmitError': {},
#   'inappropriateFeedbackSubmitting': {},
#   'inappropriateFeedbackSubmitted': {},
#   'inappropriateFeedbackSubmitError': {},
#   'isDrawerOpen': False,
#   'reviewsDrawerType': 'view',
#   'currentReviewId': '',
#   'summary': {'total': 0,
#    'limit': 0,
#    'averageRating': 0,
#    'recommendedCount': 0,
#    'reviews': [],
#    'secondaryRatingsOrder': [],
#    'bestRating': 5,
#    'worstRating': 1},
#   'vendor': 'VENDOR/TURN_TO',
#   'serverSideFetched': False,
#   'serverSideFetching': True,
#   'serverSideFetchError': False},
#  'localization': {'urlParam': 'en',
#   'language': 'en',
#   'intl': 'en-US',
#   'langRegion': 'en-US',
#   'hreflang': 'en-US',
#   'default': True,
#   'country': 'us',
#   'countryName': 'United States',
#   'currency': 'USD',
#   'reactIntl': '',
#   'merchGroup': 'US',
#   'messages': {'91330387': 'Name of wishlist is not unique.',
#    'JP.discount_addendum': 'Sale Price',
#    'browse_crossSellPopItemLowerCase': 'These popular items might interest you',
#    'browse_fallback_message': "The page you were viewing was experiencing technical difficulties and we're working to resolve it. A quick refresh should get you back in play. Apologies for the inconvenience.",
#    'browse_fallback_refresh_button': 'Refresh Now',
#    'browse_fallback_title': 'Short time out needed',
#    'browse_noMatchesFound': 'No matches found.',
#    'browse_pleaseTryAnotherSearch': 'Please try another search.',
#    'hf-geomismatch-chooseLocation': 'Choose Location',
#    'hf-geomismatch-confirm': 'Confirm',
#    'hf-geomismatch-message': 'Update your location to shop products available in {country}',
#    'hf-geomismatch-prompt': 'We think you are in {country}. Update your location?',
#    'hf-geomismatch-title': 'Confirm your Location',
#    'hf-geoselection-title': 'Select your Location',
#    'hf-header-label-carticon': 'Bag Items',
#    'hf-header-label-countryicon': 'Selected Location',
#    'hf_close_menu_aria_label': 'Close Menu',
#    'hf_cookie-policy_banner_ok': 'OK',
#    'hf_cookie_label_cookieSettings': 'Cookie Settings',
#    'hf_cookie_label_done': 'Done',
#    'hf_cookie_label_functional': 'Functional',
#    'hf_cookie_label_performance': 'Performance',
#    'hf_cookie_label_privacyPolicy': 'Privacy & Cookie Policy',
#    'hf_cookie_label_socialMedia': 'Social Media and Advertising',
#    'hf_cookie_label_yourCookieSettings': 'Your Cookie Settings',
#    'hf_cookie_policy_banner': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {privacyAndCookiePolicyHTML}. You can adjust your preferences in {cookieSettingsHTML}.',
#    'hf_cookie_policy_banner_ok': 'OK',
#    'hf_cookie_text_cookieAccept': 'Yes, I Accept',
#    'hf_cookie_text_cookieReject': "No, I Don't Accept",
#    'hf_cookie_text_do_you_accept': 'Do you accept these cookies and the processing of personal data involved?',
#    'hf_cookie_text_footer': 'You can always change your preference by visiting the "Cookie Settings" at the bottom of the page. View {privacyAndCookiePolicyHTML} for full details.',
#    'hf_cookie_text_functional': 'These cookies are required for basic site functionality and are therefore always enabled. These include cookies that allow you to be remembered as you explore the site within a single session or, if you request, from session to session. They help make the shopping cart and checkout process possible as well as assist in security issues and conforming to regulations.',
#    'hf_cookie_text_information': 'Privacy & Cookie Policy',
#    'hf_cookie_text_moreInformation': 'More Information',
#    'hf_cookie_text_performance': 'These cookies allow us to improve the siteâ\x80\x99s functionality by tracking usage on this website. In some cases these cookies improve the speed with which we can process your request, allow us to remember site preferences youâ\x80\x99ve selected. De-selecting these cookies may result in poorly-tailored recommendations and slow site performance.',
#    'hf_cookie_text_policy': 'Nike asks you to accept cookies for performance, social media and advertising purposes. Social media and advertising cookies of third parties are used to offer you social media functionalities and personalized ads. To get more information or amend your preferences, press the â\x80\x98more informationâ\x80\x99 button or visit "Cookie Settings" at the bottom of the website. To get more information about these cookies and the processing of your personal data, check our {privacyAndCookiePolicyHTML}. Do you accept these cookies and the processing of personal data involved?',
#    'hf_cookie_text_socialMedia': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#    'hf_cookie_text_socialMedia_2': 'Social media cookies offer the possibility to connect you to your social networks and share content from our website through social media. Advertising cookies (of third parties) collect information to help better tailor advertising to your interests, both within and beyond Nike websites. In some cases, these cookies involve the processing of your personal data. For more information about this processing of personal data, check our {privacyAndCookiePolicyHTML}. De-selecting these cookies may result in seeing advertising that is not as relevant to you or you not being able to link effectively with Facebook, Twitter, or other social networks and/or not allowing you to share content on social media.',
#    'hf_cookie_title_cookieSettings': 'Your Cookie Settings',
#    'hf_fallback_account': 'Account',
#    'hf_header_find_a_store': 'Find a Store',
#    'hf_header_label_acceptedPaymentTypes': 'Accepted Payment Types',
#    'hf_header_label_account': 'Account',
#    'hf_header_label_bag': 'Bag',
#    'hf_header_label_closeSearch': 'Close Search',
#    'hf_header_label_copyright': 'Â© 2023 Nike, Inc. All Rights Reserved',
#    'hf_header_label_favorites': 'Favorites',
#    'hf_header_label_help': 'Help',
#    'hf_header_label_hurleyLogo': 'Hurley Home Page',
#    'hf_header_label_joinOrLogin': 'Join/Log In To Nike Member Profile',
#    'hf_header_label_liveChat': 'Live Chat',
#    'hf_header_label_myAccount': 'My Account',
#    'hf_header_label_nikeSwooshLogo': 'Nike Home Page',
#    'hf_header_label_orders': 'Orders',
#    'hf_header_label_popular_search_terms': 'Popular Search Terms',
#    'hf_header_label_resetSearch': 'Reset Search',
#    'hf_header_label_search': 'Search',
#    'hf_header_label_search_input': 'Search Products',
#    'hf_header_label_search_open': 'Open Search Modal',
#    'hf_header_label_search_topSuggestions': 'Top Suggestions',
#    'hf_header_label_secondaryNavigation': 'Secondary Navigation',
#    'hf_header_label_selectACountry': 'Selected Location',
#    'hf_label_avatar': 'Avatar',
#    'hf_logo_converse': 'Converse Logo',
#    'hf_logo_jordan': 'Jordan Logo',
#    'hf_menu_aria_label': 'menu',
#    'hf_message_join_membership': 'Become a Nike Member for the best products, inspiration and stories in sport. {learnMore}',
#    'hf_message_join_nikeplus': 'Join Us to enjoy the best of Nike Membership with our family of apps, free shipping, access to coaching, global events and more.',
#    'hf_popular_search_gifts': 'Gifts',
#    'hf_search_cancel': 'Cancel',
#    'hf_skip_to_content': 'Skip to main content',
#    'hf_title_all_menuitem': 'All',
#    'hf_title_greeting_membership': 'Hi, {name}',
#    'hf_title_greeting_membership_a11y': 'Hi, {name}. Account & Favorites',
#    'hf_title_join_nikeplus': 'SIGN IN / JOIN US',
#    'hf_title_joinus_membership': 'Join Us',
#    'hf_title_learnmore_membership': 'Learn more',
#    'hf_title_signin_membership': 'Sign In',
#    'hf_visual_search_no_product_found': 'No product suggestions found for {query}',
#    'hf_visual_search_title': 'TOP SUGGESTIONS',
#    'hf_visual_search_viewall': 'View All',
#    'pdp_NBYCustomize': 'Customize',
#    'pdp_buying_tools_add_to_wishlist': 'Favorite',
#    'pdp_crosssell_buy_now': 'Buy Now',
#    'pdp_crosssell_cart_title': 'YOU MIGHT ALSO LIKE',
#    'pdp_crosssell_color': 'Color',
#    'pdp_crosssell_colors': 'Colors',
#    'pdp_crosssell_customize': 'Customize',
#    'pdp_crosssell_first_ordinal_indicator': 'st',
#    'pdp_crosssell_jersey_title': 'GET THE ULTIMATE',
#    'pdp_crosssell_jerseykids_title': 'GET THE ULTIMATE',
#    'pdp_crosssell_nfl_teams_available': 'All NFL Teams Available',
#    'pdp_crosssell_nfl_title': 'GET THE ULTIMATE',
#    'pdp_crosssell_nfl_title_suffix': 'HOOKUP',
#    'pdp_crosssell_nikeid_button': 'Shop All Nike By You',
#    'pdp_crosssell_nikeid_customize': 'CUSTOMIZE YOUR OWN WITH NIKE BY YOU',
#    'pdp_crosssell_nikeid_title': 'YOU MIGHT ALSO LIKE',
#    'pdp_crosssell_nikeid_url': 'http://www.nike.com/us/en_us/c/nikeid',
#    'pdp_crosssell_options': 'Options',
#    'pdp_crosssell_player_available': 'Player Available',
#    'pdp_crosssell_players_available': 'Players Available',
#    'pdp_crosssell_second_ordinal_indicator': 'nd',
#    'pdp_crosssell_shop_all_nikeid': 'SHOP ALL NIKE BY YOU',
#    'pdp_crosssell_third_ordinal_indicator': 'rd',
#    'pdp_crosssell_title': 'YOU MIGHT ALSO LIKE',
#    'pdp_crosssell_top_kids_products': 'TOP KIDSâ\x80\x99 PRODUCTS',
#    'pdp_crosssell_top_mens_products': 'TOP MENâ\x80\x99S PRODUCTS',
#    'pdp_crosssell_top_womens_products': 'TOP WOMENâ\x80\x99S PRODUCTS',
#    'pdp_crosssell_widths_available': 'Widths Available',
#    'pdp_nikeid_thumbnail_alt_text': 'Design your own Nike By You product',
#    'pdp_remove_customized_jersey': 'Remove',
#    'seePriceInCart': 'See Price in Bag',
#    'sub_footer_business_information_link_text': 'Business information confirmation',
#    'sub_footer_business_information_text': '(U) Nike Korea CEO Kimberlee Lynn Chang Mendes | 30th floor, Gangnam Finance Center, 152 Teheran-ro, Gangnam-gu, Seoul | Mail order distributor number 2011-Seoul Gangnam-03461 | Business registration number {phone}',
#    'sub_footer_businness_company_text': 'deposit payment',
#    'sub_footer_customer_service_text': 'Customer service phone number {phone} FAX {fax} | Email: {email} | Hosting service provider (U) Nike Korea',
#    'sub_footer_legal_info_link_text': 'Read more',
#    'sub_footer_legal_info_text': 'Information on content protection under the Content Industry Promotion Act.',
#    'sub_footer_modal_body_text': 'Name of content: product information, event information, etc.\nDate of creation of the content: cut-over date (or its update date if the content has been upgraded).\nAll content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent).',
#    'sub_footer_modal_body_text_one': 'Name of content: product information, event information, etc',
#    'sub_footer_modal_body_text_three': 'All content in the web page is protected for five years from the date of production or its renewal under the Content Industry Promotion Act (unauthorized copying is prohibited without consent)',
#    'sub_footer_modal_body_text_two': 'Date of creation of the content: October 05, 2022 (or its update date if the content has been upgraded)',
#    'sub_footer_modal_title': 'Indication under the Content Industry Promotion Act',
#    'sub_footer_payment_information_text': 'For safe transactions, when paying with cash, etc., \u2028you can use the purchase safety service ({company}) of Korea Payment Network Co., Ltd., which you signed up for in our shopping mall.',
#    'test': 'testing',
#    '04E2F5C8': 'Sorry, the resource you requested does not exist.',
#    '15E57A07': 'Sorry, we had an issue with your request.  Please try again.',
#    '2DA19B6C': 'Sorry, you have reached the quantity limit.  Please remove an item and try again. ',
#    '3534E689': 'Sorry, the product you have selected is not available at this time.',
#    '36A1E761': 'Sorry, we do not recognize the postal code you entered. Please try entering a different postal code.',
#    '3F7B9831': 'Sorry, we couldnâ\x80\x99t process your request because your browser has too many cookies. Clear your cookies and try again.',
#    '49780BED': 'Unable to reach Partner',
#    '4C5FB5DF': 'Maximum wishlist items exceeded.',
#    '4CB0532B': 'Sorry, the code entered is incorrect or invalid. Please try again, or enter another code.',
#    '6BD7E72A': 'Maximum wishlists per user exceeded.',
#    '7E977FCE': 'Sorry, the product you have selected is not available at this time.',
#    '840D5CFE': 'Country not currently supported',
#    '8B2AE0A4': 'The resource you requested does not exist.',
#    '9008921A': 'Product already added to wishlist.',
#    '97AE3B36': 'We are temporarily experiencing site issues. If unable to complete your purchase, please try again later.',
#    'A044DD39': 'Sorry, this code could not be applied. Please review the criteria to qualify for this promotion.',
#    'A553CABC': 'Your item total has exceeded the $1000.00 checkout limit. Please remove a few items and try again.',
#    'A954F3EE': 'Offer invalid',
#    'AA33FB74': 'Sorry, the product you have selected is not available at this time. ',
#    'ABB4C446': 'Sorry, you have reached the quantity limit. Please remove an item and try again. ',
#    'AE66C4E0': 'Sorry, this code is expired. Please try another code.',
#    'B2D8D9B5': 'Sorry, we had an issue with your request.  Please try again.',
#    'B9671077': 'Sorry, the product you have selected is not available at this time.',
#    'C4CD1584': 'Offer invalid',
#    'CF1877FC': 'Failed to make Reservation with Inventory System.',
#    'D2A6EE25': 'The given country code is not in the valid list.',
#    'D403D4AD ': 'One or More Items Unavailable. Please remove one or more items from your Bag, refresh and try again.',
#    'DAD5D797': 'Sorry, the product you have selected is not available at this time. ',
#    'E2E82F65': 'The field value is invalid',
#    'E37BAB4': 'Sorry, the price of the Gift Card is invalid. ',
#    'AE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'AT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'AU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'BE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'BG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'BR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'BR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'CA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'CH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'CL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'CN.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'CN.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'CN.NikeCom_PDP_Suffix': '-Nike China official website',
#    'CN.NikeCom_Suffix': '-Nike China official website',
#    'CN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'CZ.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'CZ.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'CZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'DE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com.  ',
#    'DE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'DE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'DK.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'DK.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'DK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'EG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'ES.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'ES.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'ES.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'FI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'FR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'FR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'FR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'GB.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'GB.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#    'GB.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'GR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'GR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'GR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'HR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'HU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'HU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'HU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'HurleyCom_Wall_SEO_Title_Suffix': '. Hurley.com',
#    'ID.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'IE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'IL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'IN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'IT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'IT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'IT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'JP.NikeCom_PDP': '',
#    'JP.NikeCom_PDP_Prefix': '',
#    'JP.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'JP.NikeCom_PDP_SEO_Desc2': 'Try-on within 30 days can be returned (except some products). [Free shipping for Nike members anytime]',
#    'JP.NikeCom_PDP_Suffix': '. Nike JP',
#    'JP.NikeCom_Prefix': '',
#    'JP.NikeCom_Suffix': '. Nike JP',
#    'JP.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'JP.NikeCom_Wall_SEO_Title_Suffix': '. Nike JP',
#    'KR.NikeCom_Suffix': '. Nike KR',
#    'KR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'KR.NikeCom_Wall_SEO_Title_Suffix': '. Nike KR',
#    'LU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'MA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'MX.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'MY.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'NL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'NL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'NL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'NO.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'NO.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'NO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'NZ.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#    'NikeCom_PDP_SEO_Keywords': '{Product_Full_Title}',
#    'NikeCom_PDP_SEO_Title': '{NikeCom_Prefix}{Product_Full_Title}{NikeCom_Suffix}',
#    'NikeCom_PDP_Suffix': '. Nike.com',
#    'NikeCom_Suffix': '. Nike.com',
#    'NikeCom_Wall_SEO_Keywords': '{TITLE}',
#    'NikeCom_Wall_SEO_Title': '{TITLE}',
#    'NikeCom_Wall_SEO_Title_Default': 'Products',
#    'NikeCom_Wall_SEO_Title_Suffix': '. Nike.com',
#    'PH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'PL.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'PL.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'PL.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'PR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'PT.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'PT.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'PT.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'RO.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'RU.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'RU.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'RU.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'SA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'SE.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'SE.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'SE.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'SG.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'SI.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'SK.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'TH.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'TH.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'TH.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'TR.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'TR.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'TR.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'TW.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'TW.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns on select orders.',
#    'TW.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'US.NikeCom_PDP_SEO_Desc1': 'Find the {Product_Full_Title} at Nike.com. ',
#    'US.NikeCom_PDP_SEO_Desc2': 'Free delivery and returns.',
#    'US.NikeCom_PDP_Suffix': '. Nike.com',
#    'US.NikeCom_Suffix': '. Nike.com',
#    'US.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'VN.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns on select orders.',
#    'ZA.NikeCom_Wall_SEO_Desc': 'Find {TITLE} at Nike.com. Free delivery and returns.',
#    'DE.pdp_vat_message': '<div> Prices incl. VAT and plus delivery costs. You can find details of shipping costs <a href = "https://www.nike.com/help/a/shipping-delivery" class = "exp-pdp-tc-disclaimer-url "> here </a> </ div>',
#    'FR.pdp_recycle_message': 'This product may be recyclable. <a href="https://www.nike.com/fr/help/a/triman"> Learn more </a>',
#    'JP.tax_addendum': '(Tax Incl.)',
#    'US.pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#    'US.pdp_standardShipping': 'Standard / Arrives 2-4 Business Days',
#    'US.pdp_twoDayShipping': 'Two-Day / Arrives 2-3 Business Days',
#    'crossell.certona.all-nfl-teams-available': 'All NFL Teams Available',
#    'crossell.certona.buy-now': 'Buy Now',
#    'crossell.certona.cart_rr': 'You Might Also Like ',
#    'crossell.certona.color-plural': 'Colors',
#    'crossell.certona.color-singular': 'Color',
#    'crossell.certona.error4041_rr': 'TOP MENâ\x80\x99S PRODUCTS',
#    'crossell.certona.error4042_rr': 'TOP WOMENâ\x80\x99S PRODUCTS',
#    'crossell.certona.error4043_rr': 'TOP KIDSâ\x80\x99 PRODUCTS',
#    'crossell.certona.first-option': 'st',
#    'crossell.certona.inactivepdp1_rr': 'THESE POPULAR PRODUCTS MIGHT INTEREST YOU',
#    'crossell.certona.inactivepdp2_rr': 'CUSTOMIZE YOUR OWN WITH NIKEiD',
#    'crossell.certona.nflbuilderpdp_rr': 'GET THE ULTIMATE',
#    'crossell.certona.nfljerseykidspdp_rr': 'GET THE ULTIMATE',
#    'crossell.certona.nfljerseypdp_rr': 'GET THE ULTIMATE',
#    'crossell.certona.nflpdp_rr_suffix': 'HOOKUP',
#    'crossell.certona.nikeid-button': 'Shop All NIKEiD',
#    'crossell.certona.nikeid-text': 'Customize',
#    'crossell.certona.nikeid-url': 'http://www.nike.com/us/en_us/c/nikeid',
#    'crossell.certona.nikeidpdp_rr': 'You Might Also Like',
#    'crossell.certona.nosearch1_rr': 'SHOP ALL NIKEiD',
#    'crossell.certona.nosearch2_rr': '&nbsp;',
#    'crossell.certona.options': 'Options',
#    'crossell.certona.pdp.crosssell.nikeid': 'CUSTOMIZE',
#    'crossell.certona.player-plural': 'Players Available',
#    'crossell.certona.player-singular': 'Player Available',
#    'crossell.certona.playerNamesAvailable': 'Players available',
#    'crossell.certona.product_rr': 'You Might Also Like',
#    'crossell.certona.purchase_rr': '(purchase_rr) REPLACE THIS VALUE IN HtmlLocalValueBundle.properties!',
#    'crossell.certona.second-option': 'nd',
#    'crossell.certona.third-option': 'rd',
#    'crossell.certona.widths-available': 'Widths Available',
#    'pdp_3rdParty_Overseas_Transfer_PI': '3rd Party and Overseas Transfer of Personal Information',
#    'pdp_Collection_Use_PI': ' the collection and use of personal information',
#    'pdp_I_Agree_To': 'I agree to',
#    'pdp_NBYAvailableFor': 'Available For',
#    'pdp_NBYButtonTitle': 'Customize',
#    'pdp_NBYColorChipLabel': 'Design Your Own',
#    'pdp_NBYCustomDesignTab': 'Your Designs',
#    'pdp_NBYDesignTabs': 'Designs',
#    'pdp_NBYInspirationTab': 'Inspiration',
#    'pdp_NBYShareYourDesign': 'Share Your Design',
#    'pdp_NBYSoldOut': 'Sold Out',
#    'pdp_NBYYourDesignTxt': "Choose 'Customize' to add a design",
#    'pdp_NotifyMeButtonTitle': 'Notify Me',
#    'pdp_NotifyMeCancel': 'Cancel',
#    'pdp_NotifyMeDefaultEmailAddressText': 'Email Address',
#    'pdp_NotifyMeDone': 'Done',
#    'pdp_NotifyMeEmailOptInMessage': 'Send me news and offers from Nike',
#    'pdp_NotifyMeInvalidEmail': 'Please enter a valid email.',
#    'pdp_NotifyMeLegalText': '{privacyLinkText} and {termsOfUseLinkText}',
#    'pdp_NotifyMeModalBody': 'Get a one-time email alert the moment this product drops',
#    'pdp_NotifyMeModalLegalLinkJoin': 'and',
#    'pdp_NotifyMeModalPrivacyPolicyLinkText': 'Privacy Policy',
#    'pdp_NotifyMeModalTermsOfUseLinkText': 'Terms of Use',
#    'pdp_NotifyMeModalTitle': "Don't Miss Out",
#    'pdp_NotifyMeOk': 'Ok',
#    'pdp_NotifyMeOkModalTitle': "You're on the List",
#    'pdp_NotifyMeServerError': 'There was an error creating this notification.  Please try again later.',
#    'pdp_NotifyMeSubmit': 'Submit',
#    'pdp_NotifyMeThanks': "We'll send a one-time email to {email} when this product drops.",
#    'pdp_NotifyMe_AddAPhoneNumber': 'Add a phone number to get notified',
#    'pdp_NotifyMe_AddAnEmail': 'Add an email address to get notified',
#    'pdp_NotifyMe_And': 'and',
#    'pdp_NotifyMe_ConsentRefusal': 'You may refuse to consent, in which case you will not be able to receive information about Nike product releases. Nike is not responsible if the notification message fails to deliver.',
#    'pdp_NotifyMe_DefaultHeaderSubtitle': 'Get a one-time notification when this product drops.',
#    'pdp_NotifyMe_EmailHeaderSubtitle': 'Enter your email to receive a one-time notification',
#    'pdp_NotifyMe_EmailHeaderTitle': 'Add your email address.',
#    'pdp_NotifyMe_MemberEmailSendTo': 'Send an email to',
#    'pdp_NotifyMe_NotifyWithEmail': 'Notify with email',
#    'pdp_NotifyMe_NotifyWithSMS': 'Notify with SMS',
#    'pdp_NotifyMe_OverseasTransfer': 'I agree to <a href="{infoTransferLink}">3rd Party and Overseas Transfer of Personal Information</a>',
#    'pdp_NotifyMe_PersonalInfo': 'I agree to the <a href="{infoCollectionLink}">collection and use of personal information</a>',
#    'pdp_NotifyMe_PrivacyPolicyLegal': 'I agree to Nikeâ\x80\x99s <a href="{privacyPolicyLink}">Privacy Policy</a> and <a href="{termsOfUseLink}">Terms of Use</a>',
#    'pdp_NotifyMe_SMSHeaderTitle': 'Add your mobile phone number.',
#    'pdp_NotifyMe_SendEmailTo': "We'll send an email to",
#    'pdp_NotifyMe_SendSMSTo': 'Weâ\x80\x99ll send an SMS to',
#    'pdp_NotifyMe_TermsOfUseLegal': 'I agree to Nikeâ\x80\x99s <a href="{termsOfUseLink}">Terms of Use</a>',
#    'pdp_NotifyMe_YouAreAllSet': "You're all set!",
#    'pdp_NotifyMe_title': "Don't Miss Out",
#    'pdp_PageNotFoundMessage': 'WE CANâ\x80\x99T FIND THE PAGE YOU ARE LOOKING FOR',
#    'pdp_RFYNotAuthorized': 'Sorry, this product is not reserved for you.',
#    'pdp_RFYProductExpiredOn': 'Expired on {expiredOn}',
#    'pdp_RFYProductRedeemedOn': 'Redeemed on {redeemedOn}',
#    'pdp_RFYRedeemProduct': 'Redeem',
#    'pdp_RFYSubtitle': 'Reserved for You',
#    'pdp_SeeMoreProducts': 'See More',
#    'pdp_SimilarStyles': 'Similar Styles',
#    'pdp_a11y_aria_choose_a_style_color': 'Choose a Style Color',
#    'pdp_a11y_avg_star_rating': 'Average Rating {rating} of {starCount}',
#    'pdp_addToCart': 'Add to Bag',
#    'pdp_addToCartErrorLabel': 'Error:',
#    'pdp_addToCartErrorText': 'This request timed out, please try again',
#    'pdp_addToWishlist': 'Add to Favorites',
#    'pdp_addedToCart': 'Added to Bag',
#    'pdp_addedToWishlist': 'Added to Favorites',
#    'pdp_additionalInfo': 'More Info',
#    'pdp_allProductsSoldOutMessage': 'This product is currently unavailable',
#    'pdp_also_includes_all_applicable_duties': 'Also includes all applicable duties',
#    'pdp_arrivesDate': 'Arrives',
#    'pdp_back': 'Back',
#    'pdp_bopisShipping': 'Shipping',
#    'pdp_button_close': 'Close',
#    'pdp_cartAndCheckout': 'Bag & Checkout',
#    'pdp_cartQuantity': 'Qty 1',
#    'pdp_check_back_soon_label': 'Check back soon.',
#    'pdp_check_back_soon_message': 'Unfortunately we are not able to fulfill orders in this country at this time. Please check back for future availability. ',
#    'pdp_checkout': 'Checkout',
#    'pdp_chooseSize': 'Select Size',
#    'pdp_closeDialogButtonLabel': 'Close this dialog window',
#    'pdp_cloudAddToCartError': 'An error has occurred: ',
#    'pdp_comingSoon': 'Coming Soon',
#    'pdp_continueShopping': 'Continue Shopping',
#    'pdp_cookie_banner_message': 'Nike processes information about your visit using cookies to improve site performance, facilitate social media sharing and offer advertising tailored to your interests. By continuing to browse our site, you agree to the use of these cookies. For more information see our {PrivacyPolicy}. You can adjust your preferences in {CookieSettings}.',
#    'pdp_cookie_settings': 'Cookie Settings',
#    'pdp_copyLink': 'Copy Link',
#    'pdp_copyLinkConfirmation': 'Copied',
#    'pdp_countdownDay': 'd',
#    'pdp_countdownHour': 'h',
#    'pdp_countdownMinute': 'm',
#    'pdp_countdownSecond': 's',
#    'pdp_country_of_origin': 'Country/Region of Origin:',
#    'pdp_currentlyUnavailable': 'Currently Unavailable',
#    'pdp_default_title': 'Nike Store. Shoes, Clothing & Gear.',
#    'pdp_estimateShippingTime': 'Estimate Shipping Time',
#    'pdp_fasterShippingOptions': 'Faster Shipping options may be available',
#    'pdp_feedbackText': 'Your input will help us create an even better shopping experience for you.',
#    'pdp_fitPrivacyHeader': 'Privacy',
#    'pdp_fitPrivacyModalCloseBtn': 'Close',
#    'pdp_fitPrivacyModalContent': '<h1>Your Privacy</h1>\n<ul>\n<li>Nike partners with <a href="https://www.fitanalytics.com/" target="_blank"><strong>Fit Analytics</strong></a> to recommend sizes on <a href="https://www.nike.com/" target="_blank">Nike.com</a>.</li><li>To help make those recommendations, <strong>Nike uses performance</strong> cookies and the information you provide.</li><li>Nike shares <strong>deidentified information</strong> with Fit Analytics to help improve size recommendations.</li><li>Nike only has access to general Fit Analytics statistics.</li>\n</ul>',
#    'pdp_fitSize': 'Your Nike Fit is',
#    'pdp_fit_opinion_runs_big': 'Runs Big',
#    'pdp_fit_opinion_runs_consistently_big': 'Customers who reviewed this product say it runs big.',
#    'pdp_fit_opinion_runs_consistently_small': 'Customers who reviewed this product say it runs small.',
#    'pdp_fit_opinion_runs_small': 'Runs Small',
#    'pdp_fit_opinion_runs_sometimes_big': 'Customers who reviewed this product say it runs slightly big.',
#    'pdp_fit_opinion_runs_sometimes_small': 'Customers who reviewed this product say it runs slightly small.',
#    'pdp_fit_opinion_runs_true': 'Customers who reviewed this product say it runs true to size.',
#    'pdp_freeShipping': 'Free Shipping with Nike Membership',
#    'pdp_gcChooseAnAmount': 'Choose an amount',
#    'pdp_gcColorwayTitle': 'Choose a design',
#    'pdp_gcCustomAmount': 'Custom amount:',
#    'pdp_gcCustomAmountMaxValueError': 'Gift card amount cannot exceed {maxValue}',
#    'pdp_gcCustomAmountMinValueError': 'Gift card amount must be at least {minValue}',
#    'pdp_gcCustomAmountRestrictedCharacterError': 'This contains a restricted character, please choose another.',
#    'pdp_gcDeliveryDetailsLink': 'Enter address',
#    'pdp_gcDeliveryDetailsText': "Let us know where it's going. ",
#    'pdp_gcDeliveryDetailsTitle': 'Add recipient delivery details',
#    'pdp_gcDeliveryMethod': 'Choose a delivery method',
#    'pdp_gcDeliveryMethodEmail': 'Email',
#    'pdp_gcDeliveryMethodMail': 'Mail',
#    'pdp_gcDigitalAddressEditButton': 'Edit',
#    'pdp_gcEmailInput': 'Email',
#    'pdp_gcLargeOrderButton': 'Need a Larger Order?',
#    'pdp_gcLargeOrderModalEmailLink': 'giftcards@nike.com',
#    'pdp_gcLargeOrderModalMainText': 'Just e-mail {emailLink} for more information or call Nike directly at 1-877-220-6453 for assistance. You will receive a reply or call-back during Nike corporate business hours (Monday through Friday, 8 AM â\x80\x93 5 PM Pacific Time, excluding holiday). Please do not send credit card information over email.',
#    'pdp_gcLargeOrderModalSubTitle': 'Need to order more than 10 cards or to put in an order totaling more than $5,000?',
#    'pdp_gcLargeOrderModalTitle': 'Need to Place a Larger Order?',
#    'pdp_gcNoPOBox': 'We do not deliver to P.O. Boxes',
#    'pdp_gcOptionalMessageErrorText': 'Your message is invalid, please try again.',
#    'pdp_gcOptionalMessageLabel': 'Add an optional message',
#    'pdp_gcOptionalMessageText': 'Enter a personalized message for the recipient.',
#    'pdp_gcQuantity': 'Quantity',
#    'pdp_gcRecipientAddress': 'Address',
#    'pdp_gcRecipientAddress2': 'Add Company, C/O, Apt, Suite, Unit (Optional)',
#    'pdp_gcRecipientAddressError': "Please enter recipient's address.",
#    'pdp_gcRecipientCity': 'City',
#    'pdp_gcRecipientCityError': "Please enter recipient's city.",
#    'pdp_gcRecipientEmailAddress': 'Email',
#    'pdp_gcRecipientEmailAddressError': 'Please enter a valid email address.',
#    'pdp_gcRecipientEmailError': 'Please enter a valid email address.',
#    'pdp_gcRecipientFirstName': 'First Name',
#    'pdp_gcRecipientFirstNameError': "Please enter recipient's first name.",
#    'pdp_gcRecipientLastName': 'Last Name',
#    'pdp_gcRecipientLastNameError': "Please enter recipient's last name.",
#    'pdp_gcRecipientState': 'State',
#    'pdp_gcRecipientStateError': "Please select recipient's state.",
#    'pdp_gcRecipientZip': 'Postal Code',
#    'pdp_gcRecipientZipError': 'Please enter a valid zip code.',
#    'pdp_gcStateDropdownTitle': 'Select a State',
#    'pdp_gcTCLink': 'Gift Card Terms and Conditions',
#    'pdp_gender_men': 'Men',
#    'pdp_gender_women': 'Women',
#    'pdp_gift_description': 'Send as an E-Gift',
#    'pdp_gift_link_message': 'Send Now',
#    'pdp_gift_message': 'You choose the gift, they choose the size and color.',
#    'pdp_gift_tooltip': "Send this item instantly, by email. They'll choose size and color, or use the gift value towards another Nike.com purchase.",
#    'pdp_helpUsImproveYourExperience': 'Help Us Improve Your Experience',
#    'pdp_highly_rated': 'Highly Rated',
#    'pdp_howItFits': 'How it Fits',
#    'pdp_incl_of_taxes': 'incl. of taxes',
#    'pdp_include_of_taxes_and_duties': 'incl. of taxes and duties',
#    'pdp_just_a_few_left_order_soon': 'Just a few left. Order soon.',
#    'pdp_just_a_few_left_order_soon_kr': 'Almost sold out. Order soon.',
#    'pdp_keepShopping': 'Keep Shopping',
#    'pdp_klarna_message': 'Buy now, pay in 3 installments with <span>Klarna</span>',
#    'pdp_klarna_message_short': '<span>Klarna</span> Available at checkout.',
#    'pdp_launchAvailableDate': 'Available {Launch_Date} at {Launch_Time}',
#    'pdp_launchBuyCTA': 'Buy',
#    'pdp_launchBuyableGuestIntro': 'Only Nike Members get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#    'pdp_launchBuyableMemberIntro': 'Only Nike Members like you get a chance to buy high-demand products like this one. {learnMoreButtonText}',
#    'pdp_launchCSGuestIntro': "Create or sign in to your free Nike Member account for a chance to buy this product the moment it's released. {learnMoreButtonText}",
#    'pdp_launchCSMemberIntro': "Nike Members like you are the only ones who have a chance to purchase this product when it's released. {learnMoreButtonText}",
#    'pdp_launchCheckoutErrorBody': 'There was a problem processing your payment.  Check your payment information and try again.',
#    'pdp_launchCheckoutErrorTitle': "Let's try this again.",
#    'pdp_launchCheckoutNotLoggedIn': 'Your session has expired.  Please refresh and login to continue.',
#    'pdp_launchCheckoutNumberNotVerified': 'Your session has expired.  Please refresh and login to continue.',
#    'pdp_launchComingSoon': 'Coming Soon',
#    'pdp_launchComingSoonStepOne': '1. Sign in to your Nike Member account or {joinButtonText}',
#    'pdp_launchComingSoonStepThree': '3. Verify your mobile number in account settings.',
#    'pdp_launchComingSoonStepTwo': '2. Confirm your payment info is updated. ',
#    'pdp_launchDismissModalButton': 'Continue Shopping',
#    'pdp_launchFirstParagraphComingSoon': "Introducing Line Checkout. Come back after a Product is available to get in line. If your turn comes up, we'll complete your order. Before getting in line, make sure you:",
#    'pdp_launchFirstParagraphGetInLine': "Line Checkout is the only way to buy some of our most popular products - like this one. Once you're in line and your turn comes up, we'll complete your order. ",
#    'pdp_launchGetInLine': 'Get in Line',
#    'pdp_launchGetInLineTitle': 'Get in Line. Get the goods.',
#    'pdp_launchInLineBodyModal': "If your turn comes up, we'll complete your order. ",
#    'pdp_launchJoinForFreeButton': 'join for free.',
#    'pdp_launchLMModalBePreparedBullet': 'Be prepared',
#    'pdp_launchLMModalBePreparedSubBullet': "Make sure you're signed in to your Nike Member account and ready when the product launches.",
#    'pdp_launchLMModalContinueShoppingCTA': 'Continue Shopping',
#    'pdp_launchLMModalFirstTitle': 'How Line Checkout Works',
#    'pdp_launchLMModalGuestJoinBullet': 'Become a Nike Member',
#    'pdp_launchLMModalGuestJoinSubBullet': 'Line Checkout is available only to Nike Members. Not a Member? {JoinForFree}',
#    'pdp_launchLMModalJoinForFree': 'Join for Free',
#    'pdp_launchLMModalJoinNikePlusCTA': 'Become a Nike Member',
#    'pdp_launchLMModalLineOne': 'To make sure Nike Members have an equal chance to purchase high-demand items on our site, we use a Line Checkout system.',
#    'pdp_launchLMModalLineThree': 'Wait times vary based on demand. Limit one item per Nike Member.',
#    'pdp_launchLMModalLineTwo': "If your chosen size and color is available when you're selected, we'll process your order. If your selection sells out before that, we'll let you know.",
#    'pdp_launchLMModalSecondTitle': 'Improve Your Odds',
#    'pdp_launchLMModalSecondTitleSubtitle': "Here's how to make your Line Checkout experience as easy as possible:",
#    'pdp_launchLMModalUpdateProfileBullet': 'Update your Nike Member profile',
#    'pdp_launchLMModalUpdateProfileSubBullet': 'Make sure your shipping and payment information is current.',
#    'pdp_launchLMModalUpdateSettingsCTA': 'Update Account Settings',
#    'pdp_launchLMModalVerifyMobileBullet': 'Verify your mobile number',
#    'pdp_launchLMModalVerifyMobileSubBullet': 'This layer of added security helps keep the Line Checkout process fair.',
#    'pdp_launchLearnMoreButtonText': 'Learn more',
#    'pdp_launchNonWinnerBody': "Thank you for entering for the Nike Air VaporMax. Unfortunately, it didn't work out this time.",
#    'pdp_launchNonWinnerTitle': "Didn't Get 'Em",
#    'pdp_launchNotifyYou': 'We will notify you in a moment whether you get a pair or not.',
#    'pdp_launchPending': "You're in line",
#    'pdp_launchSessionExpiredTitle': 'Session expired',
#    'pdp_launchSoldOut': 'Sold Out',
#    'pdp_launchUnavailableTitle': 'Product unavailable',
#    'pdp_launchWinnerBody': 'Congratulations on your purchase. A confirmation email is on the way.',
#    'pdp_launchWinnerTitle': 'You Got It',
#    'pdp_launchYouAreInLine': "You're Currently In Line",
#    'pdp_launchYouAreInLineBody': 'We will notify you in a moment whether you get a pair or not.',
#    'pdp_launch_coming_soon_title': 'Get in Line. Get the Goods.',
#    'pdp_launch_entered': 'Launch Entered',
#    'pdp_launch_non_winner': 'Non winner',
#    'pdp_launch_pending': 'Pending...',
#    'pdp_launch_purchased': 'Purchased',
#    'pdp_launch_unavailable': 'This product is no longer available.',
#    'pdp_learnMore': 'Learn More',
#    'pdp_limitedColorBadge': 'Limited Color',
#    'pdp_limitedTimeBadge': 'Seasonal (Limited Time Color)',
#    'pdp_low_inventory_order_soon': 'Low inventory! Order soon.',
#    'pdp_low_stock_message': 'Limited stock in selected size',
#    'pdp_manufacturerAccordionCopy': 'Declaration of Importer: Direct import by the individual customer<br><br>Marketed by: Nike Global Trading B.V. Singapore Branch, 30 Pasir Panjang Road, #10-31/32, Mapletree Business City, Singapore 117 440',
#    'pdp_manufacturerAccordionHeader': 'Product Information',
#    'pdp_member_exclusive_subtitle': 'Member Exclusive',
#    'pdp_member_exclusive_subtitle_na': 'Member Access',
#    'pdp_member_exclusive_support_message': 'Sign in or create a free Nike Member account to get this product.',
#    'pdp_member_exclusive_support_message_title': 'It only takes a Nike Membership',
#    'pdp_minicart_upsell_recommendations_title': 'Frequently Bought Together',
#    'pdp_nextDayShipping': 'Next-Day / Arrives 1-2 Business Days',
#    'pdp_no_return_text': 'This product is customized so the order cannot be cancelled 30 minutes after submit. Nike By You customized products do not apply to no reason return or exchange policy.',
#    'pdp_notAvailableForPickup': 'This item is not available for pickup',
#    'pdp_notifyMeSurveyText': 'If given the opportunity to be notified if this color becomes available, would you be interested?',
#    'pdp_numeric_range_separator': 'â\x80\x93',
#    'pdp_ok': 'OK',
#    'pdp_one_size': 'ONE SIZE',
#    'pdp_one_size_low_stock_message': 'Limited stock',
#    'pdp_pageNotFoundHeader': 'TIME OUT',
#    'pdp_percentageOff': 'off',
#    'pdp_pickUp': 'Free Pickup',
#    'pdp_pleaseSelectASize': 'Please select a size.',
#    'pdp_pre_order': 'Pre-Order',
#    'pdp_pre_order_get_it_first': 'Get it First:',
#    'pdp_pre_order_ships': 'Ships',
#    'pdp_privacy_policy_link': 'Privacy & Cookie Policy',
#    'pdp_productNotFound': 'THE PRODUCT YOU ARE LOOKING FOR IS NO LONGER AVAILABLE',
#    'pdp_productSoldOutMessage': 'This product is currently unavailable',
#    'pdp_product_crossedoutMessage': 'Discounted from',
#    'pdp_product_details_button': 'Read more',
#    'pdp_product_details_button_abtest_variant_a': 'View Product Details',
#    'pdp_promoMessaging': 'This product is excluded from site promotions and discounts.',
#    'pdp_recommendations_header': 'YOU MAY ALSO LIKE',
#    'pdp_recommendations_top_trending': 'TOP TRENDING',
#    'pdp_recommendedFitMessage': ' Fit: We recommend ordering a half-size up.',
#    'pdp_responsibleMaterials': 'Responsible Materials',
#    'pdp_review_text': 'Product received for free, or reviewed as part of a prize-draws/giveaway.\n<br>#productsprovidedbynike',
#    'pdp_review_text_na': 'Product received for free, or reviewed as part of a sweepstakes/giveaway.\n<br>#teamnike',
#    'pdp_reviews_accordion_panel_title': 'Reviews',
#    'pdp_reviews_add_review_button': 'Write a Review',
#    'pdp_reviews_mobile_loadmore_button': 'Load More',
#    'pdp_reviews_mobile_recpercent_button': '{{percent}}% of reviewers recommend this product',
#    'pdp_reviews_mobile_showLess_button': 'Less',
#    'pdp_reviews_mobile_showmore_button': 'More',
#    'pdp_reviews_more_review_button': 'More Reviews',
#    'pdp_reviews_no_reviews_txt': 'Have your say. Be the first to review the {{pTitle}}.',
#    'pdp_reviews_overall_rating_unit': 'Stars',
#    'pdp_reviews_sort_criterion_highest_rated': 'Highest Rated',
#    'pdp_reviews_sort_criterion_lowest_rated': 'Lowest Rated',
#    'pdp_reviews_sort_criterion_most_helpful': 'Most Helpful',
#    'pdp_reviews_sort_criterion_newest': 'Newest',
#    'pdp_reviews_sort_criterion_size_and_fit': 'Size & Fit',
#    'pdp_reviews_sort_label': 'Sort By:',
#    'pdp_sample_string': 'PDP string',
# ...
#      {'analytics': {'hashKey': '91bc7d81648fb0bc03bb2ddb0c6c45ed6a2b70f24144e35ecbfc5820408972c2'},
#       'subType': 'image',
#       'id': '91dd0dc1-df6b-4501-8297-0bcf4a64fb6c',
#       'type': 'card',
#       'version': '1633365137061',
#       'properties': {'portraitId': '',
#        'squarishURL': '',
#        'product': [],
#        'landscapeId': '',
#        'altText': '',
#        'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg',
#        'custom': {},
#        'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg',
#        'portrait': {'id': '84c9e581-df1b-44ba-b540-d21178c21295',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg'},
#        'title': '',
#        'squarishId': '',
#        'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#        'richTextLinks': [],
#        'subtitle': '',
#        'colorTheme': 'dark',
#        'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#         'modifiedDate': '2021-10-04T16:32:17.053Z',
#         'exposeTemplate': False,
#         'properties': {'actions': {}},
#         'resourceType': 'content/style'},
#        'actions': [],
#        'landscape': {'id': '9d61f74a-6c21-45d4-bb60-e94c06f3c945',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg'}}},
#      {'analytics': {'hashKey': 'fb66428b4726a52cb2f81f5739fe5be5d4b0ad04af664ecc30339ece62b60f98'},
#       'subType': 'text',
#       'id': '3a049537-aed5-44aa-b0f5-fb3e48e56399',
#       'type': 'card',
#       'version': '1633365089421',
#       'properties': {'copyId': 'a253dd95d0bae61b5d9ca9e207e32247ceb15df6',
#        'product': [],
#        'richTextLinks': [],
#        'custom': {},
#        'subtitle': '',
#        'colorTheme': 'dark',
#        'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#         'modifiedDate': '2021-10-04T16:31:29.405Z',
#         'exposeTemplate': False,
#         'properties': {'actions': {}},
#         'resourceType': 'content/style'},
#        'body': '<p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p>',
#        'title': 'Flexibility for Speed',
#        'actions': []}},
#      {'analytics': {'hashKey': 'add5b12590aa45c846ef8ab48ffb89ba2ee497d861dfff6291162efb2625bbc7'},
#       'subType': 'image',
#       'id': '072fa761-6350-45a0-9a85-88fad4ea24e7',
#       'type': 'card',
#       'version': '1633365102718',
#       'properties': {'portraitId': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#        'squarishURL': '',
#        'landscapeId': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#        'altText': '',
#        'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg',
#        'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg',
#        'portrait': {'id': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg'},
#        'title': '',
#        'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#        'richTextLinks': [],
#        'subtitle': '',
#        'colorTheme': 'dark',
#        'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#         'modifiedDate': '2021-10-04T16:31:42.718Z',
#         'exposeTemplate': False,
#         'resourceType': 'content/style'},
#        'actions': [],
#        'landscape': {'id': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg'}}},
#      {'analytics': {'hashKey': '19214ec1853bfd1aa0b5986f20c9f7bc1291c2d42405b07ae9d74bc303bb711d'},
#       'subType': 'text',
#       'id': '6de4f79e-1e52-4c01-a9d7-a21e9b8cb30b',
#       'type': 'card',
#       'version': '1633365097774',
#       'properties': {'copyId': 'd059f6db5527b41ea4abe44d472b2f9577221c23',
#        'product': [],
#        'richTextLinks': [],
#        'custom': {},
#        'subtitle': '',
#        'colorTheme': 'dark',
#        'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#         'modifiedDate': '2021-10-04T16:31:37.709Z',
#         'exposeTemplate': False,
#         'properties': {'actions': {}},
#         'resourceType': 'content/style'},
#        'body': '<p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p>',
#        'title': 'Stability for Strength',
#        'actions': []}}],
#     'layoutCards': [],
#     'firstImageUrl': 'https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png',
#     'firstImageAltText': 'Nike Free Metcon 4 Training Shoes',
#     'sustainabilityMessage': [],
#     'descriptionPreviewBullets': '',
#     'moreInfoMessages': [],
#     'sizeFitMessages': [],
#     'hubMessages': [],
#     'language': 'en',
#     'marketplace': 'US',
#     'availableSkus': [{'id': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da',
#       'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#       'resourceType': 'availableSkus',
#       'links': {'self': {'ref': '/deliver/available_skus/v1/ef237b73-2633-56fe-8ebd-fbc2258fa8da'}},
#       'available': True,
#       'level': 'LOW',
#       'skuId': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da'},
#      {'id': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f',
#       'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#       'resourceType': 'availableSkus',
#       'links': {'self': {'ref': '/deliver/available_skus/v1/2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'}},
#       'available': True,
#       'level': 'LOW',
#       'skuId': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'},
#      {'id': '9fd7e097-24db-5c33-b660-d300c3f6579c',
#       'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#       'resourceType': 'availableSkus',
#       'links': {'self': {'ref': '/deliver/available_skus/v1/9fd7e097-24db-5c33-b660-d300c3f6579c'}},
#       'available': True,
#       'level': 'LOW',
#       'skuId': '9fd7e097-24db-5c33-b660-d300c3f6579c'},
#      {'id': 'da0611fb-2af5-53fa-89c3-8baea350977b',
#       'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#       'resourceType': 'availableSkus',
#       'links': {'self': {'ref': '/deliver/available_skus/v1/da0611fb-2af5-53fa-89c3-8baea350977b'}},
#       'available': True,
#       'level': 'LOW',
#       'skuId': 'da0611fb-2af5-53fa-89c3-8baea350977b'},
#      {'id': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca',
#       'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#       'resourceType': 'availableSkus',
#       'links': {'self': {'ref': '/deliver/available_skus/v1/4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}},
#       'available': True,
#       'level': 'LOW',
#       'skuId': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}],
#     'publishType': 'FLOW',
#     'isLaunchView': False,
#     'launchView': None,
#     'isForNumberOfImagesABTesting': False,
#     'isMinimumAdvertisedPrice': False,
#     'collectionTermIds': ['c05bedd9-29d3-4e45-8c62-c463f9c5958f',
#      '1a70e9af-aea9-4a39-9773-fa6ced97c58b',
#      '65838112-1f4d-48a7-9b2f-1e8736c4cdcc',
#      'a49f8e69-ff9c-4356-89d8-d4a098fc02c2',
#      'e4e46ee6-496f-491a-8771-1a677eefee3a',
#      '94d2c954-14cd-4784-96ec-b02c950d2872',
#      '62f3c208-e1a3-45c0-9e70-a90be4e276f1',
#      'b9cefedb-1dd5-42dc-af13-939a240d4bb8',
#      '4be7e5d7-7e5b-460d-b3d7-41396b3fa985'],
#     'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#      '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#      '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#      'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#      '292efae5-2d9a-44a3-a529-cda684a47c44',
#      'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#      '7702dda3-62ca-3410-b4f3-97025be1089d',
#      '68a7b17f-291f-41f8-bf04-5e2fbe878d9b',
#      '05392778-fff6-4fa0-a375-2506d27f009e',
#      '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#      '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#      'b942d0ac-4887-4a8f-b914-d82a6181014f',
#      '67063381-90eb-4763-8f87-acc30b392f38',
#      '699b34a6-1950-3458-8322-910b695fccb7',
#      '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#      '10f9af5a-58d2-480a-a72d-5a65bd374850',
#      '0a937561-8633-3ea1-8ae3-8509f50f4127',
#      '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#      '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#      '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#      '539c6c43-d060-30b0-be5b-47c47f7c7658',
#      'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#      '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#      '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#      '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#      '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#      '2057952b-1a72-368e-b4b1-f67091ff1799',
#      '6e7e4809-fccb-4e82-8a7b-047125398076',
#      '9b0e77d0-aec5-4f4b-b8de-acb7a82e396d',
#      '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#      '7abdd901-856d-3601-94bf-14313cee8354',
#      '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#      'b5cd158b-b105-490c-b777-652943e742b0',
#      'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#      '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#      '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#      '16633190-45e5-4830-a068-232ac7aea82c',
#      '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#      '7817e756-7721-4cfb-b404-04df79c685e4',
#      'c29a0094-d302-4b7a-b5f0-73e46f772348'],
#     'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#     'catalogId': '1',
#     'selectedSkuId': {},
#     'sizeAndFitDescription': '',
#     'exclusiveAccess': False,
#     'notifyMeIndicator': False,
#     'promoExclusionAccess': False,
#     'useFeedsPromoExclusionMessage': False,
#     'jerseyIdPathName': '',
#     'nbyHubMessages': [],
#     'state': 'IN_STOCK'}}},
#  'NikeId': {'nikeIdPrebuildSuggestion': None,
#   'NBYBuilderModalOpen': False,
#   'metricId': '',
#   'itemId': '',
#   'gender': '',
#   'sizing': {},
#   'fit': '',
#   'showNBYBuyingTools': False,
#   'error': None,
#   'availability': False,
#   'async': {'prebuildSuggestions': False},
#   'isAvailable': True},
#  'NotQuiteReady': {'notQuiteReadyEvts': []},
#  'Fit': {'fitSize': '', 'localizedFitSize': '', 'isFitSizeSet': False},
#  'EDD': {'estimatedDeliveryData': None},
#  'User': {'user': {}, 'isSwoosh': False, 'initialized': False},
#  'FitAnalytics': {'fitAnalyticsRecommendedSize': None,
#   'fitAnalyticsFindMySizeClicked': False},
#  'Cart': {'isSizeSelectError': False,
#   'cartProduct': {},
#   'cartSku': {},
#   'wishlistProduct': {},
#   'wishlistSku': {},
#   'isWishlistConfirmationModalOpen': False,
#   'async': {},
#   'payload': {},
#   'cartError': []},
#  'Config': {'name': 'pdp',
#   'domain': 'dotcom',
#   'division': 'commerce',
#   'platform': 'cloud',
#   'version': '1.0.0',
#   'facebookAppId': '1397260880304609',
#   'channelId': 'd9a5bc42-4b9c-4976-858a-f159cf99c647',
#   'env': 'prod',
#   'dark': False,
#   'preview': False,
#   'branchIOKey': 'key_test_dcy0gJ0f2U1NBELEQXq8ElcgvumigPUu',
#   'defaultStyleColor': '724010-017',
#   'productStateOverride': None,
#   'gqlHash': '4bc133d8e69ba0dd907158346fed7f2e',
#   'flags': {'abTests': True,
#    'animateAccordionPanels': False,
#    'cookieSettings': False,
#    'cookieSettingsBanner': False,
#    'cutOverPdpToSegment': True,
#    'debug': False,
#    'enableMAP': True,
#    'filterByNikeDotComChannel': True,
#    'globalNavUseGeoPrivacy': True,
#    'gridRecommendations': True,
#    'hideBuyingTools': False,
#    'incentivizedReviewsMessageNA': True,
#    'incentivizedReviewsMessage': False,
#    'includeFacebookAppId': True,
#    'logoutShouldClearCart': True,
#    'lowInventoryMessage': True,
#    'loadWebShell': True,
#    'loadWebShellOnWall': False,
#    'loadForterScript': True,
#    'loadStylitics': True,
#    'notifyMe': True,
#    'showAvailabilityDate': False,
#    'recommendations': True,
#    'reserveForYou': True,
#    'sendPIDsOnWall': True,
#    'shareNBY': True,
#    'showCNNewYearsLink': False,
#    'showCgc': True,
#    'showColorWayPicker': True,
#    'showEGift': True,
#    'showElevatedContent': True,
#    'showFit': True,
#    'showGeoMismatch': True,
#    'showGiftCardMessage': True,
#    'showGiftCardTypeLink': True,
#    'showGiftCards': True,
#    'showJerseyId': True,
#    'showKlarnaPayMessage': True,
#    'showKlarnaPayLaterMessage': False,
#    'showLargeGiftCardOrder': True,
#    'showLaunchDebug': False,
#    'showLaunchProduct': True,
#    'showLeftHandNavCategories': True,
#    'showMobileWriteReview': True,
#    'showMoreInfo': True,
#    'showNBY': True,
#    'showNBYMessageHub': True,
#    'showNikeId': True,
#    'showOmni': False,
#    'showPhysicalGiftCards': True,
#    'showPromoBanner': True,
#    'showPromoMsg': True,
#    'showPromoExclusionMsg': True,
#    'showFeedsPromoExclusionMessage': False,
#    'showReadMore': True,
#    'showRelatedCategories': True,
#    'showReviews': True,
#    'showSEOCopy': False,
#    'showSinglesDaySalesLink': False,
#    'showSizeAndFit': True,
#    'showSizeCalculator': False,
#    'showSocialLinksNBY': True,
#    'showUniteTimers': False,
#    'showWidthSelector': True,
#    'showWishlist': True,
#    'skipPercentOff': False,
#    'skipSustainability': False,
#    'skipSegmentDupedEvents': True,
#    'swooshEligibleGeo': True,
#    'useBounceExchange': False,
#    'useDotcomNav': True,
#    'useDotcomNavESI': True,
#    'useExclusiveAccess': True,
#    'useFeedsMoreInfoMessage': False,
#    'useFeedsSizeFitMessage': False,
#    'useFeedsSustainabilityMessage': True,
#    'useMAPCollection': True,
#    'useNBYCloudUrl': True,
#    'useNBYImageService': True,
#    'useNeo': True,
#    'useNewRelic': True,
#    'useOptimizelyX': True,
#    'usePersonalizedNullSearch': False,
#    'useRollupKey': True,
#    'useSentryIO': False,
#    'useServiceCanonicalUrl': True,
#    'useSwitchboardRecommendations': False,
#    'useTTReviews': True,
#    'useUniteStaging': False,
#    'enableNikeShopModals': True,
#    'showElevatedCarousel': True,
#    'hideEDDFasterShippingOptionMsg': False,
#    'showEstimatedDeliveryDate': False,
#    'showEstimatedDeliveryDateAndPickup': True,
#    'showPickupLocation': True,
#    'showEDDAndBopisABTesting': False,
#    'wallFavorites': False,
#    'wallFiltersBtnFilterLabel': True,
#    'wallImpressions': True,
#    'wallNoResultsCarousel': True,
#    'useTTV5Reviews': True,
#    'useNotifyMeV2': False,
#    'isZoomEnabled': False},
#   'assetPaths': {},
#   'recommendationsScheme': 'product_rr',
#   'cacheDuration': {'404': 60,
#    'default': 900,
#    'launch': 900,
#    'pdp': 900,
#    'perf': 900,
#    'wall': 300},
#   'globalNavConfig': {'header': 'commerce-header',
#    'footer': 'footer',
#    'shared': 'shared',
#    'testHeader': 'commerce-header',
#    'testFooter': 'footer',
#    'testShared': 'shared'},
#   'optimizelyEndpoint': '//www.nike.com/assets/vendor/optimizely/prod/5aUCtZvFuDLjvdqdf2w53M.json',
#   'turnToConfig': {'turnToFetchTimeout': 350,
#    'turnToAuthBucket': 'shared/turnto/prod-auth-keys'},
#   'exp': '2011'},
#  'Console': {'providers': []},
#  'CrossSell': {'products': [], 'error': None, 'async': {'products': False}},
#  'Auth': {'bearer': ''},
#  'Experiments': {'activeExperiments': {}, 'forcedExperiments': {}},
#  'Launch': {'launchCheckoutModalOpen': False,
#   'launchCheckoutServices': 'launch-checkout'},
#  'MAPProducts': {'products': {}},
#  'Privacy': {'areSocialCookiesAllowed': False,
#   'arePerformanceCookiesAllowed': False,
#   'geoLoc': None,
#   'hasEUCookie': False},
#  'Device': {'breakpointMatched': False, 'deviceWidth': 'sm'},
#  'Overlays': [],
#  'Common': {'channel': 'NIKE',
#   'connection': {'saveData': False, 'effectiveType': None},
#   'globalHeaderFixedHeight': 60,
#   'globalHeaderHeight': 96,
#   'pageType': 'pdp',
#   'routes': [],
#   'siteHost': 'https://www.nike.com'},
#  'META': {'commit': ''},
#  'NOTIFY_ME': {'isNotifyMeModalOpen': False,
#   'page': 'default',
#   'journey': '',
#   'isNotifyMeSMSOpen': False,
#   'isNotifyMeEmailOpen': False,
#   'emailJourneyCompleted': False,
#   'smsJourneyCompleted': False,
#   'email': '',
#   'sms': ''},
#  'intl': {}}

# %%
json_object['props']['pageProps']['initialState'].keys()
# Out:
# dict_keys(['global', 'reviews', 'localization', 'banner', 'App', 'Threads', 'NikeId', 'NotQuiteReady', 'Fit', 'EDD', 'User', 'FitAnalytics', 'Cart', 'Config', 'Console', 'CrossSell', 'Auth', 'Experiments', 'Launch', 'MAPProducts', 'Privacy', 'Device', 'Overlays', 'Common', 'META', 'NOTIFY_ME', 'intl'])

# %%
# for i in json_object['props']['pageProps']['initialState'].keys():
#     print(i,"\n\n\n",json_object['props']['pageProps']['initialState'][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']
# Out:
# {'threads': None,
#  'error': None,
#  'async': {'threads': False,
#   'thread': False,
#   'availableSkus': False,
#   'prebuildSuggestion': None},
#  'products': {'DZ6326-001': {'id': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#    'threadId': '9cffc907-8db0-4932-bbc7-fae0f2bedc20',
#    'productId': '14231935',
#    'mainColor': False,
#    'productRollup': {'type': 'Standard', 'key': 'KX41Bv'},
#    'width': {'value': 'REGULAR', 'localizedValue': 'Regular'},
#    'athletes': [],
#    'styleColor': 'DZ6326-001',
#    'styleCode': 'DZ6326',
#    'category': 'Training,Cross Training',
#    'pid': '14231935',
#    'preOrder': False,
#    'preorderAvailabilityDate': '',
#    'commerceStartDate': '2022-11-07T15:00:00.000Z',
#    'isNYBCountDown': False,
#    'countdown': -1,
#    'hardLaunch': True,
#    'sportTags': ['Training', 'Cross Training'],
#    'genders': ['MEN'],
#    'brand': 'Nike',
#    'productType': 'FOOTWEAR',
#    'nikeIdStyleCode': '',
#    'productGroupId': '13888937',
#    'styleType': 'INLINE',
#    'status': 'ACTIVE',
#    'displayOrder': '',
#    'subTitle': 'Training Shoes',
#    'fullTitle': 'Nike Free Metcon 4 AMP Training Shoes',
#    'additionalInfo': None,
#    'sizeChart': None,
#    'langLocale': 'en_US',
#    'marketing': '',
#    'origin': [],
#    'colorDescription': 'Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black',
#    'description': '<div class="pi-tier3"><div class="pi-pdpmainbody"><p><b class="headline-5">&#xA0;</b></p><br><p>Whether you&#x2019;re rising with the roosters or squeezing in a late-night circuit session, these shoes help you stay fresh. They have an updated &quot;chain-link&quot; mesh that cools and flexes as you speed through agility drills, while support at the midfoot and heel helps brace you for your heaviest sets in the weight room.</p><br><p><b class="headline-5">Finding Light in the Darkness</b></p><p>During the winter solstice in the northern hemisphere, the sun has the appearance of being at a 30-degree angle of east and west when it rises and sets. Likewise, when researching the Free Metcon 4, we found the optimal angle for squatting ranges from 10 degrees to 30 degrees. The gradient, also angled at 30 degrees, goes from light to dark on the midsole and back again from dark to light to mimic the sun rising and setting during the solstice.</p><br><p><b class="headline-5">Blast from the Past</b></p><p>The 4 brings back the tough, yet breathable mesh from the original version. The upper gets embellished with a Huarache-inspired strap and rubber-striped sidewall that envelops your heel to help brace you for movement in any direction.</p><br><p><b class="headline-5">Flexibility for Speed</b></p><p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the ankle lets your foot move naturally as you burst, cut and brake.</p><br><p><b class="headline-5">Stability for Strength</b></p><p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable, yet secure feel during sudden stops and quick cuts.</p><br><p><b class="headline-5">More Benefits</b></p><ul><li>Rubber tread in high-wear areas gives you durable traction.</li><li>Rubberized logo at the tongue nods to the Nike Air Huarache of the early &apos;90s.</li></ul><br><p><b class="headline-5">Product Details</b></p><ul><li>Reflective details</li><li>This product is not intended for use as Personal Protective Equipment (PPE)<li>Shown: Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black</li><li>Style: DZ6326-001</li></li></ul></div></div>',
#    'descriptionPreview': 'Whether youâ\x80\x99re rising with the roosters or squeezing in a late-night circuit session, these shoes help you stay fresh. They have an updated "chain-link" mesh that cools and flexes as you speed through agility drills, while support at the midfoot and heel helps brace you for your heaviest sets in the weight room.',
#    'nbyContentCopy': {},
#    'prebuildId': '',
#    'mainPrebuild': '',
#    'isNikeID': False,
#    'isNBYDesign': False,
#    'updatedNBYDesignKey': '',
#    'piid': '',
#    'pathName': '',
#    'vas': [{'id': '0cba9a6c-ac96-5e0a-8bd9-0d31d5095a7c',
#      'vasType': 'GIFT_MESSAGE'},
#     {'id': '3d62c037-56f3-59d5-81d3-88ce17f7fb99', 'vasType': 'GIFT_WRAP'}],
#    'nbyCustomMessage': '',
#    'seoProductDescription': 'Find the Nike Free Metcon 4 AMP at Nike.com. ',
#    'seoProductAvailability': True,
#    'seoProductReleaseDate': '2022-11-07T15:00:00.000Z',
#    'discounted': False,
#    'fullPrice': 120,
#    'currentPrice': 120,
#    'employeePrice': 72,
#    'currency': 'USD',
#    'skus': [{'id': '28611818',
#      'nikeSize': '6',
#      'skuId': '5882ae76-f77b-5c7b-9566-9bb251ec918a',
#      'localizedSize': 'M 6 / W 7.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903069',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611821',
#      'nikeSize': '6.5',
#      'skuId': '3987819d-242d-5195-84af-4d3164e6bdab',
#      'localizedSize': 'M 6.5 / W 8',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903076',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611817',
#      'nikeSize': '7',
#      'skuId': '3de024b3-24a1-5214-a36d-f6bf82b4f5ab',
#      'localizedSize': 'M 7 / W 8.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903083',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611926',
#      'nikeSize': '7.5',
#      'skuId': 'cab139f1-7cc2-5ae8-a33a-fd93e1e92df9',
#      'localizedSize': 'M 7.5 / W 9',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903090',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611816',
#      'nikeSize': '8',
#      'skuId': 'e90f4262-9f0a-5311-8c19-21c5c7449b5f',
#      'localizedSize': 'M 8 / W 9.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903106',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611820',
#      'nikeSize': '8.5',
#      'skuId': 'ed5a02bf-9c8b-5f43-a9fb-c35da62402d0',
#      'localizedSize': 'M 8.5 / W 10',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903113',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611931',
#      'nikeSize': '9',
#      'skuId': 'cb969ea8-41df-5c36-a45a-5d2f5efe7dc6',
#      'localizedSize': 'M 9 / W 10.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903120',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611928',
#      'nikeSize': '9.5',
#      'skuId': 'abbdcf42-bd26-5534-b9f7-997e24291d6d',
#      'localizedSize': 'M 9.5 / W 11',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903137',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611815',
#      'nikeSize': '10',
#      'skuId': 'ccbf718e-fe42-55a4-91dc-b49dfa037b09',
#      'localizedSize': 'M 10 / W 11.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903144',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611929',
#      'nikeSize': '10.5',
#      'skuId': '92cb22af-23cc-517c-a753-2b5d8cbb8e62',
#      'localizedSize': 'M 10.5 / W 12',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903151',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611824',
#      'nikeSize': '11',
#      'skuId': 'f5f65912-814f-5c7b-91dc-c32637597c36',
#      'localizedSize': 'M 11 / W 12.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903168',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611822',
#      'nikeSize': '11.5',
#      'skuId': 'e858df03-7621-5a3d-b057-8e75cd505053',
#      'localizedSize': 'M 11.5 / W 13',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903175',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611823',
#      'nikeSize': '12',
#      'skuId': '60c37dc4-4d5c-5f81-89c2-f84b346b304d',
#      'localizedSize': 'M 12 / W 13.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903182',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611927',
#      'nikeSize': '12.5',
#      'skuId': 'ab44c806-bc75-5ad7-9514-172c54c7ddab',
#      'localizedSize': 'M 12.5 / W 14',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903199',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611930',
#      'nikeSize': '13',
#      'skuId': '513d2161-039d-598e-8778-3e5a4bf3262c',
#      'localizedSize': 'M 13 / W 14.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903205',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611825',
#      'nikeSize': '14',
#      'skuId': '45262cba-73c3-56b6-bc5b-f62346cf2afc',
#      'localizedSize': 'M 14 / W 15.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903212',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#     {'id': '28611819',
#      'nikeSize': '15',
#      'skuId': '9b2de139-5e2c-58c5-a3a1-ddbb465464df',
#      'localizedSize': 'M 15 / W 16.5',
#      'localizedSizePrefix': '',
#      'gtin': '00196151903229',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'}],
#    'title': 'Nike Free Metcon 4 AMP',
#    'nodes': [{'analytics': {'hashKey': '8507619bf0bb71e8363df7a1bc1bf90fe85d72d1c0250a117047376808099daa'},
#      'nodes': [{'analytics': {'hashKey': 'b1571054c01b752e2ad44ea07a64648f9caaf21a8e6a0211705fc5b9a542a676'},
#        'subType': 'image',
#        'id': 'f7d3ff8a-ccb4-4858-a7b6-bea05605c671',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': '82ddc691-dfe5-4fe0-913c-38e17ecfdb60',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'A',
#          'aspectRatio': 1,
#          'id': '79fcb768-1a4d-4bce-926d-3c6539562a28',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'A',
#          'aspectRatio': 0.8,
#          'id': '82ddc691-dfe5-4fe0-913c-38e17ecfdb60',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '79fcb768-1a4d-4bce-926d-3c6539562a28',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': '0e929a251e86702ee939291a3690688fba91fd8e5d7107d5b32c42f5337efb87'},
#        'subType': 'image',
#        'id': 'e474b409-ecd7-4aa0-ae5e-17cc29561b24',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': 'cd1114b3-263c-49ae-a967-f94f52190198',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/7a1c62b2-a916-432f-8a39-4037684da27f/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/cd1114b3-263c-49ae-a967-f94f52190198/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'B',
#          'aspectRatio': 1,
#          'id': '7a1c62b2-a916-432f-8a39-4037684da27f',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/7a1c62b2-a916-432f-8a39-4037684da27f/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'B',
#          'aspectRatio': 0.8,
#          'id': 'cd1114b3-263c-49ae-a967-f94f52190198',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/cd1114b3-263c-49ae-a967-f94f52190198/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '7a1c62b2-a916-432f-8a39-4037684da27f',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': '4370af7e3c57dc3edbe818703bf2096e63148078cf9f54ba72619f96b1404d40'},
#        'subType': 'image',
#        'id': '3c509500-b816-4885-b983-8e0bafa8a547',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': '1ba822e4-a2ce-414c-ac89-250aa7b54b97',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/47a379ef-24a6-4b68-8855-6ea12ce19f51/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/1ba822e4-a2ce-414c-ac89-250aa7b54b97/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'C',
#          'aspectRatio': 1,
#          'id': '47a379ef-24a6-4b68-8855-6ea12ce19f51',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/47a379ef-24a6-4b68-8855-6ea12ce19f51/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'C',
#          'aspectRatio': 0.8,
#          'id': '1ba822e4-a2ce-414c-ac89-250aa7b54b97',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/1ba822e4-a2ce-414c-ac89-250aa7b54b97/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '47a379ef-24a6-4b68-8855-6ea12ce19f51',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'ea18402dd82aa539e5987444ce1fd76071eda5a92e775c378e3069d4f98e9e77'},
#        'subType': 'image',
#        'id': '8402cae9-b073-49c0-8a29-659dd7bd7dbe',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': '55b0d24b-52b4-4fed-9f72-56ccc268d8ad',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/2fbce74d-776b-4186-aa42-2606202cb6c9/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/55b0d24b-52b4-4fed-9f72-56ccc268d8ad/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'D',
#          'aspectRatio': 1,
#          'id': '2fbce74d-776b-4186-aa42-2606202cb6c9',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/2fbce74d-776b-4186-aa42-2606202cb6c9/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'D',
#          'aspectRatio': 0.8,
#          'id': '55b0d24b-52b4-4fed-9f72-56ccc268d8ad',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/55b0d24b-52b4-4fed-9f72-56ccc268d8ad/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '2fbce74d-776b-4186-aa42-2606202cb6c9',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': '470f4e085c88b613f0c4000b063cbcab5a51b80dbf0a1f2d0bb3a6bb5b21a68e'},
#        'subType': 'image',
#        'id': 'f806e5bd-bcf0-44d1-a77a-d414a0b0313c',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': 'f5691c40-fd8b-4262-8b7f-912a52ddeb86',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/b03a6759-99c8-4997-8088-381528e3c0da/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/f5691c40-fd8b-4262-8b7f-912a52ddeb86/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'E',
#          'aspectRatio': 1,
#          'id': 'b03a6759-99c8-4997-8088-381528e3c0da',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/b03a6759-99c8-4997-8088-381528e3c0da/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'E',
#          'aspectRatio': 0.8,
#          'id': 'f5691c40-fd8b-4262-8b7f-912a52ddeb86',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/f5691c40-fd8b-4262-8b7f-912a52ddeb86/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': 'b03a6759-99c8-4997-8088-381528e3c0da',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'bfc9c556784de4b752446e9f1f4b46d52359e2401710d48649dee47e3fc17874'},
#        'subType': 'image',
#        'id': 'f8eb3911-7cc1-4920-95a0-8e6e4430897b',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': '72866978-a3b9-413d-9d5b-63aaf813e8a1',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/0733a458-23b9-4c71-9e95-e9b2ddd5db93/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/72866978-a3b9-413d-9d5b-63aaf813e8a1/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'F',
#          'aspectRatio': 1,
#          'id': '0733a458-23b9-4c71-9e95-e9b2ddd5db93',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/0733a458-23b9-4c71-9e95-e9b2ddd5db93/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'F',
#          'aspectRatio': 0.8,
#          'id': '72866978-a3b9-413d-9d5b-63aaf813e8a1',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/72866978-a3b9-413d-9d5b-63aaf813e8a1/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '0733a458-23b9-4c71-9e95-e9b2ddd5db93',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': '120724112c655b1db31616e63f2a5691b76ac825c2f0a8755223acd5c37102ad'},
#        'subType': 'image',
#        'id': '64ba420a-bea8-490b-b80c-66a52b6edb97',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': '85d13fc6-7e6d-4374-8db5-7bc3da70b292',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/0a473bce-9366-4f2c-92cc-3be954b7fc41/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/85d13fc6-7e6d-4374-8db5-7bc3da70b292/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'H',
#          'aspectRatio': 1,
#          'id': '0a473bce-9366-4f2c-92cc-3be954b7fc41',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/0a473bce-9366-4f2c-92cc-3be954b7fc41/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'H',
#          'aspectRatio': 0.8,
#          'id': '85d13fc6-7e6d-4374-8db5-7bc3da70b292',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/85d13fc6-7e6d-4374-8db5-7bc3da70b292/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '0a473bce-9366-4f2c-92cc-3be954b7fc41',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'c5ac916793e6e6260ad69b2d84bc0ccb9b396978d7b603c124608d398b654350'},
#        'subType': 'image',
#        'id': 'a4ac9821-c5a7-43d1-8398-9b8d61b7fbbe',
#        'type': 'card',
#        'version': '1674603758297',
#        'properties': {'portraitId': '7890eeb4-47c1-4000-a994-871702a3d9e5',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/2218e1fe-bb35-4076-ade9-caa23bb72a30/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/7890eeb4-47c1-4000-a994-871702a3d9e5/free-metcon-4-amp-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'K',
#          'aspectRatio': 1,
#          'id': '2218e1fe-bb35-4076-ade9-caa23bb72a30',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/2218e1fe-bb35-4076-ade9-caa23bb72a30/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'K',
#          'aspectRatio': 0.8,
#          'id': '7890eeb4-47c1-4000-a994-871702a3d9e5',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/7890eeb4-47c1-4000-a994-871702a3d9e5/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '2218e1fe-bb35-4076-ade9-caa23bb72a30',
#         'subtitle': '',
#         'colorTheme': 'dark'}}],
#      'subType': 'carousel',
#      'id': '7d083f29-02d4-48cb-a485-d01ad4318ba3',
#      'type': 'card',
#      'version': '1674603758297',
#      'properties': {'containerType': 'grid',
#       'loop': False,
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'autoPlay': False,
#       'title': '',
#       'body': '',
#       'speed': 6000}}],
#    'layoutCards': [],
#    'firstImageUrl': 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png',
#    'firstImageAltText': 'Nike Free Metcon 4 AMP Training Shoes',
#    'sustainabilityMessage': [],
#    'descriptionPreviewBullets': '',
#    'moreInfoMessages': [],
#    'sizeFitMessages': [],
#    'hubMessages': [],
#    'language': 'en',
#    'marketplace': 'US',
#    'availableSkus': [{'id': '3de024b3-24a1-5214-a36d-f6bf82b4f5ab',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/3de024b3-24a1-5214-a36d-f6bf82b4f5ab'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': '3de024b3-24a1-5214-a36d-f6bf82b4f5ab'},
#     {'id': 'cab139f1-7cc2-5ae8-a33a-fd93e1e92df9',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/cab139f1-7cc2-5ae8-a33a-fd93e1e92df9'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'cab139f1-7cc2-5ae8-a33a-fd93e1e92df9'},
#     {'id': 'e90f4262-9f0a-5311-8c19-21c5c7449b5f',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/e90f4262-9f0a-5311-8c19-21c5c7449b5f'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'e90f4262-9f0a-5311-8c19-21c5c7449b5f'},
#     {'id': 'ed5a02bf-9c8b-5f43-a9fb-c35da62402d0',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/ed5a02bf-9c8b-5f43-a9fb-c35da62402d0'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'ed5a02bf-9c8b-5f43-a9fb-c35da62402d0'},
#     {'id': 'cb969ea8-41df-5c36-a45a-5d2f5efe7dc6',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/cb969ea8-41df-5c36-a45a-5d2f5efe7dc6'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'cb969ea8-41df-5c36-a45a-5d2f5efe7dc6'},
#     {'id': 'abbdcf42-bd26-5534-b9f7-997e24291d6d',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/abbdcf42-bd26-5534-b9f7-997e24291d6d'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'abbdcf42-bd26-5534-b9f7-997e24291d6d'},
#     {'id': 'ccbf718e-fe42-55a4-91dc-b49dfa037b09',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/ccbf718e-fe42-55a4-91dc-b49dfa037b09'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'ccbf718e-fe42-55a4-91dc-b49dfa037b09'},
#     {'id': '92cb22af-23cc-517c-a753-2b5d8cbb8e62',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/92cb22af-23cc-517c-a753-2b5d8cbb8e62'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': '92cb22af-23cc-517c-a753-2b5d8cbb8e62'},
#     {'id': 'f5f65912-814f-5c7b-91dc-c32637597c36',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/f5f65912-814f-5c7b-91dc-c32637597c36'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'f5f65912-814f-5c7b-91dc-c32637597c36'},
#     {'id': 'e858df03-7621-5a3d-b057-8e75cd505053',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/e858df03-7621-5a3d-b057-8e75cd505053'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': 'e858df03-7621-5a3d-b057-8e75cd505053'},
#     {'id': '60c37dc4-4d5c-5f81-89c2-f84b346b304d',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/60c37dc4-4d5c-5f81-89c2-f84b346b304d'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': '60c37dc4-4d5c-5f81-89c2-f84b346b304d'},
#     {'id': 'ab44c806-bc75-5ad7-9514-172c54c7ddab',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/ab44c806-bc75-5ad7-9514-172c54c7ddab'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': 'ab44c806-bc75-5ad7-9514-172c54c7ddab'},
#     {'id': '513d2161-039d-598e-8778-3e5a4bf3262c',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/513d2161-039d-598e-8778-3e5a4bf3262c'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': '513d2161-039d-598e-8778-3e5a4bf3262c'},
#     {'id': '45262cba-73c3-56b6-bc5b-f62346cf2afc',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/45262cba-73c3-56b6-bc5b-f62346cf2afc'}},
#      'available': True,
#      'level': 'HIGH',
#      'skuId': '45262cba-73c3-56b6-bc5b-f62346cf2afc'},
#     {'id': '9b2de139-5e2c-58c5-a3a1-ddbb465464df',
#      'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/9b2de139-5e2c-58c5-a3a1-ddbb465464df'}},
#      'available': True,
#      'level': 'MEDIUM',
#      'skuId': '9b2de139-5e2c-58c5-a3a1-ddbb465464df'}],
#    'publishType': 'FLOW',
#    'isLaunchView': False,
#    'launchView': None,
#    'isForNumberOfImagesABTesting': False,
#    'isMinimumAdvertisedPrice': False,
#    'collectionTermIds': ['698d17bc-daf4-42d9-aee7-15841c59798c'],
#    'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#     '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#     '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#     '618e0e56-f642-3b7e-b1a9-1ec3d14a4bb0',
#     '5c357820-4cff-37a6-b815-984753484f06',
#     '7af3d3c5-a8cf-39aa-a8da-e5ec24c016de',
#     '292efae5-2d9a-44a3-a529-cda684a47c44',
#     'd984f2d7-84d4-37c9-b860-1c89d499358f',
#     'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#     '05392778-fff6-4fa0-a375-2506d27f009e',
#     '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#     '848bddbb-341c-3c70-8b77-05fe5d862c14',
#     '67063381-90eb-4763-8f87-acc30b392f38',
#     '539c6c43-d060-30b0-be5b-47c47f7c7658',
#     'f5cdf573-63b1-3d72-bc11-e4173c20c09f',
#     '1f497f51-bf0b-35fb-ab50-571f29a4daf1',
#     '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#     '25681ef3-6dec-3029-98fc-98da0a431aac',
#     'ce920033-3ed0-3855-a3d9-e82dde5776c7',
#     '6e7e4809-fccb-4e82-8a7b-047125398076',
#     '7abdd901-856d-3601-94bf-14313cee8354',
#     '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#     'c030f969-024a-3791-83ac-6e505b324861',
#     '7a223c0d-276a-3ce4-ade6-cc5c8d636bfa',
#     'a2244eab-52ab-3039-9df3-f264504b2c3e',
#     '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#     '0af553b6-7079-331b-a9d4-934c3966f7d1',
#     'fd271500-77b7-3553-9cde-2fb03391f223',
#     '7cf5846a-5c1e-3be6-bbff-74de4f88e7f0',
#     'b0a98271-206e-3a5c-ba51-51de7b0df907',
#     '7817e756-7721-4cfb-b404-04df79c685e4',
#     'c6709307-0293-31bb-93a5-25dc36fac4fa',
#     '9bcffd0c-90ac-4ed5-bff8-3183079c0850',
#     'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#     '3622c403-7151-3db8-ac44-d0fbeee71197',
#     '7702dda3-62ca-3410-b4f3-97025be1089d',
#     '7f4a6937-eb06-31c3-b4d8-a985366ec99b',
#     '918e3967-2990-3a54-a8d9-83d0704c1b95',
#     '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#     'a19080d2-a9de-3523-a98d-0ffaddb287fd',
#     '86100864-8775-456d-9647-0bb7d36da3ac',
#     '699b34a6-1950-3458-8322-910b695fccb7',
#     '9f483c28-b828-327b-9e6b-8b12441a1b16',
#     'b6635f29-bb01-3ccd-9ade-dae66cf82e4c',
#     '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#     '10f9af5a-58d2-480a-a72d-5a65bd374850',
#     '0a937561-8633-3ea1-8ae3-8509f50f4127',
#     '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#     '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#     '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#     'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#     '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#     'abb0cf06-d7c2-41b7-97ba-c6d5ef5f43ed',
#     '4a528b33-a71b-342c-baa2-616a89985fef',
#     '7a1af8aa-7163-34a2-bf12-c2c7bc01b85c',
#     '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#     '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#     '2057952b-1a72-368e-b4b1-f67091ff1799',
#     '11873a21-5755-3ab1-9d43-43154f0866f6',
#     '66fd0467-2345-3d11-9c0e-17101482a5a9',
#     '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#     'b5cd158b-b105-490c-b777-652943e742b0',
#     'd23dd206-e459-3d50-b3fe-5ca4426137d3',
#     'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#     '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#     '16633190-45e5-4830-a068-232ac7aea82c',
#     'a69a29b5-4dbd-3df9-a010-5d71b2a24682',
#     '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#     '0ba21a73-e751-3354-b408-42e35d56e50b'],
#    'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#    'catalogId': '1',
#    'selectedSkuId': {},
#    'sizeAndFitDescription': '',
#    'exclusiveAccess': False,
#    'notifyMeIndicator': False,
#    'promoExclusionAccess': False,
#    'useFeedsPromoExclusionMessage': False,
#    'jerseyIdPathName': '',
#    'nbyHubMessages': [],
#    'state': 'IN_STOCK'},
#   'CT3886-011': {'id': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c',
#    'threadId': '203f2607-5a2b-3926-a2de-20782076460d',
#    'productId': '13182452',
#    'mainColor': False,
#    'productRollup': {'type': 'Standard', 'key': 'KX41Bv'},
#    'width': None,
#    'athletes': [],
#    'styleColor': 'CT3886-011',
#    'styleCode': 'CT3886',
#    'category': 'Training,Cross Training',
#    'pid': '13182452',
#    'preOrder': False,
#    'preorderAvailabilityDate': '',
#    'commerceStartDate': '2021-04-01T17:00:00.000Z',
#    'isNYBCountDown': False,
#    'countdown': -1,
#    'hardLaunch': False,
#    'sportTags': ['Training', 'Cross Training'],
#    'genders': ['MEN'],
#    'brand': 'Nike',
#    'productType': 'FOOTWEAR',
#    'nikeIdStyleCode': '',
#    'productGroupId': '13888937',
#    'styleType': 'INLINE',
#    'status': 'ACTIVE',
#    'displayOrder': '',
#    'subTitle': 'Training Shoes',
#    'fullTitle': 'Nike Free Metcon 4 Training Shoes',
#    'additionalInfo': None,
#    'sizeChart': None,
#    'langLocale': 'en_US',
#    'marketing': '',
#    'origin': [],
#    'colorDescription': 'Iron Grey/Grey Fog/White/Black',
#    'description': '<div class="pi-tier3"><div class="pi-pdpmainbody"><p><b class="headline-5">FREE FLEXIBILITY WITH METCON MUSCLE.</b></p><br><p>The Nike Free Metcon 4 combines flexibility with stability to help you get the most out of your training program. Updated &quot;chain-link&quot; mesh cools and flexes as you speed through agility drills, while support at the midfoot and heel braces you for your heaviest sets in the weight room.</p><br><p><b class="headline-5">Blast From the Past</b></p><p>The 4 is bringing back the super tough yet breathable mesh from the original version. The upper gets embellished with a Huarache-inspired strap and rubber-striped sidewall that envelops your heel to brace you for movement in any direction.</p><br><p><b class="headline-5">Flexibility for Speed</b></p><p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p><br><p><b class="headline-5">Stability for Strength</b></p><p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p><br><p><b class="headline-5">More Benefits</b></p><ul><li>Rubberized logo at the tongue nods to the Huarache of the early &apos;90s.</li><li>Rubber tread in high-wear areas gives you durable traction.<li>Shown: Iron Grey/Grey Fog/White/Black</li><li>Style: CT3886-011</li></li></ul></div></div>',
#    'descriptionPreview': 'The Nike Free Metcon 4 combines flexibility with stability to help you get the most out of your training program. Updated "chain-link" mesh cools and flexes as you speed through agility drills, while support at the midfoot and heel braces you for your heaviest sets in the weight room.',
#    'nbyContentCopy': {},
#    'prebuildId': '',
#    'mainPrebuild': '',
#    'isNikeID': False,
#    'isNBYDesign': False,
#    'updatedNBYDesignKey': '',
#    'piid': '',
#    'pathName': '',
#    'vas': [{'id': '0cba9a6c-ac96-5e0a-8bd9-0d31d5095a7c',
#      'vasType': 'GIFT_MESSAGE'},
#     {'id': '3d62c037-56f3-59d5-81d3-88ce17f7fb99', 'vasType': 'GIFT_WRAP'}],
#    'nbyCustomMessage': '',
#    'seoProductDescription': 'Find the Nike Free Metcon 4 at Nike.com. ',
#    'seoProductAvailability': True,
#    'seoProductReleaseDate': '2021-04-01T17:00:00.000Z',
#    'discounted': False,
#    'fullPrice': 120,
#    'currentPrice': 120,
#    'employeePrice': 72,
#    'currency': 'USD',
#    'skus': [{'id': '26149419',
#      'nikeSize': '3.5',
#      'skuId': '3326fd88-94e2-5eb6-88e0-a70ecb9ce819',
#      'localizedSize': 'M 3.5 / W 5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093755',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149406',
#      'nikeSize': '4',
#      'skuId': '63435867-0edc-5711-899e-b2209d8d54dc',
#      'localizedSize': 'M 4 / W 5.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093762',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149417',
#      'nikeSize': '4.5',
#      'skuId': '8771988c-5a40-5629-b35a-a2f9d166d895',
#      'localizedSize': 'M 4.5 / W 6',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093779',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149404',
#      'nikeSize': '5',
#      'skuId': 'e8f32f1b-29f5-5cd1-9f09-66bf34b875c9',
#      'localizedSize': 'M 5 / W 6.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093786',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149415',
#      'nikeSize': '5.5',
#      'skuId': 'c0731c22-09fe-57ce-a5ef-f0035d19f669',
#      'localizedSize': 'M 5.5 / W 7',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093793',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149402',
#      'nikeSize': '6',
#      'skuId': '43d7da07-b929-5c7d-9cdf-dba909165f1c',
#      'localizedSize': 'M 6 / W 7.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093809',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149413',
#      'nikeSize': '6.5',
#      'skuId': '9b5c82d3-b2c4-58ac-bfbc-3591f1652814',
#      'localizedSize': 'M 6.5 / W 8',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093816',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149401',
#      'nikeSize': '7',
#      'skuId': 'e7957e80-34f2-5dd7-92ca-d62e2bdd73d6',
#      'localizedSize': 'M 7 / W 8.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093823',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149411',
#      'nikeSize': '7.5',
#      'skuId': 'd693a6a5-c55b-58f0-8a2f-f246bc754387',
#      'localizedSize': 'M 7.5 / W 9',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093830',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149424',
#      'nikeSize': '8',
#      'skuId': 'f7457e1d-877c-511f-a527-ef792918dab1',
#      'localizedSize': 'M 8 / W 9.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093847',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149409',
#      'nikeSize': '8.5',
#      'skuId': '14595e30-a4e5-58eb-bee3-0f102d2d5c5f',
#      'localizedSize': 'M 8.5 / W 10',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093854',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149423',
#      'nikeSize': '9',
#      'skuId': '640dca4c-b4f5-57f6-9759-52c345a2b565',
#      'localizedSize': 'M 9 / W 10.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093861',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149407',
#      'nikeSize': '9.5',
#      'skuId': '07957ad4-33cd-5c73-b25c-4e88f6637f21',
#      'localizedSize': 'M 9.5 / W 11',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093878',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149418',
#      'nikeSize': '10',
#      'skuId': 'a4877014-12a3-56dd-a00e-54fabfd73a86',
#      'localizedSize': 'M 10 / W 11.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093885',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149422',
#      'nikeSize': '10.5',
#      'skuId': '52228558-4358-5534-b0d9-bd92155cd1ca',
#      'localizedSize': 'M 10.5 / W 12',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093892',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149416',
#      'nikeSize': '11',
#      'skuId': 'dcff2c3b-c37f-58b7-bcbc-479c503dfd75',
#      'localizedSize': 'M 11 / W 12.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093908',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149421',
#      'nikeSize': '11.5',
#      'skuId': '2938ab34-6f3f-5cbb-bfa6-a508f798145f',
#      'localizedSize': 'M 11.5 / W 13',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093915',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149414',
#      'nikeSize': '12',
#      'skuId': '61bc2026-cc74-5efa-b413-2ecaa0d5b2c8',
#      'localizedSize': 'M 12 / W 13.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093922',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149420',
#      'nikeSize': '12.5',
#      'skuId': '43fdfd68-c88c-50ea-a5c3-b756139a63cb',
#      'localizedSize': 'M 12.5 / W 14',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093939',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149412',
#      'nikeSize': '13',
#      'skuId': '52de77e2-45a4-54f6-9c5f-416740e44774',
#      'localizedSize': 'M 13 / W 14.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093946',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149410',
#      'nikeSize': '14',
#      'skuId': '3771d271-23d9-5c5e-a6d0-c04f476f59f9',
#      'localizedSize': 'M 14 / W 15.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093953',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149408',
#      'nikeSize': '15',
#      'skuId': '84c745ff-9caf-5e61-8337-dde205881cc4',
#      'localizedSize': 'M 15 / W 16.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093960',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#     {'id': '26149405',
#      'nikeSize': '16',
#      'skuId': '23734e48-8293-57a6-ab6d-cb2d9e3903a1',
#      'localizedSize': 'M 16 / W 17.5',
#      'localizedSizePrefix': '',
#      'gtin': '00194957093977',
#      'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'}],
#    'title': 'Nike Free Metcon 4',
#    'nodes': [{'analytics': {'hashKey': '4ad488e18aa3a21f66dd1c417fa419d6b142cac5700e4f836b693d4af800fcf6'},
#      'nodes': [{'analytics': {'hashKey': '226ed88541137a11e4dd23579e9feabc87bdd2c439586b978c9825cb3f0db14d'},
#        'subType': 'image',
#        'id': 'bcce7639-4db4-41ab-973a-a89d61a94f2d',
#        'type': 'card',
#        'version': '1674603752904',
#        'properties': {'portraitId': '342243ca-132d-4f7f-8734-44fd37d91985',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'A',
#          'aspectRatio': 1,
#          'id': 'ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'A',
#          'aspectRatio': 0.8,
#          'id': '342243ca-132d-4f7f-8734-44fd37d91985',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': 'ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'c7433786fd3d6238a8f050a160eb06fe6a6018a079b758b5fc8caafb905a228e'},
#        'subType': 'image',
#        'id': 'c227c653-7ec8-4840-b388-c22610fb0b9f',
#        'type': 'card',
#        'version': '1674603752904',
#        'properties': {'portraitId': '201251ca-adaf-4b0e-b9f6-4bcbc664eef2',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/4657cf5b-2e05-4638-9207-de9d9e373004/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/201251ca-adaf-4b0e-b9f6-4bcbc664eef2/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'B',
#          'aspectRatio': 1,
#          'id': '4657cf5b-2e05-4638-9207-de9d9e373004',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/4657cf5b-2e05-4638-9207-de9d9e373004/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'B',
#          'aspectRatio': 0.8,
#          'id': '201251ca-adaf-4b0e-b9f6-4bcbc664eef2',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/201251ca-adaf-4b0e-b9f6-4bcbc664eef2/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '4657cf5b-2e05-4638-9207-de9d9e373004',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'a916251cadbfd9aa018910a1e0227ba731bcffe3619bf203c4727ec454ca4313'},
#        'subType': 'image',
#        'id': '958fb445-8854-42b2-96da-052db13c0d6d',
#        'type': 'card',
#        'version': '1674603752904',
#        'properties': {'portraitId': '3d55d5a4-430f-4888-92d3-864ca9bda713',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/1d0fd6a9-b64c-4d89-8fa7-d36243189745/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/3d55d5a4-430f-4888-92d3-864ca9bda713/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'C',
#          'aspectRatio': 1,
#          'id': '1d0fd6a9-b64c-4d89-8fa7-d36243189745',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/1d0fd6a9-b64c-4d89-8fa7-d36243189745/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'C',
#          'aspectRatio': 0.8,
#          'id': '3d55d5a4-430f-4888-92d3-864ca9bda713',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/3d55d5a4-430f-4888-92d3-864ca9bda713/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '1d0fd6a9-b64c-4d89-8fa7-d36243189745',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'b9a03c6989397d58245943587616963c684620a4b12f4db7511dcb8672be7d83'},
#        'subType': 'image',
#        'id': '8969400e-8379-4c28-831d-f62bb7204010',
#        'type': 'card',
#        'version': '1674603752904',
#        'properties': {'portraitId': 'd8a76988-8b9d-4ca2-8857-6befd7eb2968',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/d8786e84-4554-4af3-a0e6-1c6210d01c6e/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/d8a76988-8b9d-4ca2-8857-6befd7eb2968/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'D',
#          'aspectRatio': 1,
#          'id': 'd8786e84-4554-4af3-a0e6-1c6210d01c6e',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/d8786e84-4554-4af3-a0e6-1c6210d01c6e/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'D',
#          'aspectRatio': 0.8,
#          'id': 'd8a76988-8b9d-4ca2-8857-6befd7eb2968',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/d8a76988-8b9d-4ca2-8857-6befd7eb2968/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': 'd8786e84-4554-4af3-a0e6-1c6210d01c6e',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': '9d1a32f14d4361ce803c2892834a7cb033bbde8840027f60b6dab94d73d400b3'},
#        'subType': 'image',
#        'id': '59acffa0-cfa1-42ab-9af8-363774121c81',
#        'type': 'card',
#        'version': '1674603752904',
#        'properties': {'portraitId': '977cd46d-3a3a-4008-98a4-22d831f33752',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/3505ba36-a463-4476-8297-8d9c53328606/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/977cd46d-3a3a-4008-98a4-22d831f33752/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'E',
#          'aspectRatio': 1,
#          'id': '3505ba36-a463-4476-8297-8d9c53328606',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/3505ba36-a463-4476-8297-8d9c53328606/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'E',
#          'aspectRatio': 0.8,
#          'id': '977cd46d-3a3a-4008-98a4-22d831f33752',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/977cd46d-3a3a-4008-98a4-22d831f33752/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '3505ba36-a463-4476-8297-8d9c53328606',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': 'c30e2f08b14ff2d104d3560cceff82b82dbb479607e48a1185e947fc0725c7c5'},
#        'subType': 'image',
#        'id': '5c66a7ef-02e7-4e97-858a-0866f8c1cd56',
#        'type': 'card',
#        'version': '1674603752904',
#        'properties': {'portraitId': '6940670b-5664-4be4-899b-6467ce551f8e',
# ...
#        'version': '1674603750087',
#        'properties': {'portraitId': 'f7ac7b1d-45eb-480a-a651-3139832847fd',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/aa371f70-a02e-47b3-ae49-954788962550/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/f7ac7b1d-45eb-480a-a651-3139832847fd/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'H',
#          'aspectRatio': 1,
#          'id': 'aa371f70-a02e-47b3-ae49-954788962550',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/aa371f70-a02e-47b3-ae49-954788962550/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'H',
#          'aspectRatio': 0.8,
#          'id': 'f7ac7b1d-45eb-480a-a651-3139832847fd',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/f7ac7b1d-45eb-480a-a651-3139832847fd/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': 'aa371f70-a02e-47b3-ae49-954788962550',
#         'subtitle': '',
#         'colorTheme': 'dark'}},
#       {'analytics': {'hashKey': '4f82bc2a954cce848672e7b9bd367d5ad53d5d2b1859f3f976f29f306a73860b'},
#        'subType': 'image',
#        'id': 'deaf4054-a621-42cc-b068-7fa5b2ad796d',
#        'type': 'card',
#        'version': '1674603750087',
#        'properties': {'portraitId': '093e9384-6100-4892-8dd4-92a01b967176',
#         'squarishURL': 'https://static.nike.com/a/images/t_default/8141dc36-f4a8-4285-9c77-a0f9a1ff3d16/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeId': '',
#         'altText': 'Nike Free Metcon 4 Training Shoes',
#         'portraitURL': 'https://static.nike.com/a/images/t_default/093e9384-6100-4892-8dd4-92a01b967176/free-metcon-4-training-shoes-KX41Bv.png',
#         'landscapeURL': '',
#         'title': '',
#         'squarish': {'view': 'K',
#          'aspectRatio': 1,
#          'id': '8141dc36-f4a8-4285-9c77-a0f9a1ff3d16',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/8141dc36-f4a8-4285-9c77-a0f9a1ff3d16/free-metcon-4-training-shoes-KX41Bv.png'},
#         'portrait': {'view': 'K',
#          'aspectRatio': 0.8,
#          'id': '093e9384-6100-4892-8dd4-92a01b967176',
#          'type': 'product',
#          'url': 'https://static.nike.com/a/images/t_default/093e9384-6100-4892-8dd4-92a01b967176/free-metcon-4-training-shoes-KX41Bv.png'},
#         'seoName': '',
#         'squarishId': '8141dc36-f4a8-4285-9c77-a0f9a1ff3d16',
#         'subtitle': '',
#         'colorTheme': 'dark'}}],
#      'subType': 'carousel',
#      'id': 'f7bbacbb-5f90-46f0-8570-17fcbb416511',
#      'type': 'card',
#      'version': '1674603750087',
#      'properties': {'containerType': 'grid',
#       'loop': False,
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'autoPlay': False,
#       'title': '',
#       'body': '',
#       'speed': 6000}},
#     {'analytics': {'hashKey': '2bd10d9814bac3841bd9258a53ab2cf9a8aa9f68ccd61ec4a62a536e30f82c17'},
#      'subType': 'text',
#      'id': 'f5ba3b29-9958-4dfe-94ab-f48a96bc5640',
#      'type': 'card',
#      'version': '1633365074108',
#      'properties': {'copyId': '89da6c6ccc8f2c31b9553d21188539e12d355edb',
#       'product': [],
#       'richTextLinks': [],
#       'custom': {},
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#        'modifiedDate': '2021-10-04T16:31:14.015Z',
#        'exposeTemplate': False,
#        'properties': {'actions': {}},
#        'resourceType': 'content/style'},
#       'body': '<p>Explore the Nike Free Metcon 4 Training Shoe</p>',
#       'title': '',
#       'actions': []}},
#     {'analytics': {'hashKey': '9133d9cc5276fe32d38d3f2e1962cd5bb1eafdc0d807a980c479cab3434f0738'},
#      'subType': 'image',
#      'id': '45bcf90a-119d-4f67-ad47-4d0c36302d5b',
#      'type': 'card',
#      'version': '1633365132078',
#      'properties': {'portraitId': '',
#       'squarishURL': '',
#       'product': [],
#       'landscapeId': '',
#       'altText': '',
#       'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42771388-4427-4aab-9f0b-26a574d1e8df/image.jpg',
#       'custom': {},
#       'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/30917709-0fce-42c1-949f-362b0dd742d3/image.jpg',
#       'portrait': {'id': '42771388-4427-4aab-9f0b-26a574d1e8df',
#        'type': 'product',
#        'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42771388-4427-4aab-9f0b-26a574d1e8df/image.jpg'},
#       'title': '',
#       'squarishId': '',
#       'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#       'richTextLinks': [],
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#        'modifiedDate': '2021-10-04T16:32:12.058Z',
#        'exposeTemplate': False,
#        'properties': {'actions': {}},
#        'resourceType': 'content/style'},
#       'actions': [],
#       'landscape': {'id': '30917709-0fce-42c1-949f-362b0dd742d3',
#        'type': 'product',
#        'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/30917709-0fce-42c1-949f-362b0dd742d3/image.jpg'}}},
#     {'analytics': {'hashKey': '8872f83c2c0a74c5c0ac96b3a2ad1e82d40253b8659f791daae83dea49e5d3e7'},
#      'subType': 'text',
#      'id': 'bddd32d4-d7ca-42b6-8e92-465bc258bad1',
#      'type': 'card',
#      'version': '1633365080308',
#      'properties': {'copyId': '7da026d0a5a5a015078e337f5ac64e503c6252ac',
#       'product': [],
#       'richTextLinks': [],
#       'custom': {},
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#        'modifiedDate': '2021-10-04T16:31:20.279Z',
#        'exposeTemplate': False,
#        'properties': {'actions': {}},
#        'resourceType': 'content/style'},
#       'body': '<p>The 4 is bringing back the super tough yet breathable mesh from the original version. The upper gets embellished with a Huarache-inspired strap and rubber-striped sidewall that envelops your heel to brace you for movement in any direction.</p>',
#       'title': 'Blast From the Past',
#       'actions': []}},
#     {'analytics': {'hashKey': '91bc7d81648fb0bc03bb2ddb0c6c45ed6a2b70f24144e35ecbfc5820408972c2'},
#      'subType': 'image',
#      'id': '91dd0dc1-df6b-4501-8297-0bcf4a64fb6c',
#      'type': 'card',
#      'version': '1633365137061',
#      'properties': {'portraitId': '',
#       'squarishURL': '',
#       'product': [],
#       'landscapeId': '',
#       'altText': '',
#       'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg',
#       'custom': {},
#       'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg',
#       'portrait': {'id': '84c9e581-df1b-44ba-b540-d21178c21295',
#        'type': 'product',
#        'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg'},
#       'title': '',
#       'squarishId': '',
#       'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#       'richTextLinks': [],
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#        'modifiedDate': '2021-10-04T16:32:17.053Z',
#        'exposeTemplate': False,
#        'properties': {'actions': {}},
#        'resourceType': 'content/style'},
#       'actions': [],
#       'landscape': {'id': '9d61f74a-6c21-45d4-bb60-e94c06f3c945',
#        'type': 'product',
#        'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg'}}},
#     {'analytics': {'hashKey': 'fb66428b4726a52cb2f81f5739fe5be5d4b0ad04af664ecc30339ece62b60f98'},
#      'subType': 'text',
#      'id': '3a049537-aed5-44aa-b0f5-fb3e48e56399',
#      'type': 'card',
#      'version': '1633365089421',
#      'properties': {'copyId': 'a253dd95d0bae61b5d9ca9e207e32247ceb15df6',
#       'product': [],
#       'richTextLinks': [],
#       'custom': {},
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#        'modifiedDate': '2021-10-04T16:31:29.405Z',
#        'exposeTemplate': False,
#        'properties': {'actions': {}},
#        'resourceType': 'content/style'},
#       'body': '<p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p>',
#       'title': 'Flexibility for Speed',
#       'actions': []}},
#     {'analytics': {'hashKey': 'add5b12590aa45c846ef8ab48ffb89ba2ee497d861dfff6291162efb2625bbc7'},
#      'subType': 'image',
#      'id': '072fa761-6350-45a0-9a85-88fad4ea24e7',
#      'type': 'card',
#      'version': '1633365102718',
#      'properties': {'portraitId': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#       'squarishURL': '',
#       'landscapeId': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#       'altText': '',
#       'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg',
#       'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg',
#       'portrait': {'id': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#        'type': 'product',
#        'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg'},
#       'title': '',
#       'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#       'richTextLinks': [],
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#        'modifiedDate': '2021-10-04T16:31:42.718Z',
#        'exposeTemplate': False,
#        'resourceType': 'content/style'},
#       'actions': [],
#       'landscape': {'id': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#        'type': 'product',
#        'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg'}}},
#     {'analytics': {'hashKey': '19214ec1853bfd1aa0b5986f20c9f7bc1291c2d42405b07ae9d74bc303bb711d'},
#      'subType': 'text',
#      'id': '6de4f79e-1e52-4c01-a9d7-a21e9b8cb30b',
#      'type': 'card',
#      'version': '1633365097774',
#      'properties': {'copyId': 'd059f6db5527b41ea4abe44d472b2f9577221c23',
#       'product': [],
#       'richTextLinks': [],
#       'custom': {},
#       'subtitle': '',
#       'colorTheme': 'dark',
#       'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#        'modifiedDate': '2021-10-04T16:31:37.709Z',
#        'exposeTemplate': False,
#        'properties': {'actions': {}},
#        'resourceType': 'content/style'},
#       'body': '<p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p>',
#       'title': 'Stability for Strength',
#       'actions': []}}],
#    'layoutCards': [],
#    'firstImageUrl': 'https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png',
#    'firstImageAltText': 'Nike Free Metcon 4 Training Shoes',
#    'sustainabilityMessage': [],
#    'descriptionPreviewBullets': '',
#    'moreInfoMessages': [],
#    'sizeFitMessages': [],
#    'hubMessages': [],
#    'language': 'en',
#    'marketplace': 'US',
#    'availableSkus': [{'id': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da',
#      'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/ef237b73-2633-56fe-8ebd-fbc2258fa8da'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da'},
#     {'id': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f',
#      'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'},
#     {'id': '9fd7e097-24db-5c33-b660-d300c3f6579c',
#      'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/9fd7e097-24db-5c33-b660-d300c3f6579c'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': '9fd7e097-24db-5c33-b660-d300c3f6579c'},
#     {'id': 'da0611fb-2af5-53fa-89c3-8baea350977b',
#      'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/da0611fb-2af5-53fa-89c3-8baea350977b'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': 'da0611fb-2af5-53fa-89c3-8baea350977b'},
#     {'id': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca',
#      'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#      'resourceType': 'availableSkus',
#      'links': {'self': {'ref': '/deliver/available_skus/v1/4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}},
#      'available': True,
#      'level': 'LOW',
#      'skuId': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}],
#    'publishType': 'FLOW',
#    'isLaunchView': False,
#    'launchView': None,
#    'isForNumberOfImagesABTesting': False,
#    'isMinimumAdvertisedPrice': False,
#    'collectionTermIds': ['c05bedd9-29d3-4e45-8c62-c463f9c5958f',
#     '1a70e9af-aea9-4a39-9773-fa6ced97c58b',
#     '65838112-1f4d-48a7-9b2f-1e8736c4cdcc',
#     'a49f8e69-ff9c-4356-89d8-d4a098fc02c2',
#     'e4e46ee6-496f-491a-8771-1a677eefee3a',
#     '94d2c954-14cd-4784-96ec-b02c950d2872',
#     '62f3c208-e1a3-45c0-9e70-a90be4e276f1',
#     'b9cefedb-1dd5-42dc-af13-939a240d4bb8',
#     '4be7e5d7-7e5b-460d-b3d7-41396b3fa985'],
#    'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#     '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#     '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#     'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#     '292efae5-2d9a-44a3-a529-cda684a47c44',
#     'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#     '7702dda3-62ca-3410-b4f3-97025be1089d',
#     '68a7b17f-291f-41f8-bf04-5e2fbe878d9b',
#     '05392778-fff6-4fa0-a375-2506d27f009e',
#     '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#     '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#     'b942d0ac-4887-4a8f-b914-d82a6181014f',
#     '67063381-90eb-4763-8f87-acc30b392f38',
#     '699b34a6-1950-3458-8322-910b695fccb7',
#     '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#     '10f9af5a-58d2-480a-a72d-5a65bd374850',
#     '0a937561-8633-3ea1-8ae3-8509f50f4127',
#     '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#     '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#     '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#     '539c6c43-d060-30b0-be5b-47c47f7c7658',
#     'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#     '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#     '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#     '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#     '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#     '2057952b-1a72-368e-b4b1-f67091ff1799',
#     '6e7e4809-fccb-4e82-8a7b-047125398076',
#     '9b0e77d0-aec5-4f4b-b8de-acb7a82e396d',
#     '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#     '7abdd901-856d-3601-94bf-14313cee8354',
#     '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#     'b5cd158b-b105-490c-b777-652943e742b0',
#     'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#     '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#     '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#     '16633190-45e5-4830-a068-232ac7aea82c',
#     '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#     '7817e756-7721-4cfb-b404-04df79c685e4',
#     'c29a0094-d302-4b7a-b5f0-73e46f772348'],
#    'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#    'catalogId': '1',
#    'selectedSkuId': {},
#    'sizeAndFitDescription': '',
#    'exclusiveAccess': False,
#    'notifyMeIndicator': False,
#    'promoExclusionAccess': False,
#    'useFeedsPromoExclusionMessage': False,
#    'jerseyIdPathName': '',
#    'nbyHubMessages': [],
#    'state': 'IN_STOCK'}}}

# %%
json_object['props']['pageProps']['initialState']['Threads'].keys()
# Out:
# dict_keys(['threads', 'error', 'async', 'products'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads'].keys():
#     print(i,"\n\n\n",json_object['props']['pageProps']['initialState']['Threads'][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']
# Out:
# {'DZ6326-001': {'id': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#   'threadId': '9cffc907-8db0-4932-bbc7-fae0f2bedc20',
#   'productId': '14231935',
#   'mainColor': False,
#   'productRollup': {'type': 'Standard', 'key': 'KX41Bv'},
#   'width': {'value': 'REGULAR', 'localizedValue': 'Regular'},
#   'athletes': [],
#   'styleColor': 'DZ6326-001',
#   'styleCode': 'DZ6326',
#   'category': 'Training,Cross Training',
#   'pid': '14231935',
#   'preOrder': False,
#   'preorderAvailabilityDate': '',
#   'commerceStartDate': '2022-11-07T15:00:00.000Z',
#   'isNYBCountDown': False,
#   'countdown': -1,
#   'hardLaunch': True,
#   'sportTags': ['Training', 'Cross Training'],
#   'genders': ['MEN'],
#   'brand': 'Nike',
#   'productType': 'FOOTWEAR',
#   'nikeIdStyleCode': '',
#   'productGroupId': '13888937',
#   'styleType': 'INLINE',
#   'status': 'ACTIVE',
#   'displayOrder': '',
#   'subTitle': 'Training Shoes',
#   'fullTitle': 'Nike Free Metcon 4 AMP Training Shoes',
#   'additionalInfo': None,
#   'sizeChart': None,
#   'langLocale': 'en_US',
#   'marketing': '',
#   'origin': [],
#   'colorDescription': 'Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black',
#   'description': '<div class="pi-tier3"><div class="pi-pdpmainbody"><p><b class="headline-5">&#xA0;</b></p><br><p>Whether you&#x2019;re rising with the roosters or squeezing in a late-night circuit session, these shoes help you stay fresh. They have an updated &quot;chain-link&quot; mesh that cools and flexes as you speed through agility drills, while support at the midfoot and heel helps brace you for your heaviest sets in the weight room.</p><br><p><b class="headline-5">Finding Light in the Darkness</b></p><p>During the winter solstice in the northern hemisphere, the sun has the appearance of being at a 30-degree angle of east and west when it rises and sets. Likewise, when researching the Free Metcon 4, we found the optimal angle for squatting ranges from 10 degrees to 30 degrees. The gradient, also angled at 30 degrees, goes from light to dark on the midsole and back again from dark to light to mimic the sun rising and setting during the solstice.</p><br><p><b class="headline-5">Blast from the Past</b></p><p>The 4 brings back the tough, yet breathable mesh from the original version. The upper gets embellished with a Huarache-inspired strap and rubber-striped sidewall that envelops your heel to help brace you for movement in any direction.</p><br><p><b class="headline-5">Flexibility for Speed</b></p><p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the ankle lets your foot move naturally as you burst, cut and brake.</p><br><p><b class="headline-5">Stability for Strength</b></p><p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable, yet secure feel during sudden stops and quick cuts.</p><br><p><b class="headline-5">More Benefits</b></p><ul><li>Rubber tread in high-wear areas gives you durable traction.</li><li>Rubberized logo at the tongue nods to the Nike Air Huarache of the early &apos;90s.</li></ul><br><p><b class="headline-5">Product Details</b></p><ul><li>Reflective details</li><li>This product is not intended for use as Personal Protective Equipment (PPE)<li>Shown: Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black</li><li>Style: DZ6326-001</li></li></ul></div></div>',
#   'descriptionPreview': 'Whether youâ\x80\x99re rising with the roosters or squeezing in a late-night circuit session, these shoes help you stay fresh. They have an updated "chain-link" mesh that cools and flexes as you speed through agility drills, while support at the midfoot and heel helps brace you for your heaviest sets in the weight room.',
#   'nbyContentCopy': {},
#   'prebuildId': '',
#   'mainPrebuild': '',
#   'isNikeID': False,
#   'isNBYDesign': False,
#   'updatedNBYDesignKey': '',
#   'piid': '',
#   'pathName': '',
#   'vas': [{'id': '0cba9a6c-ac96-5e0a-8bd9-0d31d5095a7c',
#     'vasType': 'GIFT_MESSAGE'},
#    {'id': '3d62c037-56f3-59d5-81d3-88ce17f7fb99', 'vasType': 'GIFT_WRAP'}],
#   'nbyCustomMessage': '',
#   'seoProductDescription': 'Find the Nike Free Metcon 4 AMP at Nike.com. ',
#   'seoProductAvailability': True,
#   'seoProductReleaseDate': '2022-11-07T15:00:00.000Z',
#   'discounted': False,
#   'fullPrice': 120,
#   'currentPrice': 120,
#   'employeePrice': 72,
#   'currency': 'USD',
#   'skus': [{'id': '28611818',
#     'nikeSize': '6',
#     'skuId': '5882ae76-f77b-5c7b-9566-9bb251ec918a',
#     'localizedSize': 'M 6 / W 7.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903069',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611821',
#     'nikeSize': '6.5',
#     'skuId': '3987819d-242d-5195-84af-4d3164e6bdab',
#     'localizedSize': 'M 6.5 / W 8',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903076',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611817',
#     'nikeSize': '7',
#     'skuId': '3de024b3-24a1-5214-a36d-f6bf82b4f5ab',
#     'localizedSize': 'M 7 / W 8.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903083',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611926',
#     'nikeSize': '7.5',
#     'skuId': 'cab139f1-7cc2-5ae8-a33a-fd93e1e92df9',
#     'localizedSize': 'M 7.5 / W 9',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903090',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611816',
#     'nikeSize': '8',
#     'skuId': 'e90f4262-9f0a-5311-8c19-21c5c7449b5f',
#     'localizedSize': 'M 8 / W 9.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903106',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611820',
#     'nikeSize': '8.5',
#     'skuId': 'ed5a02bf-9c8b-5f43-a9fb-c35da62402d0',
#     'localizedSize': 'M 8.5 / W 10',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903113',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611931',
#     'nikeSize': '9',
#     'skuId': 'cb969ea8-41df-5c36-a45a-5d2f5efe7dc6',
#     'localizedSize': 'M 9 / W 10.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903120',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611928',
#     'nikeSize': '9.5',
#     'skuId': 'abbdcf42-bd26-5534-b9f7-997e24291d6d',
#     'localizedSize': 'M 9.5 / W 11',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903137',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611815',
#     'nikeSize': '10',
#     'skuId': 'ccbf718e-fe42-55a4-91dc-b49dfa037b09',
#     'localizedSize': 'M 10 / W 11.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903144',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611929',
#     'nikeSize': '10.5',
#     'skuId': '92cb22af-23cc-517c-a753-2b5d8cbb8e62',
#     'localizedSize': 'M 10.5 / W 12',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903151',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611824',
#     'nikeSize': '11',
#     'skuId': 'f5f65912-814f-5c7b-91dc-c32637597c36',
#     'localizedSize': 'M 11 / W 12.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903168',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611822',
#     'nikeSize': '11.5',
#     'skuId': 'e858df03-7621-5a3d-b057-8e75cd505053',
#     'localizedSize': 'M 11.5 / W 13',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903175',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611823',
#     'nikeSize': '12',
#     'skuId': '60c37dc4-4d5c-5f81-89c2-f84b346b304d',
#     'localizedSize': 'M 12 / W 13.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903182',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611927',
#     'nikeSize': '12.5',
#     'skuId': 'ab44c806-bc75-5ad7-9514-172c54c7ddab',
#     'localizedSize': 'M 12.5 / W 14',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903199',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611930',
#     'nikeSize': '13',
#     'skuId': '513d2161-039d-598e-8778-3e5a4bf3262c',
#     'localizedSize': 'M 13 / W 14.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903205',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611825',
#     'nikeSize': '14',
#     'skuId': '45262cba-73c3-56b6-bc5b-f62346cf2afc',
#     'localizedSize': 'M 14 / W 15.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903212',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'},
#    {'id': '28611819',
#     'nikeSize': '15',
#     'skuId': '9b2de139-5e2c-58c5-a3a1-ddbb465464df',
#     'localizedSize': 'M 15 / W 16.5',
#     'localizedSizePrefix': '',
#     'gtin': '00196151903229',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533'}],
#   'title': 'Nike Free Metcon 4 AMP',
#   'nodes': [{'analytics': {'hashKey': '8507619bf0bb71e8363df7a1bc1bf90fe85d72d1c0250a117047376808099daa'},
#     'nodes': [{'analytics': {'hashKey': 'b1571054c01b752e2ad44ea07a64648f9caaf21a8e6a0211705fc5b9a542a676'},
#       'subType': 'image',
#       'id': 'f7d3ff8a-ccb4-4858-a7b6-bea05605c671',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': '82ddc691-dfe5-4fe0-913c-38e17ecfdb60',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'A',
#         'aspectRatio': 1,
#         'id': '79fcb768-1a4d-4bce-926d-3c6539562a28',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'A',
#         'aspectRatio': 0.8,
#         'id': '82ddc691-dfe5-4fe0-913c-38e17ecfdb60',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '79fcb768-1a4d-4bce-926d-3c6539562a28',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '0e929a251e86702ee939291a3690688fba91fd8e5d7107d5b32c42f5337efb87'},
#       'subType': 'image',
#       'id': 'e474b409-ecd7-4aa0-ae5e-17cc29561b24',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': 'cd1114b3-263c-49ae-a967-f94f52190198',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/7a1c62b2-a916-432f-8a39-4037684da27f/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/cd1114b3-263c-49ae-a967-f94f52190198/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'B',
#         'aspectRatio': 1,
#         'id': '7a1c62b2-a916-432f-8a39-4037684da27f',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/7a1c62b2-a916-432f-8a39-4037684da27f/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'B',
#         'aspectRatio': 0.8,
#         'id': 'cd1114b3-263c-49ae-a967-f94f52190198',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/cd1114b3-263c-49ae-a967-f94f52190198/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '7a1c62b2-a916-432f-8a39-4037684da27f',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '4370af7e3c57dc3edbe818703bf2096e63148078cf9f54ba72619f96b1404d40'},
#       'subType': 'image',
#       'id': '3c509500-b816-4885-b983-8e0bafa8a547',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': '1ba822e4-a2ce-414c-ac89-250aa7b54b97',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/47a379ef-24a6-4b68-8855-6ea12ce19f51/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/1ba822e4-a2ce-414c-ac89-250aa7b54b97/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'C',
#         'aspectRatio': 1,
#         'id': '47a379ef-24a6-4b68-8855-6ea12ce19f51',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/47a379ef-24a6-4b68-8855-6ea12ce19f51/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'C',
#         'aspectRatio': 0.8,
#         'id': '1ba822e4-a2ce-414c-ac89-250aa7b54b97',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/1ba822e4-a2ce-414c-ac89-250aa7b54b97/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '47a379ef-24a6-4b68-8855-6ea12ce19f51',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'ea18402dd82aa539e5987444ce1fd76071eda5a92e775c378e3069d4f98e9e77'},
#       'subType': 'image',
#       'id': '8402cae9-b073-49c0-8a29-659dd7bd7dbe',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': '55b0d24b-52b4-4fed-9f72-56ccc268d8ad',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/2fbce74d-776b-4186-aa42-2606202cb6c9/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/55b0d24b-52b4-4fed-9f72-56ccc268d8ad/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'D',
#         'aspectRatio': 1,
#         'id': '2fbce74d-776b-4186-aa42-2606202cb6c9',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/2fbce74d-776b-4186-aa42-2606202cb6c9/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'D',
#         'aspectRatio': 0.8,
#         'id': '55b0d24b-52b4-4fed-9f72-56ccc268d8ad',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/55b0d24b-52b4-4fed-9f72-56ccc268d8ad/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '2fbce74d-776b-4186-aa42-2606202cb6c9',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '470f4e085c88b613f0c4000b063cbcab5a51b80dbf0a1f2d0bb3a6bb5b21a68e'},
#       'subType': 'image',
#       'id': 'f806e5bd-bcf0-44d1-a77a-d414a0b0313c',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': 'f5691c40-fd8b-4262-8b7f-912a52ddeb86',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/b03a6759-99c8-4997-8088-381528e3c0da/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/f5691c40-fd8b-4262-8b7f-912a52ddeb86/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'E',
#         'aspectRatio': 1,
#         'id': 'b03a6759-99c8-4997-8088-381528e3c0da',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/b03a6759-99c8-4997-8088-381528e3c0da/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'E',
#         'aspectRatio': 0.8,
#         'id': 'f5691c40-fd8b-4262-8b7f-912a52ddeb86',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/f5691c40-fd8b-4262-8b7f-912a52ddeb86/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': 'b03a6759-99c8-4997-8088-381528e3c0da',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'bfc9c556784de4b752446e9f1f4b46d52359e2401710d48649dee47e3fc17874'},
#       'subType': 'image',
#       'id': 'f8eb3911-7cc1-4920-95a0-8e6e4430897b',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': '72866978-a3b9-413d-9d5b-63aaf813e8a1',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/0733a458-23b9-4c71-9e95-e9b2ddd5db93/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/72866978-a3b9-413d-9d5b-63aaf813e8a1/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'F',
#         'aspectRatio': 1,
#         'id': '0733a458-23b9-4c71-9e95-e9b2ddd5db93',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/0733a458-23b9-4c71-9e95-e9b2ddd5db93/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'F',
#         'aspectRatio': 0.8,
#         'id': '72866978-a3b9-413d-9d5b-63aaf813e8a1',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/72866978-a3b9-413d-9d5b-63aaf813e8a1/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '0733a458-23b9-4c71-9e95-e9b2ddd5db93',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '120724112c655b1db31616e63f2a5691b76ac825c2f0a8755223acd5c37102ad'},
#       'subType': 'image',
#       'id': '64ba420a-bea8-490b-b80c-66a52b6edb97',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': '85d13fc6-7e6d-4374-8db5-7bc3da70b292',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/0a473bce-9366-4f2c-92cc-3be954b7fc41/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/85d13fc6-7e6d-4374-8db5-7bc3da70b292/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'H',
#         'aspectRatio': 1,
#         'id': '0a473bce-9366-4f2c-92cc-3be954b7fc41',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/0a473bce-9366-4f2c-92cc-3be954b7fc41/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'H',
#         'aspectRatio': 0.8,
#         'id': '85d13fc6-7e6d-4374-8db5-7bc3da70b292',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/85d13fc6-7e6d-4374-8db5-7bc3da70b292/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '0a473bce-9366-4f2c-92cc-3be954b7fc41',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'c5ac916793e6e6260ad69b2d84bc0ccb9b396978d7b603c124608d398b654350'},
#       'subType': 'image',
#       'id': 'a4ac9821-c5a7-43d1-8398-9b8d61b7fbbe',
#       'type': 'card',
#       'version': '1674603758297',
#       'properties': {'portraitId': '7890eeb4-47c1-4000-a994-871702a3d9e5',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/2218e1fe-bb35-4076-ade9-caa23bb72a30/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 AMP Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/7890eeb4-47c1-4000-a994-871702a3d9e5/free-metcon-4-amp-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'K',
#         'aspectRatio': 1,
#         'id': '2218e1fe-bb35-4076-ade9-caa23bb72a30',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/2218e1fe-bb35-4076-ade9-caa23bb72a30/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'K',
#         'aspectRatio': 0.8,
#         'id': '7890eeb4-47c1-4000-a994-871702a3d9e5',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/7890eeb4-47c1-4000-a994-871702a3d9e5/free-metcon-4-amp-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '2218e1fe-bb35-4076-ade9-caa23bb72a30',
#        'subtitle': '',
#        'colorTheme': 'dark'}}],
#     'subType': 'carousel',
#     'id': '7d083f29-02d4-48cb-a485-d01ad4318ba3',
#     'type': 'card',
#     'version': '1674603758297',
#     'properties': {'containerType': 'grid',
#      'loop': False,
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'autoPlay': False,
#      'title': '',
#      'body': '',
#      'speed': 6000}}],
#   'layoutCards': [],
#   'firstImageUrl': 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png',
#   'firstImageAltText': 'Nike Free Metcon 4 AMP Training Shoes',
#   'sustainabilityMessage': [],
#   'descriptionPreviewBullets': '',
#   'moreInfoMessages': [],
#   'sizeFitMessages': [],
#   'hubMessages': [],
#   'language': 'en',
#   'marketplace': 'US',
#   'availableSkus': [{'id': '3de024b3-24a1-5214-a36d-f6bf82b4f5ab',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/3de024b3-24a1-5214-a36d-f6bf82b4f5ab'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': '3de024b3-24a1-5214-a36d-f6bf82b4f5ab'},
#    {'id': 'cab139f1-7cc2-5ae8-a33a-fd93e1e92df9',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/cab139f1-7cc2-5ae8-a33a-fd93e1e92df9'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'cab139f1-7cc2-5ae8-a33a-fd93e1e92df9'},
#    {'id': 'e90f4262-9f0a-5311-8c19-21c5c7449b5f',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/e90f4262-9f0a-5311-8c19-21c5c7449b5f'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'e90f4262-9f0a-5311-8c19-21c5c7449b5f'},
#    {'id': 'ed5a02bf-9c8b-5f43-a9fb-c35da62402d0',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/ed5a02bf-9c8b-5f43-a9fb-c35da62402d0'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'ed5a02bf-9c8b-5f43-a9fb-c35da62402d0'},
#    {'id': 'cb969ea8-41df-5c36-a45a-5d2f5efe7dc6',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/cb969ea8-41df-5c36-a45a-5d2f5efe7dc6'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'cb969ea8-41df-5c36-a45a-5d2f5efe7dc6'},
#    {'id': 'abbdcf42-bd26-5534-b9f7-997e24291d6d',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/abbdcf42-bd26-5534-b9f7-997e24291d6d'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'abbdcf42-bd26-5534-b9f7-997e24291d6d'},
#    {'id': 'ccbf718e-fe42-55a4-91dc-b49dfa037b09',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/ccbf718e-fe42-55a4-91dc-b49dfa037b09'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'ccbf718e-fe42-55a4-91dc-b49dfa037b09'},
#    {'id': '92cb22af-23cc-517c-a753-2b5d8cbb8e62',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/92cb22af-23cc-517c-a753-2b5d8cbb8e62'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': '92cb22af-23cc-517c-a753-2b5d8cbb8e62'},
#    {'id': 'f5f65912-814f-5c7b-91dc-c32637597c36',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/f5f65912-814f-5c7b-91dc-c32637597c36'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'f5f65912-814f-5c7b-91dc-c32637597c36'},
#    {'id': 'e858df03-7621-5a3d-b057-8e75cd505053',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/e858df03-7621-5a3d-b057-8e75cd505053'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': 'e858df03-7621-5a3d-b057-8e75cd505053'},
#    {'id': '60c37dc4-4d5c-5f81-89c2-f84b346b304d',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/60c37dc4-4d5c-5f81-89c2-f84b346b304d'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': '60c37dc4-4d5c-5f81-89c2-f84b346b304d'},
#    {'id': 'ab44c806-bc75-5ad7-9514-172c54c7ddab',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/ab44c806-bc75-5ad7-9514-172c54c7ddab'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': 'ab44c806-bc75-5ad7-9514-172c54c7ddab'},
#    {'id': '513d2161-039d-598e-8778-3e5a4bf3262c',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/513d2161-039d-598e-8778-3e5a4bf3262c'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': '513d2161-039d-598e-8778-3e5a4bf3262c'},
#    {'id': '45262cba-73c3-56b6-bc5b-f62346cf2afc',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/45262cba-73c3-56b6-bc5b-f62346cf2afc'}},
#     'available': True,
#     'level': 'HIGH',
#     'skuId': '45262cba-73c3-56b6-bc5b-f62346cf2afc'},
#    {'id': '9b2de139-5e2c-58c5-a3a1-ddbb465464df',
#     'productId': '53dea5bc-5d36-5c8c-bb54-55a8fecea533',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/9b2de139-5e2c-58c5-a3a1-ddbb465464df'}},
#     'available': True,
#     'level': 'MEDIUM',
#     'skuId': '9b2de139-5e2c-58c5-a3a1-ddbb465464df'}],
#   'publishType': 'FLOW',
#   'isLaunchView': False,
#   'launchView': None,
#   'isForNumberOfImagesABTesting': False,
#   'isMinimumAdvertisedPrice': False,
#   'collectionTermIds': ['698d17bc-daf4-42d9-aee7-15841c59798c'],
#   'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#    '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#    '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#    '618e0e56-f642-3b7e-b1a9-1ec3d14a4bb0',
#    '5c357820-4cff-37a6-b815-984753484f06',
#    '7af3d3c5-a8cf-39aa-a8da-e5ec24c016de',
#    '292efae5-2d9a-44a3-a529-cda684a47c44',
#    'd984f2d7-84d4-37c9-b860-1c89d499358f',
#    'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#    '05392778-fff6-4fa0-a375-2506d27f009e',
#    '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#    '848bddbb-341c-3c70-8b77-05fe5d862c14',
#    '67063381-90eb-4763-8f87-acc30b392f38',
#    '539c6c43-d060-30b0-be5b-47c47f7c7658',
#    'f5cdf573-63b1-3d72-bc11-e4173c20c09f',
#    '1f497f51-bf0b-35fb-ab50-571f29a4daf1',
#    '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#    '25681ef3-6dec-3029-98fc-98da0a431aac',
#    'ce920033-3ed0-3855-a3d9-e82dde5776c7',
#    '6e7e4809-fccb-4e82-8a7b-047125398076',
#    '7abdd901-856d-3601-94bf-14313cee8354',
#    '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#    'c030f969-024a-3791-83ac-6e505b324861',
#    '7a223c0d-276a-3ce4-ade6-cc5c8d636bfa',
#    'a2244eab-52ab-3039-9df3-f264504b2c3e',
#    '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#    '0af553b6-7079-331b-a9d4-934c3966f7d1',
#    'fd271500-77b7-3553-9cde-2fb03391f223',
#    '7cf5846a-5c1e-3be6-bbff-74de4f88e7f0',
#    'b0a98271-206e-3a5c-ba51-51de7b0df907',
#    '7817e756-7721-4cfb-b404-04df79c685e4',
#    'c6709307-0293-31bb-93a5-25dc36fac4fa',
#    '9bcffd0c-90ac-4ed5-bff8-3183079c0850',
#    'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#    '3622c403-7151-3db8-ac44-d0fbeee71197',
#    '7702dda3-62ca-3410-b4f3-97025be1089d',
#    '7f4a6937-eb06-31c3-b4d8-a985366ec99b',
#    '918e3967-2990-3a54-a8d9-83d0704c1b95',
#    '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#    'a19080d2-a9de-3523-a98d-0ffaddb287fd',
#    '86100864-8775-456d-9647-0bb7d36da3ac',
#    '699b34a6-1950-3458-8322-910b695fccb7',
#    '9f483c28-b828-327b-9e6b-8b12441a1b16',
#    'b6635f29-bb01-3ccd-9ade-dae66cf82e4c',
#    '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#    '10f9af5a-58d2-480a-a72d-5a65bd374850',
#    '0a937561-8633-3ea1-8ae3-8509f50f4127',
#    '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#    '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#    '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#    'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#    '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#    'abb0cf06-d7c2-41b7-97ba-c6d5ef5f43ed',
#    '4a528b33-a71b-342c-baa2-616a89985fef',
#    '7a1af8aa-7163-34a2-bf12-c2c7bc01b85c',
#    '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#    '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#    '2057952b-1a72-368e-b4b1-f67091ff1799',
#    '11873a21-5755-3ab1-9d43-43154f0866f6',
#    '66fd0467-2345-3d11-9c0e-17101482a5a9',
#    '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#    'b5cd158b-b105-490c-b777-652943e742b0',
#    'd23dd206-e459-3d50-b3fe-5ca4426137d3',
#    'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#    '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#    '16633190-45e5-4830-a068-232ac7aea82c',
#    'a69a29b5-4dbd-3df9-a010-5d71b2a24682',
#    '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#    '0ba21a73-e751-3354-b408-42e35d56e50b'],
#   'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#   'catalogId': '1',
#   'selectedSkuId': {},
#   'sizeAndFitDescription': '',
#   'exclusiveAccess': False,
#   'notifyMeIndicator': False,
#   'promoExclusionAccess': False,
#   'useFeedsPromoExclusionMessage': False,
#   'jerseyIdPathName': '',
#   'nbyHubMessages': [],
#   'state': 'IN_STOCK'},
#  'CT3886-011': {'id': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c',
#   'threadId': '203f2607-5a2b-3926-a2de-20782076460d',
#   'productId': '13182452',
#   'mainColor': False,
#   'productRollup': {'type': 'Standard', 'key': 'KX41Bv'},
#   'width': None,
#   'athletes': [],
#   'styleColor': 'CT3886-011',
#   'styleCode': 'CT3886',
#   'category': 'Training,Cross Training',
#   'pid': '13182452',
#   'preOrder': False,
#   'preorderAvailabilityDate': '',
#   'commerceStartDate': '2021-04-01T17:00:00.000Z',
#   'isNYBCountDown': False,
#   'countdown': -1,
#   'hardLaunch': False,
#   'sportTags': ['Training', 'Cross Training'],
#   'genders': ['MEN'],
#   'brand': 'Nike',
#   'productType': 'FOOTWEAR',
#   'nikeIdStyleCode': '',
#   'productGroupId': '13888937',
#   'styleType': 'INLINE',
#   'status': 'ACTIVE',
#   'displayOrder': '',
#   'subTitle': 'Training Shoes',
#   'fullTitle': 'Nike Free Metcon 4 Training Shoes',
#   'additionalInfo': None,
#   'sizeChart': None,
#   'langLocale': 'en_US',
#   'marketing': '',
#   'origin': [],
#   'colorDescription': 'Iron Grey/Grey Fog/White/Black',
#   'description': '<div class="pi-tier3"><div class="pi-pdpmainbody"><p><b class="headline-5">FREE FLEXIBILITY WITH METCON MUSCLE.</b></p><br><p>The Nike Free Metcon 4 combines flexibility with stability to help you get the most out of your training program. Updated &quot;chain-link&quot; mesh cools and flexes as you speed through agility drills, while support at the midfoot and heel braces you for your heaviest sets in the weight room.</p><br><p><b class="headline-5">Blast From the Past</b></p><p>The 4 is bringing back the super tough yet breathable mesh from the original version. The upper gets embellished with a Huarache-inspired strap and rubber-striped sidewall that envelops your heel to brace you for movement in any direction.</p><br><p><b class="headline-5">Flexibility for Speed</b></p><p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p><br><p><b class="headline-5">Stability for Strength</b></p><p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p><br><p><b class="headline-5">More Benefits</b></p><ul><li>Rubberized logo at the tongue nods to the Huarache of the early &apos;90s.</li><li>Rubber tread in high-wear areas gives you durable traction.<li>Shown: Iron Grey/Grey Fog/White/Black</li><li>Style: CT3886-011</li></li></ul></div></div>',
#   'descriptionPreview': 'The Nike Free Metcon 4 combines flexibility with stability to help you get the most out of your training program. Updated "chain-link" mesh cools and flexes as you speed through agility drills, while support at the midfoot and heel braces you for your heaviest sets in the weight room.',
#   'nbyContentCopy': {},
#   'prebuildId': '',
#   'mainPrebuild': '',
#   'isNikeID': False,
#   'isNBYDesign': False,
#   'updatedNBYDesignKey': '',
#   'piid': '',
#   'pathName': '',
#   'vas': [{'id': '0cba9a6c-ac96-5e0a-8bd9-0d31d5095a7c',
#     'vasType': 'GIFT_MESSAGE'},
#    {'id': '3d62c037-56f3-59d5-81d3-88ce17f7fb99', 'vasType': 'GIFT_WRAP'}],
#   'nbyCustomMessage': '',
#   'seoProductDescription': 'Find the Nike Free Metcon 4 at Nike.com. ',
#   'seoProductAvailability': True,
#   'seoProductReleaseDate': '2021-04-01T17:00:00.000Z',
#   'discounted': False,
#   'fullPrice': 120,
#   'currentPrice': 120,
#   'employeePrice': 72,
#   'currency': 'USD',
#   'skus': [{'id': '26149419',
#     'nikeSize': '3.5',
#     'skuId': '3326fd88-94e2-5eb6-88e0-a70ecb9ce819',
#     'localizedSize': 'M 3.5 / W 5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093755',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149406',
#     'nikeSize': '4',
#     'skuId': '63435867-0edc-5711-899e-b2209d8d54dc',
#     'localizedSize': 'M 4 / W 5.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093762',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149417',
#     'nikeSize': '4.5',
#     'skuId': '8771988c-5a40-5629-b35a-a2f9d166d895',
#     'localizedSize': 'M 4.5 / W 6',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093779',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149404',
#     'nikeSize': '5',
#     'skuId': 'e8f32f1b-29f5-5cd1-9f09-66bf34b875c9',
#     'localizedSize': 'M 5 / W 6.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093786',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149415',
#     'nikeSize': '5.5',
#     'skuId': 'c0731c22-09fe-57ce-a5ef-f0035d19f669',
#     'localizedSize': 'M 5.5 / W 7',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093793',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149402',
#     'nikeSize': '6',
#     'skuId': '43d7da07-b929-5c7d-9cdf-dba909165f1c',
#     'localizedSize': 'M 6 / W 7.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093809',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149413',
#     'nikeSize': '6.5',
#     'skuId': '9b5c82d3-b2c4-58ac-bfbc-3591f1652814',
#     'localizedSize': 'M 6.5 / W 8',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093816',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149401',
#     'nikeSize': '7',
#     'skuId': 'e7957e80-34f2-5dd7-92ca-d62e2bdd73d6',
#     'localizedSize': 'M 7 / W 8.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093823',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149411',
#     'nikeSize': '7.5',
#     'skuId': 'd693a6a5-c55b-58f0-8a2f-f246bc754387',
#     'localizedSize': 'M 7.5 / W 9',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093830',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149424',
#     'nikeSize': '8',
#     'skuId': 'f7457e1d-877c-511f-a527-ef792918dab1',
#     'localizedSize': 'M 8 / W 9.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093847',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149409',
#     'nikeSize': '8.5',
#     'skuId': '14595e30-a4e5-58eb-bee3-0f102d2d5c5f',
#     'localizedSize': 'M 8.5 / W 10',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093854',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149423',
#     'nikeSize': '9',
#     'skuId': '640dca4c-b4f5-57f6-9759-52c345a2b565',
#     'localizedSize': 'M 9 / W 10.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093861',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149407',
#     'nikeSize': '9.5',
#     'skuId': '07957ad4-33cd-5c73-b25c-4e88f6637f21',
#     'localizedSize': 'M 9.5 / W 11',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093878',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149418',
#     'nikeSize': '10',
#     'skuId': 'a4877014-12a3-56dd-a00e-54fabfd73a86',
#     'localizedSize': 'M 10 / W 11.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093885',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149422',
#     'nikeSize': '10.5',
#     'skuId': '52228558-4358-5534-b0d9-bd92155cd1ca',
#     'localizedSize': 'M 10.5 / W 12',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093892',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149416',
#     'nikeSize': '11',
#     'skuId': 'dcff2c3b-c37f-58b7-bcbc-479c503dfd75',
#     'localizedSize': 'M 11 / W 12.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093908',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149421',
#     'nikeSize': '11.5',
#     'skuId': '2938ab34-6f3f-5cbb-bfa6-a508f798145f',
#     'localizedSize': 'M 11.5 / W 13',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093915',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149414',
#     'nikeSize': '12',
#     'skuId': '61bc2026-cc74-5efa-b413-2ecaa0d5b2c8',
#     'localizedSize': 'M 12 / W 13.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093922',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149420',
#     'nikeSize': '12.5',
#     'skuId': '43fdfd68-c88c-50ea-a5c3-b756139a63cb',
#     'localizedSize': 'M 12.5 / W 14',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093939',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149412',
#     'nikeSize': '13',
#     'skuId': '52de77e2-45a4-54f6-9c5f-416740e44774',
#     'localizedSize': 'M 13 / W 14.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093946',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149410',
#     'nikeSize': '14',
#     'skuId': '3771d271-23d9-5c5e-a6d0-c04f476f59f9',
#     'localizedSize': 'M 14 / W 15.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093953',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149408',
#     'nikeSize': '15',
#     'skuId': '84c745ff-9caf-5e61-8337-dde205881cc4',
#     'localizedSize': 'M 15 / W 16.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093960',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'},
#    {'id': '26149405',
#     'nikeSize': '16',
#     'skuId': '23734e48-8293-57a6-ab6d-cb2d9e3903a1',
#     'localizedSize': 'M 16 / W 17.5',
#     'localizedSizePrefix': '',
#     'gtin': '00194957093977',
#     'productId': 'a134236f-3c64-5229-96b6-8c3fe7e33a3c'}],
#   'title': 'Nike Free Metcon 4',
#   'nodes': [{'analytics': {'hashKey': '4ad488e18aa3a21f66dd1c417fa419d6b142cac5700e4f836b693d4af800fcf6'},
#     'nodes': [{'analytics': {'hashKey': '226ed88541137a11e4dd23579e9feabc87bdd2c439586b978c9825cb3f0db14d'},
#       'subType': 'image',
#       'id': 'bcce7639-4db4-41ab-973a-a89d61a94f2d',
#       'type': 'card',
#       'version': '1674603752904',
#       'properties': {'portraitId': '342243ca-132d-4f7f-8734-44fd37d91985',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'A',
#         'aspectRatio': 1,
#         'id': 'ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'A',
#         'aspectRatio': 0.8,
#         'id': '342243ca-132d-4f7f-8734-44fd37d91985',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': 'ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'c7433786fd3d6238a8f050a160eb06fe6a6018a079b758b5fc8caafb905a228e'},
#       'subType': 'image',
#       'id': 'c227c653-7ec8-4840-b388-c22610fb0b9f',
#       'type': 'card',
#       'version': '1674603752904',
#       'properties': {'portraitId': '201251ca-adaf-4b0e-b9f6-4bcbc664eef2',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/4657cf5b-2e05-4638-9207-de9d9e373004/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/201251ca-adaf-4b0e-b9f6-4bcbc664eef2/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'B',
#         'aspectRatio': 1,
#         'id': '4657cf5b-2e05-4638-9207-de9d9e373004',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/4657cf5b-2e05-4638-9207-de9d9e373004/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'B',
#         'aspectRatio': 0.8,
#         'id': '201251ca-adaf-4b0e-b9f6-4bcbc664eef2',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/201251ca-adaf-4b0e-b9f6-4bcbc664eef2/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '4657cf5b-2e05-4638-9207-de9d9e373004',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'a916251cadbfd9aa018910a1e0227ba731bcffe3619bf203c4727ec454ca4313'},
#       'subType': 'image',
#       'id': '958fb445-8854-42b2-96da-052db13c0d6d',
#       'type': 'card',
#       'version': '1674603752904',
#       'properties': {'portraitId': '3d55d5a4-430f-4888-92d3-864ca9bda713',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/1d0fd6a9-b64c-4d89-8fa7-d36243189745/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/3d55d5a4-430f-4888-92d3-864ca9bda713/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'C',
#         'aspectRatio': 1,
#         'id': '1d0fd6a9-b64c-4d89-8fa7-d36243189745',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/1d0fd6a9-b64c-4d89-8fa7-d36243189745/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'C',
#         'aspectRatio': 0.8,
#         'id': '3d55d5a4-430f-4888-92d3-864ca9bda713',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/3d55d5a4-430f-4888-92d3-864ca9bda713/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '1d0fd6a9-b64c-4d89-8fa7-d36243189745',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'b9a03c6989397d58245943587616963c684620a4b12f4db7511dcb8672be7d83'},
#       'subType': 'image',
#       'id': '8969400e-8379-4c28-831d-f62bb7204010',
#       'type': 'card',
#       'version': '1674603752904',
#       'properties': {'portraitId': 'd8a76988-8b9d-4ca2-8857-6befd7eb2968',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/d8786e84-4554-4af3-a0e6-1c6210d01c6e/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/d8a76988-8b9d-4ca2-8857-6befd7eb2968/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'D',
#         'aspectRatio': 1,
#         'id': 'd8786e84-4554-4af3-a0e6-1c6210d01c6e',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/d8786e84-4554-4af3-a0e6-1c6210d01c6e/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'D',
#         'aspectRatio': 0.8,
#         'id': 'd8a76988-8b9d-4ca2-8857-6befd7eb2968',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/d8a76988-8b9d-4ca2-8857-6befd7eb2968/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': 'd8786e84-4554-4af3-a0e6-1c6210d01c6e',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '9d1a32f14d4361ce803c2892834a7cb033bbde8840027f60b6dab94d73d400b3'},
#       'subType': 'image',
#       'id': '59acffa0-cfa1-42ab-9af8-363774121c81',
#       'type': 'card',
#       'version': '1674603752904',
#       'properties': {'portraitId': '977cd46d-3a3a-4008-98a4-22d831f33752',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/3505ba36-a463-4476-8297-8d9c53328606/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/977cd46d-3a3a-4008-98a4-22d831f33752/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'E',
#         'aspectRatio': 1,
#         'id': '3505ba36-a463-4476-8297-8d9c53328606',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/3505ba36-a463-4476-8297-8d9c53328606/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'E',
#         'aspectRatio': 0.8,
#         'id': '977cd46d-3a3a-4008-98a4-22d831f33752',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/977cd46d-3a3a-4008-98a4-22d831f33752/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '3505ba36-a463-4476-8297-8d9c53328606',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': 'c30e2f08b14ff2d104d3560cceff82b82dbb479607e48a1185e947fc0725c7c5'},
#       'subType': 'image',
#       'id': '5c66a7ef-02e7-4e97-858a-0866f8c1cd56',
#       'type': 'card',
#       'version': '1674603752904',
#       'properties': {'portraitId': '6940670b-5664-4be4-899b-6467ce551f8e',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/36fa3e35-adf5-488c-8ce5-6405613d7491/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/6940670b-5664-4be4-899b-6467ce551f8e/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'F',
#         'aspectRatio': 1,
#         'id': '36fa3e35-adf5-488c-8ce5-6405613d7491',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/36fa3e35-adf5-488c-8ce5-6405613d7491/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'F',
#         'aspectRatio': 0.8,
#         'id': '6940670b-5664-4be4-899b-6467ce551f8e',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/6940670b-5664-4be4-899b-6467ce551f8e/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '36fa3e35-adf5-488c-8ce5-6405613d7491',
#        'subtitle': '',
# ...
#        'seoName': '',
#        'squarishId': '67273e89-5cac-45c3-97aa-51139e609b38',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '4a22326108bcdfa8c1c1673befd1577adc07033523559d04298ae4915d9812d3'},
#       'subType': 'image',
#       'id': 'd33b0add-0d93-47a4-aa2b-78ddca545dc0',
#       'type': 'card',
#       'version': '1674603750087',
#       'properties': {'portraitId': 'f7ac7b1d-45eb-480a-a651-3139832847fd',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/aa371f70-a02e-47b3-ae49-954788962550/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/f7ac7b1d-45eb-480a-a651-3139832847fd/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'H',
#         'aspectRatio': 1,
#         'id': 'aa371f70-a02e-47b3-ae49-954788962550',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/aa371f70-a02e-47b3-ae49-954788962550/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'H',
#         'aspectRatio': 0.8,
#         'id': 'f7ac7b1d-45eb-480a-a651-3139832847fd',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/f7ac7b1d-45eb-480a-a651-3139832847fd/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': 'aa371f70-a02e-47b3-ae49-954788962550',
#        'subtitle': '',
#        'colorTheme': 'dark'}},
#      {'analytics': {'hashKey': '4f82bc2a954cce848672e7b9bd367d5ad53d5d2b1859f3f976f29f306a73860b'},
#       'subType': 'image',
#       'id': 'deaf4054-a621-42cc-b068-7fa5b2ad796d',
#       'type': 'card',
#       'version': '1674603750087',
#       'properties': {'portraitId': '093e9384-6100-4892-8dd4-92a01b967176',
#        'squarishURL': 'https://static.nike.com/a/images/t_default/8141dc36-f4a8-4285-9c77-a0f9a1ff3d16/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeId': '',
#        'altText': 'Nike Free Metcon 4 Training Shoes',
#        'portraitURL': 'https://static.nike.com/a/images/t_default/093e9384-6100-4892-8dd4-92a01b967176/free-metcon-4-training-shoes-KX41Bv.png',
#        'landscapeURL': '',
#        'title': '',
#        'squarish': {'view': 'K',
#         'aspectRatio': 1,
#         'id': '8141dc36-f4a8-4285-9c77-a0f9a1ff3d16',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/8141dc36-f4a8-4285-9c77-a0f9a1ff3d16/free-metcon-4-training-shoes-KX41Bv.png'},
#        'portrait': {'view': 'K',
#         'aspectRatio': 0.8,
#         'id': '093e9384-6100-4892-8dd4-92a01b967176',
#         'type': 'product',
#         'url': 'https://static.nike.com/a/images/t_default/093e9384-6100-4892-8dd4-92a01b967176/free-metcon-4-training-shoes-KX41Bv.png'},
#        'seoName': '',
#        'squarishId': '8141dc36-f4a8-4285-9c77-a0f9a1ff3d16',
#        'subtitle': '',
#        'colorTheme': 'dark'}}],
#     'subType': 'carousel',
#     'id': 'f7bbacbb-5f90-46f0-8570-17fcbb416511',
#     'type': 'card',
#     'version': '1674603750087',
#     'properties': {'containerType': 'grid',
#      'loop': False,
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'autoPlay': False,
#      'title': '',
#      'body': '',
#      'speed': 6000}},
#    {'analytics': {'hashKey': '2bd10d9814bac3841bd9258a53ab2cf9a8aa9f68ccd61ec4a62a536e30f82c17'},
#     'subType': 'text',
#     'id': 'f5ba3b29-9958-4dfe-94ab-f48a96bc5640',
#     'type': 'card',
#     'version': '1633365074108',
#     'properties': {'copyId': '89da6c6ccc8f2c31b9553d21188539e12d355edb',
#      'product': [],
#      'richTextLinks': [],
#      'custom': {},
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#       'modifiedDate': '2021-10-04T16:31:14.015Z',
#       'exposeTemplate': False,
#       'properties': {'actions': {}},
#       'resourceType': 'content/style'},
#      'body': '<p>Explore the Nike Free Metcon 4 Training Shoe</p>',
#      'title': '',
#      'actions': []}},
#    {'analytics': {'hashKey': '9133d9cc5276fe32d38d3f2e1962cd5bb1eafdc0d807a980c479cab3434f0738'},
#     'subType': 'image',
#     'id': '45bcf90a-119d-4f67-ad47-4d0c36302d5b',
#     'type': 'card',
#     'version': '1633365132078',
#     'properties': {'portraitId': '',
#      'squarishURL': '',
#      'product': [],
#      'landscapeId': '',
#      'altText': '',
#      'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42771388-4427-4aab-9f0b-26a574d1e8df/image.jpg',
#      'custom': {},
#      'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/30917709-0fce-42c1-949f-362b0dd742d3/image.jpg',
#      'portrait': {'id': '42771388-4427-4aab-9f0b-26a574d1e8df',
#       'type': 'product',
#       'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42771388-4427-4aab-9f0b-26a574d1e8df/image.jpg'},
#      'title': '',
#      'squarishId': '',
#      'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#      'richTextLinks': [],
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#       'modifiedDate': '2021-10-04T16:32:12.058Z',
#       'exposeTemplate': False,
#       'properties': {'actions': {}},
#       'resourceType': 'content/style'},
#      'actions': [],
#      'landscape': {'id': '30917709-0fce-42c1-949f-362b0dd742d3',
#       'type': 'product',
#       'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/30917709-0fce-42c1-949f-362b0dd742d3/image.jpg'}}},
#    {'analytics': {'hashKey': '8872f83c2c0a74c5c0ac96b3a2ad1e82d40253b8659f791daae83dea49e5d3e7'},
#     'subType': 'text',
#     'id': 'bddd32d4-d7ca-42b6-8e92-465bc258bad1',
#     'type': 'card',
#     'version': '1633365080308',
#     'properties': {'copyId': '7da026d0a5a5a015078e337f5ac64e503c6252ac',
#      'product': [],
#      'richTextLinks': [],
#      'custom': {},
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#       'modifiedDate': '2021-10-04T16:31:20.279Z',
#       'exposeTemplate': False,
#       'properties': {'actions': {}},
#       'resourceType': 'content/style'},
#      'body': '<p>The 4 is bringing back the super tough yet breathable mesh from the original version. The upper gets embellished with a Huarache-inspired strap and rubber-striped sidewall that envelops your heel to brace you for movement in any direction.</p>',
#      'title': 'Blast From the Past',
#      'actions': []}},
#    {'analytics': {'hashKey': '91bc7d81648fb0bc03bb2ddb0c6c45ed6a2b70f24144e35ecbfc5820408972c2'},
#     'subType': 'image',
#     'id': '91dd0dc1-df6b-4501-8297-0bcf4a64fb6c',
#     'type': 'card',
#     'version': '1633365137061',
#     'properties': {'portraitId': '',
#      'squarishURL': '',
#      'product': [],
#      'landscapeId': '',
#      'altText': '',
#      'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg',
#      'custom': {},
#      'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg',
#      'portrait': {'id': '84c9e581-df1b-44ba-b540-d21178c21295',
#       'type': 'product',
#       'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/84c9e581-df1b-44ba-b540-d21178c21295/image.jpg'},
#      'title': '',
#      'squarishId': '',
#      'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#      'richTextLinks': [],
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#       'modifiedDate': '2021-10-04T16:32:17.053Z',
#       'exposeTemplate': False,
#       'properties': {'actions': {}},
#       'resourceType': 'content/style'},
#      'actions': [],
#      'landscape': {'id': '9d61f74a-6c21-45d4-bb60-e94c06f3c945',
#       'type': 'product',
#       'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9d61f74a-6c21-45d4-bb60-e94c06f3c945/image.jpg'}}},
#    {'analytics': {'hashKey': 'fb66428b4726a52cb2f81f5739fe5be5d4b0ad04af664ecc30339ece62b60f98'},
#     'subType': 'text',
#     'id': '3a049537-aed5-44aa-b0f5-fb3e48e56399',
#     'type': 'card',
#     'version': '1633365089421',
#     'properties': {'copyId': 'a253dd95d0bae61b5d9ca9e207e32247ceb15df6',
#      'product': [],
#      'richTextLinks': [],
#      'custom': {},
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#       'modifiedDate': '2021-10-04T16:31:29.405Z',
#       'exposeTemplate': False,
#       'properties': {'actions': {}},
#       'resourceType': 'content/style'},
#      'body': '<p>Nike Free technology in the forefoot creates flexibility for agility moves and sprints. Stretch around the collar lets your foot move naturally as you burst, cut and brake.</p>',
#      'title': 'Flexibility for Speed',
#      'actions': []}},
#    {'analytics': {'hashKey': 'add5b12590aa45c846ef8ab48ffb89ba2ee497d861dfff6291162efb2625bbc7'},
#     'subType': 'image',
#     'id': '072fa761-6350-45a0-9a85-88fad4ea24e7',
#     'type': 'card',
#     'version': '1633365102718',
#     'properties': {'portraitId': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#      'squarishURL': '',
#      'landscapeId': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#      'altText': '',
#      'portraitURL': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg',
#      'landscapeURL': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg',
#      'portrait': {'id': '42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f',
#       'type': 'product',
#       'url': 'https://static.nike.com/a/images/t_prod/w_1536,c_limit/42e05cbc-5f2d-4e7b-ba00-8ecfd3ef380f/image.jpg'},
#      'title': '',
#      'copyId': 'bf21a9e8fbc5a3846fb05b4fa0859e0917b2202f',
#      'richTextLinks': [],
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'extra_large'}},
#       'modifiedDate': '2021-10-04T16:31:42.718Z',
#       'exposeTemplate': False,
#       'resourceType': 'content/style'},
#      'actions': [],
#      'landscape': {'id': '9dcb8dcf-fc29-41d7-b283-ef87dabedbb4',
#       'type': 'product',
#       'url': 'https://static.nike.com/a/images/t_prod/w_1920,c_limit/9dcb8dcf-fc29-41d7-b283-ef87dabedbb4/image.jpg'}}},
#    {'analytics': {'hashKey': '19214ec1853bfd1aa0b5986f20c9f7bc1291c2d42405b07ae9d74bc303bb711d'},
#     'subType': 'text',
#     'id': '6de4f79e-1e52-4c01-a9d7-a21e9b8cb30b',
#     'type': 'card',
#     'version': '1633365097774',
#     'properties': {'copyId': 'd059f6db5527b41ea4abe44d472b2f9577221c23',
#      'product': [],
#      'richTextLinks': [],
#      'custom': {},
#      'subtitle': '',
#      'colorTheme': 'dark',
#      'style': {'defaultStyle': {'margin': {'top': 'medium'}},
#       'modifiedDate': '2021-10-04T16:31:37.709Z',
#       'exposeTemplate': False,
#       'properties': {'actions': {}},
#       'resourceType': 'content/style'},
#      'body': '<p>The wide heel creates a solid base for lifting. A softer foam core cushions your foot, while a firmer outer layer is durable and stable. Wide internal webbing distributes pressure around your midfoot for a comfortable yet locked-in feel during sudden stops and quick cuts.</p>',
#      'title': 'Stability for Strength',
#      'actions': []}}],
#   'layoutCards': [],
#   'firstImageUrl': 'https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png',
#   'firstImageAltText': 'Nike Free Metcon 4 Training Shoes',
#   'sustainabilityMessage': [],
#   'descriptionPreviewBullets': '',
#   'moreInfoMessages': [],
#   'sizeFitMessages': [],
#   'hubMessages': [],
#   'language': 'en',
#   'marketplace': 'US',
#   'availableSkus': [{'id': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da',
#     'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/ef237b73-2633-56fe-8ebd-fbc2258fa8da'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': 'ef237b73-2633-56fe-8ebd-fbc2258fa8da'},
#    {'id': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f',
#     'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': '2c32a782-bd9d-56e8-9780-ba1ddd0f5d8f'},
#    {'id': '9fd7e097-24db-5c33-b660-d300c3f6579c',
#     'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/9fd7e097-24db-5c33-b660-d300c3f6579c'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': '9fd7e097-24db-5c33-b660-d300c3f6579c'},
#    {'id': 'da0611fb-2af5-53fa-89c3-8baea350977b',
#     'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/da0611fb-2af5-53fa-89c3-8baea350977b'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': 'da0611fb-2af5-53fa-89c3-8baea350977b'},
#    {'id': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca',
#     'productId': '4230a9aa-8434-5c0a-991c-23c557cada21',
#     'resourceType': 'availableSkus',
#     'links': {'self': {'ref': '/deliver/available_skus/v1/4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}},
#     'available': True,
#     'level': 'LOW',
#     'skuId': '4a3566bc-5d0b-5f36-ae25-ee66ed4f36ca'}],
#   'publishType': 'FLOW',
#   'isLaunchView': False,
#   'launchView': None,
#   'isForNumberOfImagesABTesting': False,
#   'isMinimumAdvertisedPrice': False,
#   'collectionTermIds': ['c05bedd9-29d3-4e45-8c62-c463f9c5958f',
#    '1a70e9af-aea9-4a39-9773-fa6ced97c58b',
#    '65838112-1f4d-48a7-9b2f-1e8736c4cdcc',
#    'a49f8e69-ff9c-4356-89d8-d4a098fc02c2',
#    'e4e46ee6-496f-491a-8771-1a677eefee3a',
#    '94d2c954-14cd-4784-96ec-b02c950d2872',
#    '62f3c208-e1a3-45c0-9e70-a90be4e276f1',
#    'b9cefedb-1dd5-42dc-af13-939a240d4bb8',
#    '4be7e5d7-7e5b-460d-b3d7-41396b3fa985'],
#   'conceptIds': ['f3e53c71-c423-401a-98d8-58ab7c5ead07',
#    '12dfa6f8-bf97-333f-bf8a-e7e2b4b03917',
#    '5b915c7f-6f38-489a-a1a7-acc3b574551d',
#    'a062e621-5ee9-4d20-ac4f-cc2b83ba401c',
#    '292efae5-2d9a-44a3-a529-cda684a47c44',
#    'bcab1a4e-d080-3e6d-9a2e-5d9538064d60',
#    '7702dda3-62ca-3410-b4f3-97025be1089d',
#    '68a7b17f-291f-41f8-bf04-5e2fbe878d9b',
#    '05392778-fff6-4fa0-a375-2506d27f009e',
#    '2d375fdb-39a1-4982-842f-3f4a357ec32b',
#    '758f6b44-e5a7-46be-b288-bac9c3ebe83f',
#    'b942d0ac-4887-4a8f-b914-d82a6181014f',
#    '67063381-90eb-4763-8f87-acc30b392f38',
#    '699b34a6-1950-3458-8322-910b695fccb7',
#    '527f2d29-89bd-422d-a53a-cdb52784a8a9',
#    '10f9af5a-58d2-480a-a72d-5a65bd374850',
#    '0a937561-8633-3ea1-8ae3-8509f50f4127',
#    '6de391eb-ab3d-4625-a5e7-d537e87f2bfa',
#    '01097ea6-0c27-3c83-91eb-d7757ac196e3',
#    '97ea50fe-970f-3816-8ce6-90e79890d2f7',
#    '539c6c43-d060-30b0-be5b-47c47f7c7658',
#    'cb09fd63-b7c0-3aef-a9a6-040218d4b4e4',
#    '9e5e6948-8820-4a24-a4d3-01cdb5dc8291',
#    '2dcff554-e5ff-3b40-b222-4bc50947c1c2',
#    '63b97c64-c4e8-4ba2-8e2e-0814e6eaf9b7',
#    '1b8d9aea-0567-4942-b419-bb0c61785b8d',
#    '2057952b-1a72-368e-b4b1-f67091ff1799',
#    '6e7e4809-fccb-4e82-8a7b-047125398076',
#    '9b0e77d0-aec5-4f4b-b8de-acb7a82e396d',
#    '2e0b5ce6-1e53-377c-ad44-9f504f7d226a',
#    '7abdd901-856d-3601-94bf-14313cee8354',
#    '0f64ecc7-d624-4e91-b171-b83a03dd8550',
#    'b5cd158b-b105-490c-b777-652943e742b0',
#    'f5c24c6d-bcb8-31ec-a177-b8d75e902d1b',
#    '37734db6-efb3-39b9-bd03-fe43d8f87daf',
#    '37a4f06f-eb0e-4ef0-8926-629ebc55ba14',
#    '16633190-45e5-4830-a068-232ac7aea82c',
#    '568f7ffc-ee7f-49ed-98eb-0b94708d6e88',
#    '7817e756-7721-4cfb-b404-04df79c685e4',
#    'c29a0094-d302-4b7a-b5f0-73e46f772348'],
#   'sizeChartUrl': 'https://www.nike.com/size-fit/unisex-footwear-mens-based',
#   'catalogId': '1',
#   'selectedSkuId': {},
#   'sizeAndFitDescription': '',
#   'exclusiveAccess': False,
#   'notifyMeIndicator': False,
#   'promoExclusionAccess': False,
#   'useFeedsPromoExclusionMessage': False,
#   'jerseyIdPathName': '',
#   'nbyHubMessages': [],
#   'state': 'IN_STOCK'}}

# %%
json_object['props']['pageProps']['initialState']['Threads']['products'].keys()
# Out:
# dict_keys(['DZ6326-001', 'CT3886-011', 'CT3886-390', 'CT3886-010', 'CT3886-693', 'CT3886-601', 'CT3886-600', 'CT3886-004', 'CT3886-300', 'CT3886-400'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads']['products'].keys():
#     print(i,"\n\n\n",json_object['props']['pageProps']['initialState']['Threads']['products'][i],"\n\n\n\n\n")

# %%
for i in json_object['props']['pageProps']['initialState']['Threads']['products'].keys():
    print(i,"\n\n\n",json_object['props']['pageProps']['initialState']['Threads']['products'][i].keys(),"\n\n\n\n\n")
# Out:
# DZ6326-001
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-011
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-390
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-010
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-693
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-601
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-600
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-004
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-300
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])
#
#
#
#
#
# CT3886-400
#
#
#  dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])

# %% [markdown]
# AS you can see above, all products had the same keys, therefore we can make the dictionary hashings dynamic hence forth. For now, I am going to using the following product id: CT3886-011 as test for now then make the code fully dynamic later.

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011'].keys()
# Out:
# dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages', 'language', 'marketplace', 'availableSkus', 'publishType', 'isLaunchView', 'launchView', 'isForNumberOfImagesABTesting', 'isMinimumAdvertisedPrice', 'collectionTermIds', 'conceptIds', 'sizeChartUrl', 'catalogId', 'selectedSkuId', 'sizeAndFitDescription', 'exclusiveAccess', 'notifyMeIndicator', 'promoExclusionAccess', 'useFeedsPromoExclusionMessage', 'jerseyIdPathName', 'nbyHubMessages', 'state'])

# %% [markdown]
# # Extracting test values or example values that we need.

# %%
tes1 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['title']
tes2 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['currentPrice']
tes3 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['colorDescription']
tes4 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['firstImageUrl']

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0].keys()
# Out:
# dict_keys(['analytics', 'nodes', 'subType', 'id', 'type', 'version', 'properties'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0].keys():
#     print(i,"\n",json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0].keys()
# Out:
# dict_keys(['analytics', 'subType', 'id', 'type', 'version', 'properties'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0].keys():
#     print(i,"\n",json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0]['properties']
# Out:
# {'portraitId': '342243ca-132d-4f7f-8734-44fd37d91985',
#  'squarishURL': 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png',
#  'landscapeId': '',
#  'altText': 'Nike Free Metcon 4 Training Shoes',
#  'portraitURL': 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png',
#  'landscapeURL': '',
#  'title': '',
#  'squarish': {'view': 'A',
#   'aspectRatio': 1,
#   'id': 'ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab',
#   'type': 'product',
#   'url': 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png'},
#  'portrait': {'view': 'A',
#   'aspectRatio': 0.8,
#   'id': '342243ca-132d-4f7f-8734-44fd37d91985',
#   'type': 'product',
#   'url': 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png'},
#  'seoName': '',
#  'squarishId': 'ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab',
#  'subtitle': '',
#  'colorTheme': 'dark'}

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0]['properties'].keys()
# Out:
# dict_keys(['portraitId', 'squarishURL', 'landscapeId', 'altText', 'portraitURL', 'landscapeURL', 'title', 'squarish', 'portrait', 'seoName', 'squarishId', 'subtitle', 'colorTheme'])

# %%
squarishURL = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0]['properties']['squarishURL']
portraitURL = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0]['properties']['portraitURL']
squarishURL2 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0]['properties']['squarish']['url']
portraitURL2 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-011']['nodes'][0]['nodes'][0]['properties']['portrait']['url']

# %% [markdown]
# # Data stuctures to hold our scraped values so we can turn it into a dataframe Later

# %%
Titles = []
prices = []
color = []
FirstImagesUrl = []
URL1 = []
URL2 = []
URL3 = []
URL4 = []

# %% [markdown]
# # NOW WE MAKE IT DYNAMIC!!

# %%
for i in json_object['props']['pageProps']['initialState']['Threads']['products'].keys():
    temp_list_for_pictures = []
    val1 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['title']
    val2 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['currentPrice']
    val3 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['colorDescription']
    val4 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['firstImageUrl']
    pic1 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['squarishURL']
    pic2 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['portraitURL']
    pic3 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['squarish']['url']
    pic4 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['portrait']['url']
    Titles.append(val1)
    prices.append(val2)
    color.append(val3)
    FirstImagesUrl.append(val4)
    URL1.append(pic1)
    URL2.append(pic2)
    URL3.append(pic3)
    URL4.append(pic4)

# %% [markdown]
# # Creating a DataFrame to organize everything

# %%
shoes = {
    "Title": Titles,
    "Price": prices,
    "Color": color,
    "FirstImageUrl": FirstImagesUrl,
    "squarishURL": URL1,
    "portraitURL": URL2,
    "squarishURL2": URL3,
    "portraitURL2" : URL4,
}

# %%
Final_Metcon_Data = pd.DataFrame(shoes)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
Final_Metcon_Data
# Out:
#                     Title   Price  \
# 0  Nike Free Metcon 4 AMP  120.00
# 1      Nike Free Metcon 4  120.00
# 2      Nike Free Metcon 4  120.00
# 3      Nike Free Metcon 4  120.00
# 4      Nike Free Metcon 4  120.00
# 5      Nike Free Metcon 4   92.97
# 6      Nike Free Metcon 4  120.00
# 7      Nike Free Metcon 4  120.00
# 8      Nike Free Metcon 4  120.00
# 9      Nike Free Metcon 4  120.00
#
#                                                Color  \
# 0  Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black
# 1                     Iron Grey/Grey Fog/White/Black
# 2                    Pro Green/Black/White/Pro Green
# 3                         Black/Iron Grey/Volt/Black
# 4                Team Maroon/Black/White/Team Maroon
# 5                Team Red/Cave Purple/Bright Crimson
# 6                         University Red/White/Black
# 7        Anthracite/White/Blue Lightning/Citron Tint
# 8     Mint Foam/Barely Green/Cave Purple/Ghost Green
# 9                            Signal Blue/White/Black
#
#                                                                                                                  FirstImageUrl  \
# 0  https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png
# 1      https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png
# 2      https://static.nike.com/a/images/t_default/acd7a9fd-87ae-4f37-8ea5-919d85b666b3/free-metcon-4-training-shoes-KX41Bv.png
# 3      https://static.nike.com/a/images/t_default/decea93c-13eb-4465-9e7b-480091106d17/free-metcon-4-training-shoes-KX41Bv.png
# 4      https://static.nike.com/a/images/t_default/845c7c00-07d6-4dda-97e0-98838438484c/free-metcon-4-training-shoes-KX41Bv.png
# 5      https://static.nike.com/a/images/t_default/2b2a0b8b-152d-4a6d-9012-e7bab1ecb3e3/free-metcon-4-training-shoes-KX41Bv.png
# 6      https://static.nike.com/a/images/t_default/7886881f-c4f7-4196-add1-20147c3c0e7b/free-metcon-4-training-shoes-KX41Bv.png
# 7      https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png
# 8      https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-training-shoes-KX41Bv.png
# 9      https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png
#
#                                                                                                                    squarishURL  \
# 0  https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png
# 1      https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png
# 2      https://static.nike.com/a/images/t_default/acd7a9fd-87ae-4f37-8ea5-919d85b666b3/free-metcon-4-training-shoes-KX41Bv.png
# 3      https://static.nike.com/a/images/t_default/decea93c-13eb-4465-9e7b-480091106d17/free-metcon-4-training-shoes-KX41Bv.png
# 4      https://static.nike.com/a/images/t_default/845c7c00-07d6-4dda-97e0-98838438484c/free-metcon-4-training-shoes-KX41Bv.png
# 5      https://static.nike.com/a/images/t_default/2b2a0b8b-152d-4a6d-9012-e7bab1ecb3e3/free-metcon-4-training-shoes-KX41Bv.png
# 6      https://static.nike.com/a/images/t_default/7886881f-c4f7-4196-add1-20147c3c0e7b/free-metcon-4-training-shoes-KX41Bv.png
# 7      https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png
# 8      https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-training-shoes-KX41Bv.png
# 9      https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png
#
#                                                                                                                    portraitURL  \
# 0  https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png
# 1      https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png
# 2      https://static.nike.com/a/images/t_default/31320bac-edac-4593-acc1-92b7a04fb608/free-metcon-4-training-shoes-KX41Bv.png
# 3      https://static.nike.com/a/images/t_default/4fa65f97-c9a9-4446-847f-fa73db77c681/free-metcon-4-training-shoes-KX41Bv.png
# 4      https://static.nike.com/a/images/t_default/cf0c4819-f09b-4d8e-b08c-5c8ca990ee83/free-metcon-4-training-shoes-KX41Bv.png
# 5      https://static.nike.com/a/images/t_default/029605ed-185c-4e66-bbbe-215052658bd6/free-metcon-4-training-shoes-KX41Bv.png
# 6      https://static.nike.com/a/images/t_default/655bd09c-f56c-4375-8027-1374aa3245bc/free-metcon-4-training-shoes-KX41Bv.png
# 7      https://static.nike.com/a/images/t_default/a22f19be-c9b6-4c01-85ea-f513b2be8180/free-metcon-4-training-shoes-KX41Bv.png
# 8      https://static.nike.com/a/images/t_default/15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0/free-metcon-4-training-shoes-KX41Bv.png
# 9      https://static.nike.com/a/images/t_default/be170ab9-c41b-458d-8626-b47348ba74c1/free-metcon-4-training-shoes-KX41Bv.png
#
#                                                                                                                   squarishURL2  \
# 0  https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png
# 1      https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png
# 2      https://static.nike.com/a/images/t_default/acd7a9fd-87ae-4f37-8ea5-919d85b666b3/free-metcon-4-training-shoes-KX41Bv.png
# 3      https://static.nike.com/a/images/t_default/decea93c-13eb-4465-9e7b-480091106d17/free-metcon-4-training-shoes-KX41Bv.png
# 4      https://static.nike.com/a/images/t_default/845c7c00-07d6-4dda-97e0-98838438484c/free-metcon-4-training-shoes-KX41Bv.png
# 5      https://static.nike.com/a/images/t_default/2b2a0b8b-152d-4a6d-9012-e7bab1ecb3e3/free-metcon-4-training-shoes-KX41Bv.png
# 6      https://static.nike.com/a/images/t_default/7886881f-c4f7-4196-add1-20147c3c0e7b/free-metcon-4-training-shoes-KX41Bv.png
# 7      https://static.nike.com/a/images/t_default/3954af94-ef0e-4277-a3a2-2df84eba652a/free-metcon-4-training-shoes-KX41Bv.png
# 8      https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-training-shoes-KX41Bv.png
# 9      https://static.nike.com/a/images/t_default/66ff0862-3564-4062-b8db-fb153820642b/free-metcon-4-training-shoes-KX41Bv.png
#
#                                                                                                                   portraitURL2
# 0  https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png
# 1      https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png
# 2      https://static.nike.com/a/images/t_default/31320bac-edac-4593-acc1-92b7a04fb608/free-metcon-4-training-shoes-KX41Bv.png
# 3      https://static.nike.com/a/images/t_default/4fa65f97-c9a9-4446-847f-fa73db77c681/free-metcon-4-training-shoes-KX41Bv.png
# 4      https://static.nike.com/a/images/t_default/cf0c4819-f09b-4d8e-b08c-5c8ca990ee83/free-metcon-4-training-shoes-KX41Bv.png
# 5      https://static.nike.com/a/images/t_default/029605ed-185c-4e66-bbbe-215052658bd6/free-metcon-4-training-shoes-KX41Bv.png
# 6      https://static.nike.com/a/images/t_default/655bd09c-f56c-4375-8027-1374aa3245bc/free-metcon-4-training-shoes-KX41Bv.png
# 7      https://static.nike.com/a/images/t_default/a22f19be-c9b6-4c01-85ea-f513b2be8180/free-metcon-4-training-shoes-KX41Bv.png
# 8      https://static.nike.com/a/images/t_default/15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0/free-metcon-4-training-shoes-KX41Bv.png
# 9      https://static.nike.com/a/images/t_default/be170ab9-c41b-458d-8626-b47348ba74c1/free-metcon-4-training-shoes-KX41Bv.png

# %% [markdown]
# # Storing this data into a database in mysql Workbench

# %% [markdown]
# WE shall be creating a connection to mysql.connector to create our tables here in python and also check the data in our tables later on

# %%
import mysql.connector
from mysql.connector import errorcode

try:
  connection = mysql.connector.connect(host='localhost',
                                user='root',
                                passwd='kitboy123!')
  print("Connection Succesful!!")

except mysql.connector.Error as err:
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  else:
    print(err)
# Out:
# Connection Succesful!!

# %% [markdown]
# # Pre-defined queries to perform our desired functions

# %%
Database_use_Query = "use Data_Engineer_Track"

Table_Creation_Query = '''Create Table Nike_Shoes(col int primary key auto_increment, Title varchar(50), Price float, Color varchar(50),
                        FirstImageUrl varchar(1000), squarishURL varchar(1000), portraitURL varchar(1000), squarishURL2 varchar(1000),
                        portraitURL2 varchar(1000))'''

Final_result = '''Select * from Nike_Shoes;'''

# %%
cursor = connection.cursor()
cursor.execute(Database_use_Query) #query to be executed
# cursor.execute(Table_Creation_Query)
# result = cursor.fetchall() #Grabbing the result
# print(result)

# %% [markdown]
# # Creating A Engine connection to be able to connect to our database and write or desired results to A table

# %% [markdown]
# In this part, I shall be using the sqlalchemy python packacge to make a connection to our database and create a engine. We then write the final mecon results to the database

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw="kitboy123!",
                               db="Data_Engineer_Track"))

# %% [markdown]
# # Finally Writing Our Dataframe To MYSQL WORKBENCH!

# %% [markdown]
# "Nike shoes" in this case is the name of our table and  con is the connection which would be the engine we created above. If exist is asking of what action to take if the table already exist and index = false means do not write the index of the dataframe to the database

# %%
#Final_Metcon_Data.to_sql('nike_shoes', con = engine, if_exists = 'append', chunksize = 1000,index= False)

# %% [markdown]
# # Checking our Final output or result that is stored in the database.

# %%
cursor.execute(Database_use_Query)
cursor.execute(Final_result) #Query to be executed
result = cursor.fetchall()
print(result)
# Out:
# [(1, 'Nike Free Metcon 4 AMP', 120.0, 'Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black', 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png'), (2, 'Nike Free Metcon 4', 120.0, 'Iron Grey/Grey Fog/White/Black', 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/342243ca-132d-4f7f-8734-44fd37d91985/free-metcon-4-training-shoes-KX41Bv.png'), (3, 'Nike Free Metcon 4', 120.0, 'Pro Green/Black/White/Pro Green', 'https://static.nike.com/a/images/t_default/acd7a9fd-87ae-4f37-8ea5-919d85b666b3/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/acd7a9fd-87ae-4f37-8ea5-919d85b666b3/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/31320bac-edac-4593-acc1-92b7a04fb608/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/acd7a9fd-87ae-4f37-8ea5-919d85b666b3/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/31320bac-edac-4593-acc1-92b7a04fb608/free-metcon-4-training-shoes-KX41Bv.png'), (4, 'Nike Free Metcon 4', 120.0, 'Black/Iron Grey/Volt/Black', 'https://static.nike.com/a/images/t_default/decea93c-13eb-4465-9e7b-480091106d17/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/decea93c-13eb-4465-9e7b-480091106d17/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/4fa65f97-c9a9-4446-847f-fa73db77c681/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/decea93c-13eb-4465-9e7b-480091106d17/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/4fa65f97-c9a9-4446-847f-fa73db77c681/free-metcon-4-training-shoes-KX41Bv.png'), (5, 'Nike Free Metcon 4', 120.0, 'Team Maroon/Black/White/Team Maroon', 'https://static.nike.com/a/images/t_default/845c7c00-07d6-4dda-97e0-98838438484c/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/845c7c00-07d6-4dda-97e0-98838438484c/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/cf0c4819-f09b-4d8e-b08c-5c8ca990ee83/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/845c7c00-07d6-4dda-97e0-98838438484c/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/cf0c4819-f09b-4d8e-b08c-5c8ca990ee83/free-metcon-4-training-shoes-KX41Bv.png'), (6, 'Nike Free Metcon 4', 92.97, 'Team Red/Cave Purple/Bright Crimson', 'https://static.nike.com/a/images/t_default/2b2a0b8b-152d-4a6d-9012-e7bab1ecb3e3/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/2b2a0b8b-152d-4a6d-9012-e7bab1ecb3e3/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/029605ed-185c-4e66-bbbe-215052658bd6/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/2b2a0b8b-152d-4a6d-9012-e7bab1ecb3e3/free-metcon-4-tra ...
