# %%
'''In this program I am making an api request with regular request python module to make google searches.
I shall also be using try and except clauses in python.'''

import html_to_json
import pandas as pd
import requests
import json

#Link of what you want to search using search api.
urlLink = "https://www.nike.com/t/free-metcon-4-training-shoes-KX41Bv/CT3886-301?nikemt=true&cp=38647199687_search_%7CPRODUCT_GROUP%7CGOOGLE%7C71700000101429394%7CGG_Evergreen_Shopping_Shoes_AllShoes%7C%7Cc&exp=2011&gclsrc=aw.ds&&gclid=CjwKCAiAkrWdBhBkEiwAZ9cdcG7uW3qP3yZZIUe8oysRg4raRJLgiCGHfPXxeNCBlp908KAIcQgWcxoCF1kQAvD_BwE&gclsrc=aw.ds"

response = requests.get(url=urlLink)
response.encoding = 'ISO-8859-1'
print("The data's encoding is:",response.encoding)
print("\nstatusCode:", response.status_code)
#print("\nThe respose headers are:",response.headers)
#print("\nThe response content:",response.content)
#print(response.text)


data_in_json = html_to_json.convert(response.text)
print(data_in_json.keys())
#converting it from a list to dictionary

data = data_in_json['html']
actualData = data[0]

print("Here are the keys to the returned data:", actualData.keys())

################################## Now We access our Data!! Yay!!!#########################
#print(actualData['body'][0])
count = 1
for i in actualData['body'][0].keys():
    if i == 'script':
        print(len(actualData['body'][0][i]))
        #print("Key==", i, "\n\n\n\n", actualData['body'][0][i], "\n")
        #print(actualData['body'][0][i][7])
        # for j in actualData['body'][0][i]:
        #     try:
        #         print(j['_attributes'])
        #     except:
        #         print("This is an exception")
        #         print(j['_value'])
        #     count = count + 1

# for i in data_in_json['html']:
#     print(i)
# Out:
# The data's encoding is: ISO-8859-1
#
# statusCode: 200
# dict_keys(['_value', 'html'])
# Here are the keys to the returned data: dict_keys(['_attributes', 'head', 'body'])
# 26

# %% [markdown]
# Further breaking down the dictionary and trying to Access the real images we want. We use the json.loads() to convert  the str dictonary data to json

# %%
for i in actualData['body'][0].keys():
    if i == 'script':
        for line in actualData['body'][0][i]:
            #print(line,"\n\n\n")
            if len(line.keys()) == 2:
                #print(line["_attributes"],"\n\n")
                if line["_attributes"]['type'] == 'application/json':
                    #print(line["_value"])
                    json_object = json.loads(line["_value"]) #converting the str json format data to actual json and dictonary instead of a string

# %% [markdown]
# # Inspecting JSON Object

# %%
json_object
# Out:
# {'props': {'pageProps': {'initialState': {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#       'titleTemplate': '%s',
#       'meta': [{'name': 'description',
#         'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#        {'name': 'keywords', 'content': 'Nike Free Metcon 4 Workout Shoes'},
#        {'name': 'robots', 'content': 'index, follow'},
#        {'property': 'og:title',
#         'content': 'Nike Free Metcon 4 Workout Shoes. Nike.com'},
#        {'property': 'og:description',
#         'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#        {'property': 'og:type', 'content': 'website'},
#        {'property': 'og:url',
#         'content': 'https://www.nike.com/t/free-metcon-4-workout-shoes-KX41Bv'},
#        {'property': 'og:image',
# ...

# %% [markdown]
# # Now we are gonna work with the new json object to access data and our pictures

# %% [markdown]
# We are going to be hashing the keys and accessing the data one by one. The step by steps will show us printing the data then checking for the extra keys inside the data and accesing those.

# %%
print(json_object.keys())
# Out:
# dict_keys(['props', 'page', 'query', 'buildId', 'assetPrefix', 'isFallback', 'gssp', 'customServer'])

# %%
# for i in json_object.keys():
#     print(i,"\n\n",json_object[i], "\n\n\n\n\n")

# %%
json_object['props']
# Out:
# {'pageProps': {'initialState': {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#      'titleTemplate': '%s',
#      'meta': [{'name': 'description',
#        'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#       {'name': 'keywords', 'content': 'Nike Free Metcon 4 Workout Shoes'},
#       {'name': 'robots', 'content': 'index, follow'},
#       {'property': 'og:title',
#        'content': 'Nike Free Metcon 4 Workout Shoes. Nike.com'},
#       {'property': 'og:description',
#        'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#       {'property': 'og:type', 'content': 'website'},
#       {'property': 'og:url',
#        'content': 'https://www.nike.com/t/free-metcon-4-workout-shoes-KX41Bv'},
#       {'property': 'og:image',
# ...

# %%
json_object['props'].keys()
# Out:
# dict_keys(['pageProps', '__N_SSP'])

# %%
# for i in json_object['props'].keys():
#     print(i,"\n\n\n",json_object['props'][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']
# Out:
# {'initialState': {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#     'titleTemplate': '%s',
#     'meta': [{'name': 'description',
#       'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#      {'name': 'keywords', 'content': 'Nike Free Metcon 4 Workout Shoes'},
#      {'name': 'robots', 'content': 'index, follow'},
#      {'property': 'og:title',
#       'content': 'Nike Free Metcon 4 Workout Shoes. Nike.com'},
#      {'property': 'og:description',
#       'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#      {'property': 'og:type', 'content': 'website'},
#      {'property': 'og:url',
#       'content': 'https://www.nike.com/t/free-metcon-4-workout-shoes-KX41Bv'},
#      {'property': 'og:image',
#       'content': 'https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-workout-shoes-KX41Bv.png'},
# ...

# %%
json_object['props']['pageProps'].keys()
# Out:
# dict_keys(['initialState'])

# %%
json_object['props']['pageProps']['initialState']
# Out:
# {'global': {'metaTags': {'defaultTitle': 'Nike Store. Shoes, Clothing & Gear.',
#    'titleTemplate': '%s',
#    'meta': [{'name': 'description',
#      'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#     {'name': 'keywords', 'content': 'Nike Free Metcon 4 Workout Shoes'},
#     {'name': 'robots', 'content': 'index, follow'},
#     {'property': 'og:title',
#      'content': 'Nike Free Metcon 4 Workout Shoes. Nike.com'},
#     {'property': 'og:description',
#      'content': 'Find the Nike Free Metcon 4 Workout Shoes at Nike.com.  Free delivery and returns.'},
#     {'property': 'og:type', 'content': 'website'},
#     {'property': 'og:url',
#      'content': 'https://www.nike.com/t/free-metcon-4-workout-shoes-KX41Bv'},
#     {'property': 'og:image',
#      'content': 'https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-workout-shoes-KX41Bv.png'},
# ...

# %%
json_object['props']['pageProps']['initialState'].keys()
# Out:
# dict_keys(['global', 'reviews', 'localization', 'banner', 'App', 'Threads', 'NikeId', 'NotQuiteReady', 'Fit', 'EDD', 'User', 'FitAnalytics', 'Cart', 'Config', 'Console', 'CrossSell', 'Auth', 'Experiments', 'Launch', 'MAPProducts', 'Privacy', 'Device', 'Overlays', 'Common', 'META', 'NOTIFY_ME', 'intl'])

# %%
# for i in json_object['props']['pageProps']['initialState'].keys():
#     print(i,"\n\n\n",json_object['props']['pageProps']['initialState'][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']
# Out:
# {'threads': None,
#  'error': None,
#  'async': {'threads': False,
#   'thread': False,
#   'availableSkus': False,
#   'prebuildSuggestion': None},
#  'products': {'CT3886-300': {'id': '4b72f6c9-5728-5c73-b52b-8d63f3f1993c',
#    'threadId': '88976992-1fb9-41cd-a5bc-8c4b50173a2d',
#    'productId': '14095565',
#    'mainColor': False,
#    'productRollup': {'type': 'Standard', 'key': 'KX41Bv'},
#    'width': None,
#    'athletes': [],
#    'styleColor': 'CT3886-300',
#    'styleCode': 'CT3886',
#    'category': 'Training & Gym,Workouts',
#    'pid': '14095565',
#    'preOrder': False,
#    'preorderAvailabilityDate': '',
#    'commerceStartDate': '2022-07-21T14:00:00.000Z',
#    'isNYBCountDown': False,
#    'countdown': -1,
#    'hardLaunch': True,
#    'sportTags': ['Training & Gym', 'Workouts'],
#    'genders': ['MEN'],
#    'brand': 'Nike',
#    'productType': 'FOOTWEAR',
#    'nikeIdStyleCode': '',
#    'productGroupId': '13888937',
#    'styleType': 'INLINE',
# ...

# %%
json_object['props']['pageProps']['initialState']['Threads'].keys()
# Out:
# dict_keys(['threads', 'error', 'async', 'products'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads'].keys():
#     print(i,"\n\n\n",json_object['props']['pageProps']['initialState']['Threads'][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']
# Out:
# {'CT3886-300': {'id': '4b72f6c9-5728-5c73-b52b-8d63f3f1993c',
#   'threadId': '88976992-1fb9-41cd-a5bc-8c4b50173a2d',
#   'productId': '14095565',
#   'mainColor': False,
#   'productRollup': {'type': 'Standard', 'key': 'KX41Bv'},
#   'width': None,
#   'athletes': [],
#   'styleColor': 'CT3886-300',
#   'styleCode': 'CT3886',
#   'category': 'Training & Gym,Workouts',
#   'pid': '14095565',
#   'preOrder': False,
#   'preorderAvailabilityDate': '',
#   'commerceStartDate': '2022-07-21T14:00:00.000Z',
#   'isNYBCountDown': False,
#   'countdown': -1,
#   'hardLaunch': True,
#   'sportTags': ['Training & Gym', 'Workouts'],
#   'genders': ['MEN'],
#   'brand': 'Nike',
#   'productType': 'FOOTWEAR',
#   'nikeIdStyleCode': '',
#   'productGroupId': '13888937',
#   'styleType': 'INLINE',
#   'status': 'ACTIVE',
#   'displayOrder': '',
#   'subTitle': 'Workout Shoes',
#   'fullTitle': 'Nike Free Metcon 4 Workout Shoes',
#   'additionalInfo': None,
#   'sizeChart': None,
# ...

# %%
json_object['props']['pageProps']['initialState']['Threads']['products'].keys()
# Out:
# dict_keys(['CT3886-300'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads']['products'].keys():
#     print(i,"\n\n\n",json_object['props']['pageProps']['initialState']['Threads']['products'][i],"\n\n\n\n\n")

# %%
for i in json_object['props']['pageProps']['initialState']['Threads']['products'].keys():
    print(i,"\n\n\n",json_object['props']['pageProps']['initialState']['Threads']['products'][i].keys(),"\n\n\n\n\n")
# Out:
# CT3886-300
#
#
# ...

# %% [markdown]
# AS you can see above, all products had the same keys, therefore we can make the dictionary hashings dynamic hence forth. For now, I am going to use the following product id: CT3886-011 as test for now then make the code fully dynamic later.

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300'].keys()
# Out:
# dict_keys(['id', 'threadId', 'productId', 'mainColor', 'productRollup', 'width', 'athletes', 'styleColor', 'styleCode', 'category', 'pid', 'preOrder', 'preorderAvailabilityDate', 'commerceStartDate', 'isNYBCountDown', 'countdown', 'hardLaunch', 'sportTags', 'genders', 'brand', 'productType', 'nikeIdStyleCode', 'productGroupId', 'styleType', 'status', 'displayOrder', 'subTitle', 'fullTitle', 'additionalInfo', 'sizeChart', 'langLocale', 'marketing', 'origin', 'colorDescription', 'description', 'descriptionPreview', 'nbyContentCopy', 'prebuildId', 'mainPrebuild', 'isNikeID', 'isNBYDesign', 'updatedNBYDesignKey', 'piid', 'pathName', 'vas', 'nbyCustomMessage', 'seoProductDescription', 'seoProductAvailability', 'seoProductReleaseDate', 'discounted', 'fullPrice', 'currentPrice', 'employeePrice', 'currency', 'skus', 'title', 'nodes', 'layoutCards', 'firstImageUrl', 'firstImageAltText', 'sustainabilityMessage', 'descriptionPreviewBullets', 'moreInfoMessages', 'sizeFitMessages', 'hubMessages',
# ...

# %% [markdown]
# # Extracting test values or example values that we need.

# %%
tes1 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['title']
tes2 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['currentPrice']
tes3 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['colorDescription']
tes4 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['firstImageUrl']

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0].keys()
# Out:
# dict_keys(['analytics', 'nodes', 'subType', 'id', 'type', 'version', 'properties'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0].keys():
#     print(i,"\n",json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0].keys()
# Out:
# dict_keys(['analytics', 'subType', 'id', 'type', 'version', 'properties'])

# %%
# for i in json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0].keys():
#     print(i,"\n",json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0][i],"\n\n\n\n\n")

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0]['properties']
# Out:
# {'portraitId': '15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0',
#  'squarishURL': 'https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-workout-shoes-KX41Bv.png',
#  'landscapeId': '',
#  'altText': 'Nike Free Metcon 4 Workout Shoes',
#  'portraitURL': 'https://static.nike.com/a/images/t_default/15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0/free-metcon-4-workout-shoes-KX41Bv.png',
#  'landscapeURL': '',
#  'title': '',
#  'squarish': {'view': 'A',
#   'aspectRatio': 1,
#   'id': '6c248067-b97e-4f45-b17a-5a5e1c1c2423',
#   'type': 'product',
#   'url': 'https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-workout-shoes-KX41Bv.png'},
#  'portrait': {'view': 'A',
#   'aspectRatio': 0.8,
#   'id': '15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0',
#   'type': 'product',
#   'url': 'https://static.nike.com/a/images/t_default/15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0/free-metcon-4-workout-shoes-KX41Bv.png'},
#  'seoName': '',
# ...

# %%
json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0]['properties'].keys()
# Out:
# dict_keys(['portraitId', 'squarishURL', 'landscapeId', 'altText', 'portraitURL', 'landscapeURL', 'title', 'squarish', 'portrait', 'seoName', 'squarishId', 'subtitle', 'colorTheme'])

# %%
squarishURL = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0]['properties']['squarishURL']
portraitURL = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0]['properties']['portraitURL']
squarishURL2 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0]['properties']['squarish']['url']
portraitURL2 = json_object['props']['pageProps']['initialState']['Threads']['products']['CT3886-300']['nodes'][0]['nodes'][0]['properties']['portrait']['url']

# %% [markdown]
# # Data stuctures to hold our scraped values so we can turn it into a dataframe Later

# %%
Titles = []
prices = []
color = []
FirstImagesUrl = []
URL1 = []
URL2 = []
URL3 = []
URL4 = []

# %% [markdown]
# # NOW WE MAKE IT DYNAMIC!!

# %%
for i in json_object['props']['pageProps']['initialState']['Threads']['products'].keys():
    temp_list_for_pictures = []
    val1 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['title']
    val2 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['currentPrice']
    val3 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['colorDescription']
    val4 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['firstImageUrl']
    pic1 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['squarishURL']
    pic2 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['portraitURL']
    pic3 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['squarish']['url']
    pic4 = json_object['props']['pageProps']['initialState']['Threads']['products'][i]['nodes'][0]['nodes'][0]['properties']['portrait']['url']
    Titles.append(val1)
    prices.append(val2)
    color.append(val3)
    FirstImagesUrl.append(val4)
    URL1.append(pic1)
    URL2.append(pic2)
    URL3.append(pic3)
    URL4.append(pic4)

# %% [markdown]
# # Creating a DataFrame to organize everything

# %%
shoes = {
    "Title": Titles,
    "Price": prices,
    "Color": color,
    "FirstImageUrl": FirstImagesUrl,
    "squarishURL": URL1,
    "portraitURL": URL2,
    "squarishURL2": URL3,
    "portraitURL2" : URL4,
}

# %%
Final_Metcon_Data = pd.DataFrame(shoes)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
Final_Metcon_Data
# Out:
#                 Title  Price                                           Color  \
# 0  Nike Free Metcon 4  95.97  Mint Foam/Barely Green/Cave Purple/Ghost Green
#
#                                                                                                             FirstImageUrl  \
# 0  https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-workout-shoes-KX41Bv.png
#
#                                                                                                               squarishURL  \
# 0  https://static.nike.com/a/images/t_default/6c248067-b97e-4f45-b17a-5a5e1c1c2423/free-metcon-4-workout-shoes-KX41Bv.png
#
#                                                                                                               portraitURL  \
# 0  https://static.nike.com/a/images/t_default/15989f45-9d49-4c9a-8e02-f9ed1d8a0aa0/free-metcon-4-workout-shoes-KX41Bv.png
#
# ...

# %% [markdown]
# # Storing this data into a database in mysql Workbench

# %% [markdown]
# WE shall be creating a connection to mysql.connector to create our tables here in python and also check the data in our tables later on

# %%
import mysql.connector
from mysql.connector import errorcode

try:
  connection = mysql.connector.connect(host='localhost',
                                user='root',
                                passwd=Password) #password to workbench database
  print("Connection Succesful!!")

except mysql.connector.Error as err:
  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  else:
    print(err)
# Out:
# Connection Succesful!!

# %% [markdown]
# # Pre-defined queries to perform our desired functions

# %%
Database_use_Query = "use Data_Engineer_Track"

Table_Creation_Query = '''Create Table Nike_Shoes(col int primary key auto_increment, Title varchar(50), Price float, Color varchar(50),
                        FirstImageUrl varchar(1000), squarishURL varchar(1000), portraitURL varchar(1000), squarishURL2 varchar(1000),
                        portraitURL2 varchar(1000))'''

Final_result = '''Select * from Nike_Shoes;'''

# %%
cursor = connection.cursor()
cursor.execute(Database_use_Query) #query to be executed
# cursor.execute(Table_Creation_Query)
# result = cursor.fetchall() #Grabbing the result
# print(result)

# %% [markdown]
# # Creating A Engine connection to be able to connect to our database and write or desired results to A table

# %% [markdown]
# In this part, I shall be using the sqlalchemy python packacge to make a connection to our database and create a engine. We then write the final mecon results to the database

# %%
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                       .format(user="root",
                               pw=Password,
                               db="Data_Engineer_Track"))

# %% [markdown]
# # Finally Writing Our Dataframe To MYSQL WORKBENCH!

# %% [markdown]
# "Nike shoes" in this case is the name of our table and  con is the connection which would be the engine we created above. If exist is asking of what action to take if the table already exist and index = false means do not write the index of the dataframe to the database

# %%
#Final_Metcon_Data.to_sql('nike_shoes', con = engine, if_exists = 'append', chunksize = 1000,index= False)

# %% [markdown]
# # Checking our Final output or result that is stored in the database.

# %%
cursor.execute(Database_use_Query)
cursor.execute(Final_result) #Query to be executed
result = cursor.fetchall()

# %%
print(result)
# Out:
# [(1, 'Nike Free Metcon 4 AMP', 120.0, 'Dark Smoke Grey/Smoke Grey/Light Smoke Grey/Black', 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/79fcb768-1a4d-4bce-926d-3c6539562a28/free-metcon-4-amp-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/82ddc691-dfe5-4fe0-913c-38e17ecfdb60/free-metcon-4-amp-training-shoes-KX41Bv.png'), (2, 'Nike Free Metcon 4', 120.0, 'Iron Grey/Grey Fog/White/Black', 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/free-metcon-4-training-shoes-KX41Bv.png', 'https://static.nike.com/a/images/t_default/ea2cd2e3-7d73-4380-a3a7-1b6aff7eabab/
# ...
